# %%
# 8个G的细节评论
import os
import pandas as pd

def split_csv_by_column(file_path, output_path, column_name):
    """
    根据某列的值将CSV文件拆分为多个CSV文件

    :param file_path: 原CSV文件路径
    :param output_path: 拆分后的CSV文件输出路径
    :param column_name: 用于拆分数据的列名
    """
    # 检查输出文件夹是否存在，如果不存在则创建之
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # 使用pandas的read_csv函数读取CSV文件
    df = pd.read_csv(file_path)

    # 获取指定列的所有唯一值
    unique_values = df[column_name].unique()

    # 定义无法作为文件名的字符
    invalid_file_chars = ['#','$']

    # 遍历唯一值列表，为每个唯一值创建一个单独的CSV文件
    for value in unique_values:
        # 检查列名是否含有无法作为文件名的字符
        if any(char in str(value) for char in invalid_file_chars):
            print(f'Skipping invalid filename for value: {value}')
            continue  # 如果列名包含无效字符，跳过并处理下一个值

        subset_df = df[df[column_name] == value]
        output_file = f"{output_path}/{value}.csv"
        subset_df.to_csv(output_file, index=False)
        print(f"Saved data for {column_name} = {value} to {output_file}")

# 使用示例
input_file = "steam_reviews.csv"
output_dir = "comments"
column_to_split_by = "app_name"
split_csv_by_column(input_file, output_dir, column_to_split_by)
# Out:
# Saved data for app_name = The Witcher 3: Wild Hunt to comments/The Witcher 3: Wild Hunt.csv
# Saved data for app_name = Half-Life to comments/Half-Life.csv
# Saved data for app_name = Counter-Strike: Source to comments/Counter-Strike: Source.csv
# Saved data for app_name = Half-Life 2: Episode Two to comments/Half-Life 2: Episode Two.csv
# Saved data for app_name = Portal 2 to comments/Portal 2.csv
# Saved data for app_name = X Rebirth to comments/X Rebirth.csv
# Saved data for app_name = Garry's Mod to comments/Garry's Mod.csv
# Saved data for app_name = Sid Meier's Civilization V to comments/Sid Meier's Civilization V.csv
# Saved data for app_name = Dead by Daylight to comments/Dead by Daylight.csv
# Saved data for app_name = Sid Meier's Civilization VI to comments/Sid Meier's Civilization VI.csv
# Saved data for app_name = Subnautica to comments/Subnautica.csv
# Saved data for app_name = Human: Fall Flat to comments/Human: Fall Flat.csv
# Saved data for app_name = Beat Saber to comments/Beat Saber.csv
# Saved data for app_name = Cold Waters to comments/Cold Waters.csv
# Saved data for app_name = Banished to comments/Banished.csv
# Saved data for app_name = Celeste to comments/Celeste.csv
# Saved data for app_name = Getting Over It with Bennett Foddy to comments/Getting Over It with Bennett Foddy.csv
# Saved data for app_name = A Hat in Time to comments/A Hat in Time.csv
# Saved data for app_name = Overcooked! 2 to comments/Overcooked! 2.csv
# Saved data for app_name = Slipstream to comments/Slipstream.csv
# Saved data for app_name = The Forest to comments/The Forest.csv
# Saved data for app_name = Pogostuck: Rage With Your Friends to comments/Pogostuck: Rage With Your Friends.csv
# Saved data for app_name = PC Building Simulator to comments/PC Building Simulator.csv
# Saved data for app_name = RollerCoaster Tycoon World to comments/RollerCoaster Tycoon World.csv
# Saved data for app_name = NBA 2K18 to comments/NBA 2K18.csv
# Saved data for app_name = NBA 2K21 to comments/NBA 2K21.csv
# Saved data for app_name = Deus Ex: The Fall to comments/Deus Ex: The Fall.csv
# Saved data for app_name = Rapture Rejects to comments/Rapture Rejects.csv
# Saved data for app_name = Artifact to comments/Artifact.csv
# Saved data for app_name = Call of Duty: Infinite Warfare to comments/Call of Duty: Infinite Warfare.csv
# Saved data for app_name = Cube World to comments/Cube World.csv
# Saved data for app_name = NBA 2K19 to comments/NBA 2K19.csv
# Saved data for app_name = Nether to comments/Nether.csv
# Saved data for app_name = Wolfenstein: Youngblood to comments/Wolfenstein: Youngblood.csv
# Saved data for app_name = Warhammer 40,000: Dawn of War III to comments/Warhammer 40,000: Dawn of War III.csv
# Saved data for app_name = Takedown: Red Sabre to comments/Takedown: Red Sabre.csv
# Saved data for app_name = ATLAS to comments/ATLAS.csv
# Saved data for app_name = Stay Out to comments/Stay Out.csv
# Saved data for app_name = Identity to comments/Identity.csv
# Saved data for app_name = Umbrella Corps to comments/Umbrella Corps.csv
# Saved data for app_name = Hunt Down The Freeman to comments/Hunt Down The Freeman.csv
# Saved data for app_name = WWE 2K20 to comments/WWE 2K20.csv
# Saved data for app_name = Down To One to comments/Down To One.csv
# Saved data for app_name = Axiom Verge to comments/Axiom Verge.csv
# Saved data for app_name = Guacamelee! Super Turbo Championship Edition to comments/Guacamelee! Super Turbo Championship Edition.csv
# Saved data for app_name = The Binding of Isaac: Rebirth to comments/The Binding of Isaac: Rebirth.csv
# Saved data for app_name = To the Moon to comments/To the Moon.csv
# Saved data for app_name = Cave Story+ to comments/Cave Story+.csv
# Saved data for app_name = Titan Souls to comments/Titan Souls.csv
# Saved data for app_name = Shovel Knight: Treasure Trove to comments/Shovel Knight: Treasure Trove.csv
# Saved data for app_name = Super Meat Boy to comments/Super Meat Boy.csv
# Saved data for app_name = Don't Escape: 4 Days to Survive to comments/Don't Escape: 4 Days to Survive.csv
# Saved data for app_name = Volgarr the Viking to comments/Volgarr the Viking.csv
# Saved data for app_name = Momodora: Reverie Under the Moonlight to comments/Momodora: Reverie Under the Moonlight.csv
# Saved data for app_name = Enter the Gungeon to comments/Enter the Gungeon.csv
# Saved data for app_name = Shadow Complex Remastered to comments/Shadow Complex Remastered.csv
# Saved data for app_name = Salt and Sanctuary to comments/Salt and Sanctuary.csv
# Saved data for app_name = 20XX to comments/20XX.csv
# Saved data for app_name = Hollow Knight to comments/Hollow Knight.csv
# Saved data for app_name = The End Is Nigh to comments/The End Is Nigh.csv
# Saved data for app_name = Factorio to comments/Factorio.csv
# Saved data for app_name = RimWorld to comments/RimWorld.csv
# Saved data for app_name = Insurgency: Sandstorm to comments/Insurgency: Sandstorm.csv
# Saved data for app_name = Slay the Spire to comments/Slay the Spire.csv
# Saved data for app_name = Euro Truck Simulator 2 to comments/Euro Truck Simulator 2.csv
# Saved data for app_name = Wallpaper Engine to comments/Wallpaper Engine.csv
# Saved data for app_name = Pathfinder: Kingmaker to comments/Pathfinder: Kingmaker.csv
# Saved data for app_name = Farming Simulator 19 to comments/Farming Simulator 19.csv
# Saved data for app_name = Foundation to comments/Foundation.csv
# Saved data for app_name = GOD EATER 3 to comments/GOD EATER 3.csv
# Saved data for app_name = Kenshi to comments/Kenshi.csv
# Saved data for app_name = Into the Breach to comments/Into the Breach.csv
# Saved data for app_name = Warhammer: Vermintide 2 to comments/Warhammer: Vermintide 2.csv
# Saved data for app_name = A Way Out to comments/A Way Out.csv
# Saved data for app_name = Borderlands 3 to comments/Borderlands 3.csv
# Saved data for app_name = Sekiro™: Shadows Die Twice to comments/Sekiro™: Shadows Die Twice.csv
# Saved data for app_name = Total War: THREE KINGDOMS to comments/Total War: THREE KINGDOMS.csv
# Saved data for app_name = DEATH STRANDING to comments/DEATH STRANDING.csv
# Saved data for app_name = MORDHAU to comments/MORDHAU.csv
# Saved data for app_name = DOOM Eternal to comments/DOOM Eternal.csv
# Saved data for app_name = Age of Empires: Definitive Edition to comments/Age of Empires: Definitive Edition.csv
# Saved data for app_name = A Short Hike to comments/A Short Hike.csv
# Saved data for app_name = The Henry Stickmin Collection to comments/The Henry Stickmin Collection.csv
# Saved data for app_name = Crusader Kings III to comments/Crusader Kings III.csv
# Saved data for app_name = Void Bastards to comments/Void Bastards.csv
# Saved data for app_name = Stardew Valley to comments/Stardew Valley.csv
# Saved data for app_name = Tom Clancy's Rainbow Six Siege to comments/Tom Clancy's Rainbow Six Siege.csv
# Saved data for app_name = Among Us to comments/Among Us.csv
# Saved data for app_name = 三国群英传8 Heroes of the Three Kingdoms 8 to comments/三国群英传8 Heroes of the Three Kingdoms 8.csv
# Saved data for app_name = Blackwake to comments/Blackwake.csv
# Saved data for app_name = Little Nightmares to comments/Little Nightmares.csv
# Saved data for app_name = Bomber Crew to comments/Bomber Crew.csv
# Saved data for app_name = Neon Hardcorps to comments/Neon Hardcorps.csv
# Saved data for app_name = Dragon Cliff 龙崖 to comments/Dragon Cliff 龙崖.csv
# Saved data for app_name = DRAGON BALL FighterZ to comments/DRAGON BALL FighterZ.csv
# Saved data for app_name = X-Blades to comments/X-Blades.csv
# Saved data for app_name = Rust to comments/Rust.csv
# Saved data for app_name = Nova Drift to comments/Nova Drift.csv
# Saved data for app_name = Due Process to comments/Due Process.csv
# Saved data for app_name = Far Cry 5 to comments/Far Cry 5.csv
# Saved data for app_name = Raft to comments/Raft.csv
# Saved data for app_name = HITMAN™ 2 to comments/HITMAN™ 2.csv
# Saved data for app_name = Assassin's Creed Odyssey to comments/Assassin's Creed Odyssey.csv
# Saved data for app_name = Hades to comments/Hades.csv
# Saved data for app_name = Phasmophobia to comments/Phasmophobia.csv
# Saved data for app_name = Helltaker to comments/Helltaker.csv
# Saved data for app_name = Mount & Blade: Warband to comments/Mount & Blade: Warband.csv
# Saved data for app_name = Totally Accurate Battle Simulator to comments/Totally Accurate Battle Simulator.csv
# Saved data for app_name = People Playground to comments/People Playground.csv
# Saved data for app_name = Doki Doki Literature Club to comments/Doki Doki Literature Club.csv
# Saved data for app_name = Resident Evil 2 to comments/Resident Evil 2.csv
# Saved data for app_name = Slime Rancher to comments/Slime Rancher.csv
# Saved data for app_name = Hotline Miami to comments/Hotline Miami.csv
# Saved data for app_name = Tomb Raider to comments/Tomb Raider.csv
# Saved data for app_name = Mirror to comments/Mirror.csv
# Saved data for app_name = BattleBlock Theater to comments/BattleBlock Theater.csv
# Saved data for app_name = Dishonored to comments/Dishonored.csv
# Saved data for app_name = South Park™: The Stick of Truth™ to comments/South Park™: The Stick of Truth™.csv
# Saved data for app_name = Undertale to comments/Undertale.csv
# Saved data for app_name = Don't Starve to comments/Don't Starve.csv
# Saved data for app_name = Rocket League to comments/Rocket League.csv
# Saved data for app_name = Persona 4 Golden to comments/Persona 4 Golden.csv
# Saved data for app_name = Dead Cells to comments/Dead Cells.csv
# Saved data for app_name = OneShot to comments/OneShot.csv
# Saved data for app_name = VA-11 Hall-A: Cyberpunk Bartender Action to comments/VA-11 Hall-A: Cyberpunk Bartender Action.csv
# Saved data for app_name = Broforce to comments/Broforce.csv
# Saved data for app_name = The Wolf Among Us to comments/The Wolf Among Us.csv
# Saved data for app_name = The Walking Dead to comments/The Walking Dead.csv
# Saved data for app_name = Divinity: Original Sin 2 to comments/Divinity: Original Sin 2.csv
# Saved data for app_name = Satisfactory to comments/Satisfactory.csv
# Saved data for app_name = One Finger Death Punch to comments/One Finger Death Punch.csv
# Saved data for app_name = Bloons TD 6 to comments/Bloons TD 6.csv
# Saved data for app_name = Oxygen Not Included to comments/Oxygen Not Included.csv
# Saved data for app_name = Cuphead to comments/Cuphead.csv
# Saved data for app_name = ULTRAKILL to comments/ULTRAKILL.csv
# Saved data for app_name = Baba Is You to comments/Baba Is You.csv
# Saved data for app_name = Castle Crashers to comments/Castle Crashers.csv
# Saved data for app_name = Townscaper to comments/Townscaper.csv
# Saved data for app_name = Papers, Please to comments/Papers, Please.csv
# Saved data for app_name = Senren＊Banka to comments/Senren＊Banka.csv
# Saved data for app_name = GRIS to comments/GRIS.csv
# Saved data for app_name = DUSK to comments/DUSK.csv
# Saved data for app_name = Outlast to comments/Outlast.csv
# Saved data for app_name = The Elder Scrolls V: Skyrim to comments/The Elder Scrolls V: Skyrim.csv
# Saved data for app_name = The Room to comments/The Room.csv
# Saved data for app_name = FTL: Faster Than Light to comments/FTL: Faster Than Light.csv
# Saved data for app_name = There Is No Game: Wrong Dimension to comments/There Is No Game: Wrong Dimension.csv
# Saved data for app_name = Dying Light to comments/Dying Light.csv
# Saved data for app_name = American Truck Simulator to comments/American Truck Simulator.csv
# Saved data for app_name = Saints Row: The Third to comments/Saints Row: The Third.csv
# Saved data for app_name = STAR WARS™ Empire at War: Gold Pack to comments/STAR WARS™ Empire at War: Gold Pack.csv
# Saved data for app_name = Ori and the Will of the Wisps to comments/Ori and the Will of the Wisps.csv
# Saved data for app_name = BeamNG.drive to comments/BeamNG.drive.csv
# Saved data for app_name = The Room Two to comments/The Room Two.csv
# Saved data for app_name = Age of Empires II (2013) to comments/Age of Empires II (2013).csv
# Saved data for app_name = Ravenfield to comments/Ravenfield.csv
# Saved data for app_name = Super Hexagon to comments/Super Hexagon.csv
# Saved data for app_name = BioShock Infinite to comments/BioShock Infinite.csv
# Saved data for app_name = Just Shapes & Beats to comments/Just Shapes & Beats.csv
# Saved data for app_name = DOOM to comments/DOOM.csv
# Saved data for app_name = Black Mesa to comments/Black Mesa.csv
# Saved data for app_name = Finding Paradise to comments/Finding Paradise.csv
# Saved data for app_name = Tabletop Simulator to comments/Tabletop Simulator.csv
# Saved data for app_name = Keep Talking and Nobody Explodes to comments/Keep Talking and Nobody Explodes.csv
# Saved data for app_name = Duck Game to comments/Duck Game.csv
# Saved data for app_name = STEINS;GATE to comments/STEINS;GATE.csv
# Saved data for app_name = Danganronpa: Trigger Happy Havoc to comments/Danganronpa: Trigger Happy Havoc.csv
# Saved data for app_name = Mark of the Ninja to comments/Mark of the Ninja.csv
# Saved data for app_name = Phoenix Wright: Ace Attorney Trilogy to comments/Phoenix Wright: Ace Attorney Trilogy.csv
# Saved data for app_name = Batman: Arkham Asylum GOTY Edition to comments/Batman: Arkham Asylum GOTY Edition.csv
# Saved data for app_name = Gunpoint to comments/Gunpoint.csv
# Saved data for app_name = The Binding of Isaac to comments/The Binding of Isaac.csv
# Saved data for app_name = Danganronpa 2: Goodbye Despair to comments/Danganronpa 2: Goodbye Despair.csv
# Saved data for app_name = HuniePop to comments/HuniePop.csv
# Saved data for app_name = Grimm's Hollow to comments/Grimm's Hollow.csv
# Saved data for app_name = Grand Theft Auto V to comments/Grand Theft Auto V.csv
# Saved data for app_name = PLAYERUNKNOWN'S BATTLEGROUNDS to comments/PLAYERUNKNOWN'S BATTLEGROUNDS.csv
# Saved data for app_name = Monster Hunter: World to comments/Monster Hunter: World.csv
# Saved data for app_name = The Elder Scrolls Online to comments/The Elder Scrolls Online.csv
# Saved data for app_name = Total War: WARHAMMER II to comments/Total War: WARHAMMER II.csv
# Saved data for app_name = Cities: Skylines to comments/Cities: Skylines.csv
# Saved data for app_name = Assassin's Creed Origins to comments/Assassin's Creed Origins.csv
# Saved data for app_name = Stellaris to comments/Stellaris.csv
# Saved data for app_name = Black Desert Online to comments/Black Desert Online.csv
# Saved data for app_name = Kingdom Come: Deliverance to comments/Kingdom Come: Deliverance.csv
# Saved data for app_name = Jurassic World Evolution to comments/Jurassic World Evolution.csv
# Saved data for app_name = ARK: Survival Evolved to comments/ARK: Survival Evolved.csv
# Saved data for app_name = No Man's Sky to comments/No Man's Sky.csv
# Saved data for app_name = SCUM to comments/SCUM.csv
# Saved data for app_name = Frostpunk to comments/Frostpunk.csv
# Saved data for app_name = Tom Clancy's Ghost Recon® Wildlands to comments/Tom Clancy's Ghost Recon® Wildlands.csv
# Saved data for app_name = FINAL FANTASY XV WINDOWS EDITION to comments/FINAL FANTASY XV WINDOWS EDITION.csv
# Saved data for app_name = Fallout 4 to comments/Fallout 4.csv
# Saved data for app_name = DARK SOULS™ III to comments/DARK SOULS™ III.csv
# Saved data for app_name = Rise of the Tomb Raider to comments/Rise of the Tomb Raider.csv
# Saved data for app_name = Sword Art Online: Fatal Bullet to comments/Sword Art Online: Fatal Bullet.csv
# Saved data for app_name = The Crew 2 to comments/The Crew 2.csv
# Saved data for app_name = DARK SOULS™: REMASTERED to comments/DARK SOULS™: REMASTERED.csv
# Saved data for app_name = Middle-earth™: Shadow of War™ to comments/Middle-earth™: Shadow of War™.csv
# Saved data for app_name = Watch_Dogs 2 to comments/Watch_Dogs 2.csv
# Saved data for app_name = Pillars of Eternity II: Deadfire to comments/Pillars of Eternity II: Deadfire.csv
# Saved data for app_name = Hearts of Iron IV to comments/Hearts of Iron IV.csv
# Saved data for app_name = They Are Billions to comments/They Are Billions.csv
# Saved data for app_name = Total War Saga: Thrones of Britannia to comments/Total War Saga: Thrones of Britannia.csv
# Saved data for app_name = Don't Starve Together to comments/Don't Starve Together.csv
# Saved data for app_name = Total War: ROME II - Emperor Edition to comments/Total War: ROME II - Emperor Edition.csv
# Saved data for app_name = Call of Duty: WWII to comments/Call of Duty: WWII.csv
# Saved data for app_name = BATTLETECH to comments/BATTLETECH.csv
# Saved data for app_name = Terraria to comments/Terraria.csv
# Saved data for app_name = PAYDAY 2 to comments/PAYDAY 2.csv
# Saved data for app_name = XCOM 2 to comments/XCOM 2.csv
# Saved data for app_name = Deep Rock Galactic to comments/Deep Rock Galactic.csv
# Saved data for app_name = The Sims(TM) 3 to comments/The Sims(TM) 3.csv
# Saved data for app_name = Hunt: Showdown to comments/Hunt: Showdown.csv
# Saved data for app_name = theHunter: Call of the Wild™ to comments/theHunter: Call of the Wild™.csv
# Saved data for app_name = Conan Exiles to comments/Conan Exiles.csv
# Saved data for app_name = Two Point Hospital to comments/Two Point Hospital.csv
# Saved data for app_name = Total War: WARHAMMER to comments/Total War: WARHAMMER.csv
# Saved data for app_name = The Elder Scrolls V: Skyrim Special Edition to comments/The Elder Scrolls V: Skyrim Special Edition.csv
# Saved data for app_name = Darkest Dungeon® to comments/Darkest Dungeon®.csv
# Saved data for app_name = NieR:Automata™ to comments/NieR:Automata™.csv
# Saved data for app_name = Bless Online to comments/Bless Online.csv
# Saved data for app_name = Football Manager 2019 to comments/Football Manager 2019.csv
# Saved data for app_name = House Flipper to comments/House Flipper.csv
# Saved data for app_name = Surviving Mars to comments/Surviving Mars.csv
# Saved data for app_name = SOULCALIBUR VI to comments/SOULCALIBUR VI.csv
# Saved data for app_name = For Honor to comments/For Honor.csv
# Saved data for app_name = Arma 3 to comments/Arma 3.csv
# Saved data for app_name = Ni no Kuni™ II: Revenant Kingdom to comments/Ni no Kuni™ II: Revenant Kingdom.csv
# Saved data for app_name = SOS to comments/SOS.csv
# Saved data for app_name = Battle Royale Trainer to comments/Battle Royale Trainer.csv
# Saved data for app_name = My Time At Portia to comments/My Time At Portia.csv
# Saved data for app_name = Iconoclasts to comments/Iconoclasts.csv
# Saved data for app_name = Railway Empire to comments/Railway Empire.csv
# Saved data for app_name = Trailmakers to comments/Trailmakers.csv
# Saved data for app_name = Staxel to comments/Staxel.csv
# Saved data for app_name = BATTALION 1944 to comments/BATTALION 1944.csv
# Saved data for app_name = The Legend of Heroes: Trails of Cold Steel II to comments/The Legend of Heroes: Trails of Cold Steel II.csv
# Saved data for app_name = Rise of Industry to comments/Rise of Industry.csv
# Saved data for app_name = CHRONO TRIGGER to comments/CHRONO TRIGGER.csv
# Saved data for app_name = Freeman: Guerrilla Warfare to comments/Freeman: Guerrilla Warfare.csv
# Saved data for app_name = Dungreed to comments/Dungreed.csv
# Saved data for app_name = Puyo Puyo™Tetris®  to comments/Puyo Puyo™Tetris® .csv
# Saved data for app_name = Secret of Mana to comments/Secret of Mana.csv
# Saved data for app_name = Farm Together to comments/Farm Together.csv
# Saved data for app_name = Cyberdimension Neptunia: 4 Goddesses Online to comments/Cyberdimension Neptunia: 4 Goddesses Online.csv
# Saved data for app_name = Fishing: Barents Sea to comments/Fishing: Barents Sea.csv
# Saved data for app_name = DYNASTY WARRIORS 9 to comments/DYNASTY WARRIORS 9.csv
# Saved data for app_name = We Were Here Too to comments/We Were Here Too.csv
# Saved data for app_name = METAL GEAR SURVIVE to comments/METAL GEAR SURVIVE.csv
# Saved data for app_name = Desolate to comments/Desolate.csv
# Saved data for app_name = Eco to comments/Eco.csv
# Saved data for app_name = SENRAN KAGURA Peach Beach Splash to comments/SENRAN KAGURA Peach Beach Splash.csv
# Saved data for app_name = PixARK to comments/PixARK.csv
# Saved data for app_name = Out of the Park Baseball 19 to comments/Out of the Park Baseball 19.csv
# Saved data for app_name = Devil May Cry HD Collection to comments/Devil May Cry HD Collection.csv
# Saved data for app_name = Heroes of Hammerwatch to comments/Heroes of Hammerwatch.csv
# Saved data for app_name = Ghost of a Tale to comments/Ghost of a Tale.csv
# Saved data for app_name = Monster Prom to comments/Monster Prom.csv
# Saved data for app_name = Farm Manager 2018 to comments/Farm Manager 2018.csv
# Saved data for app_name = Rules Of Survival to comments/Rules Of Survival.csv
# Saved data for app_name = STEINS;GATE 0 to comments/STEINS;GATE 0.csv
# Saved data for app_name = Ancestors Legacy to comments/Ancestors Legacy.csv
# Saved data for app_name = FAR: Lone Sails to comments/FAR: Lone Sails.csv
# Saved data for app_name = Crash Bandicoot™ N. Sane Trilogy to comments/Crash Bandicoot™ N. Sane Trilogy.csv
# Saved data for app_name = Budget Cuts to comments/Budget Cuts.csv
# Saved data for app_name = Totally Accurate Battlegrounds to comments/Totally Accurate Battlegrounds.csv
# Saved data for app_name = Vampyr to comments/Vampyr.csv
# Saved data for app_name = Clicker Heroes 2 to comments/Clicker Heroes 2.csv
# Saved data for app_name = Yakuza 0 to comments/Yakuza 0.csv
# Saved data for app_name = WWE 2K19 to comments/WWE 2K19.csv
# Saved data for app_name = Warhammer 40,000: Mechanicus to comments/Warhammer 40,000: Mechanicus.csv
# Saved data for app_name = Thief Simulator to comments/Thief Simulator.csv
# Saved data for app_name = Darksiders III to comments/Darksiders III.csv
# Saved data for app_name = Mutant Year Zero: Road to Eden to comments/Mutant Year Zero: Road to Eden.csv
# Saved data for app_name = Kingdom Two Crowns to comments/Kingdom Two Crowns.csv
# Saved data for app_name = Just Cause 4 to comments/Just Cause 4.csv
# Saved data for app_name = Planet Coaster to comments/Planet Coaster.csv
# Saved data for app_name = Nioh: Complete Edition to comments/Nioh: Complete Edition.csv
# Saved data for app_name = Europa Universalis IV to comments/Europa Universalis IV.csv
# Saved data for app_name = FINAL FANTASY XII THE ZODIAC AGE to comments/FINAL FANTASY XII THE ZODIAC AGE.csv
# Saved data for app_name = Just Cause 3 to comments/Just Cause 3.csv
# Saved data for app_name = FINAL FANTASY XIV Online to comments/FINAL FANTASY XIV Online.csv
# Saved data for app_name = Resident Evil 7 Biohazard to comments/Resident Evil 7 Biohazard.csv
# Saved data for app_name = Torment: Tides of Numenera to comments/Torment: Tides of Numenera.csv
# Saved data for app_name = Detention to comments/Detention.csv
# Saved data for app_name = Pit People to comments/Pit People.csv
# Saved data for app_name = Tales of Berseria to comments/Tales of Berseria.csv
# Saved data for app_name = Urban Empire to comments/Urban Empire.csv
# Saved data for app_name = Avorion to comments/Avorion.csv
# Saved data for app_name = Youtubers Life to comments/Youtubers Life.csv
# Saved data for app_name = Night in the Woods to comments/Night in the Woods.csv
# Saved data for app_name = Golf It! to comments/Golf It!.csv
# Saved data for app_name = Northgard to comments/Northgard.csv
# Saved data for app_name = BERSERK and the Band of the Hawk to comments/BERSERK and the Band of the Hawk.csv
# Saved data for app_name = The Wild Eight to comments/The Wild Eight.csv
# Saved data for app_name = Sniper Elite 4 to comments/Sniper Elite 4.csv
# Saved data for app_name = For The King to comments/For The King.csv
# Saved data for app_name = WWE 2K17 to comments/WWE 2K17.csv
# Saved data for app_name = Fairy Fencer F Advent Dark Force to comments/Fairy Fencer F Advent Dark Force.csv
# Saved data for app_name = Day of Infamy to comments/Day of Infamy.csv
# Saved data for app_name = SENRAN KAGURA ESTIVAL VERSUS to comments/SENRAN KAGURA ESTIVAL VERSUS.csv
# Saved data for app_name = Streets of Rogue to comments/Streets of Rogue.csv
# Saved data for app_name = Ultimate Marvel vs. Capcom 3 to comments/Ultimate Marvel vs. Capcom 3.csv
# Saved data for app_name = SimAirport to comments/SimAirport.csv
# Saved data for app_name = Thimbleweed Park to comments/Thimbleweed Park.csv
# Saved data for app_name = Toukiden 2 to comments/Toukiden 2.csv
# Saved data for app_name = Dead Rising 4 to comments/Dead Rising 4.csv
# Saved data for app_name = X-Plane 11 to comments/X-Plane 11.csv
# Saved data for app_name = Styx: Shards of Darkness to comments/Styx: Shards of Darkness.csv
# Saved data for app_name = Train Sim World® 2020 to comments/Train Sim World® 2020.csv
# Saved data for app_name = DRAGON QUEST HEROES™ II to comments/DRAGON QUEST HEROES™ II.csv
# Saved data for app_name = Steel Division: Normandy 44 to comments/Steel Division: Normandy 44.csv
# Saved data for app_name = DiRT 4 to comments/DiRT 4.csv
# Saved data for app_name = Half-Life: Alyx to comments/Half-Life: Alyx.csv

# %%
# # 2个的正常评论
#
# def split_csv_by_column(file_path, output_path, column_name):
#     """
#     根据某列的值将CSV文件拆分为多个CSV文件
#
#     :param file_path: 原CSV文件路径
#     :param output_path: 拆分后的CSV文件输出路径
#     :param column_name: 用于拆分数据的列名
#     """
#     # 检查输出文件夹是否存在，如果不存在则创建之
#     if not os.path.exists(output_path):
#         os.makedirs(output_path)
#
#     # 使用pandas的read_csv函数读取CSV文件
#     df = pd.read_csv(file_path)
#
#     # 获取指定列的所有唯一值
#     unique_values = df[column_name].unique()
#
#     # 定义无法作为文件名的字符
#     invalid_file_chars = ['#','$']
#
#     # 遍历唯一值列表，为每个唯一值创建一个单独的CSV文件
#     for value in unique_values:
#         # 检查列名是否含有无法作为文件名的字符
#         if 'Retro' in str(value):
#             print(f'Skipping value containing Retro: {value}')
#             continue
#         if 'Valiant Hearts: The Great War™' in str(value):
#             print(f'Skipping value containing Retro: {value}')
#             continue
#         if any(char in str(value) for char in invalid_file_chars):
#             print(f'Skipping invalid filename for value: {value}')
#             continue  # 如果列名包含无效字符，跳过并处理下一个值
#
#         subset_df = df[df[column_name] == value]
#         output_file = f"{output_path}/{value}.csv"
#         subset_df.to_csv(output_file, index=False)
#         print(f"Saved data for {column_name} = {value} to {output_file}")
#
# # 使用示例
# input_file = "dataset.csv"
# output_dir = "most_game_comments"
# column_to_split_by = "app_name"
# split_csv_by_column(input_file, output_dir, column_to_split_by)
# Out:
# Saved data for app_name = Counter-Strike to most_game_comments/Counter-Strike.csv
# Saved data for app_name = Rag Doll Kung Fu to most_game_comments/Rag Doll Kung Fu.csv
# Saved data for app_name = Silo 2 to most_game_comments/Silo 2.csv
# Saved data for app_name = Call of Duty: World at War to most_game_comments/Call of Duty: World at War.csv
# Saved data for app_name = nan to most_game_comments/nan.csv
# Saved data for app_name = King's Quest Collection to most_game_comments/King's Quest Collection.csv
# Saved data for app_name = Space Quest Collection to most_game_comments/Space Quest Collection.csv
# Saved data for app_name = Aces of the Galaxy to most_game_comments/Aces of the Galaxy.csv
# Saved data for app_name = TimeShift to most_game_comments/TimeShift.csv
# Saved data for app_name = 3D Ultra Minigolf Adventures Deluxe to most_game_comments/3D Ultra Minigolf Adventures Deluxe.csv
# Saved data for app_name = Prototype to most_game_comments/Prototype.csv
# Saved data for app_name = Call of Duty: Modern Warfare 2 to most_game_comments/Call of Duty: Modern Warfare 2.csv
# Saved data for app_name = Postal 3 to most_game_comments/Postal 3.csv
# Saved data for app_name = Runespell: Overture to most_game_comments/Runespell: Overture.csv
# Saved data for app_name = Dead Mountaineer's Hotel to most_game_comments/Dead Mountaineer's Hotel.csv
# Saved data for app_name = Stroke of Fate: Operation Valkyrie to most_game_comments/Stroke of Fate: Operation Valkyrie.csv
# Saved data for app_name = PT Boats: Knights of the Sea to most_game_comments/PT Boats: Knights of the Sea.csv
# Saved data for app_name = Kingdoms of Amalur: Reckoning™ to most_game_comments/Kingdoms of Amalur: Reckoning™.csv
# Saved data for app_name = PT Boats: South Gambit to most_game_comments/PT Boats: South Gambit.csv
# Saved data for app_name = Orcs Must Die! to most_game_comments/Orcs Must Die!.csv
# Saved data for app_name = Disciples III: Reincarnation to most_game_comments/Disciples III: Reincarnation.csv
# Saved data for app_name = A.V.A. Alliance of Valiant Arms™ to most_game_comments/A.V.A. Alliance of Valiant Arms™.csv
# Saved data for app_name = Gatling Gears to most_game_comments/Gatling Gears.csv
# Saved data for app_name = Shank 2 to most_game_comments/Shank 2.csv
# Saved data for app_name = WARP to most_game_comments/WARP.csv
# Saved data for app_name = iBomber Defense to most_game_comments/iBomber Defense.csv
# Saved data for app_name = Storm in a Teacup to most_game_comments/Storm in a Teacup.csv
# Saved data for app_name = Inside a Star-filled Sky  to most_game_comments/Inside a Star-filled Sky .csv
# Saved data for app_name = BEEP to most_game_comments/BEEP.csv
# Saved data for app_name = The Club to most_game_comments/The Club.csv
# Saved data for app_name = Portal 2 - The Final Hours to most_game_comments/Portal 2 - The Final Hours.csv
# Saved data for app_name = Super Monday Night Combat to most_game_comments/Super Monday Night Combat.csv
# Saved data for app_name = ORION: Prelude to most_game_comments/ORION: Prelude.csv
# Saved data for app_name = Total War: EMPIRE - Definitive Edition to most_game_comments/Total War: EMPIRE - Definitive Edition.csv
# Saved data for app_name = A New Beginning - Final Cut to most_game_comments/A New Beginning - Final Cut.csv
# Saved data for app_name = Lume to most_game_comments/Lume.csv
# Saved data for app_name = Critical Mass to most_game_comments/Critical Mass.csv
# Saved data for app_name = Ms. Splosion Man to most_game_comments/Ms. Splosion Man.csv
# Saved data for app_name = Age of Empires® III (2007) to most_game_comments/Age of Empires® III (2007).csv
# Saved data for app_name = Terraria to most_game_comments/Terraria.csv
# Saved data for app_name = Tobe's Vertical Adventure to most_game_comments/Tobe's Vertical Adventure.csv
# Saved data for app_name = The Cursed Crusade to most_game_comments/The Cursed Crusade.csv
# Saved data for app_name = Aliens vs. Predator to most_game_comments/Aliens vs. Predator.csv
# Saved data for app_name = Bastion to most_game_comments/Bastion.csv
# Saved data for app_name = Space Pirates and Zombies to most_game_comments/Space Pirates and Zombies.csv
# Saved data for app_name = Breath of Death VII  to most_game_comments/Breath of Death VII .csv
# Saved data for app_name = Cthulhu Saves the World  to most_game_comments/Cthulhu Saves the World .csv
# Saved data for app_name = Arma 3 to most_game_comments/Arma 3.csv
# Saved data for app_name = Waves to most_game_comments/Waves.csv
# Saved data for app_name = War Inc. Battlezone to most_game_comments/War Inc. Battlezone.csv
# Saved data for app_name = Starpoint Gemini to most_game_comments/Starpoint Gemini.csv
# Saved data for app_name = Ticket to Ride to most_game_comments/Ticket to Ride.csv
# Saved data for app_name = Memoir '44 Online to most_game_comments/Memoir '44 Online.csv
# Saved data for app_name = Vessel to most_game_comments/Vessel.csv
# Saved data for app_name = Project Zomboid to most_game_comments/Project Zomboid.csv
# Saved data for app_name = Death Rally to most_game_comments/Death Rally.csv
# Saved data for app_name = Alan Wake to most_game_comments/Alan Wake.csv
# Saved data for app_name = Legend of Fae to most_game_comments/Legend of Fae.csv
# Saved data for app_name = Fowl Space to most_game_comments/Fowl Space.csv
# Saved data for app_name = Achron to most_game_comments/Achron.csv
# Saved data for app_name = Sherlock Holmes: Nemesis to most_game_comments/Sherlock Holmes: Nemesis.csv
# Saved data for app_name = inMomentum to most_game_comments/inMomentum.csv
# Saved data for app_name = Dracula: Origin to most_game_comments/Dracula: Origin.csv
# Saved data for app_name = Data Jammers: FastForward to most_game_comments/Data Jammers: FastForward.csv
# Saved data for app_name = Astro Tripper to most_game_comments/Astro Tripper.csv
# Saved data for app_name = Mutant Storm Reloaded to most_game_comments/Mutant Storm Reloaded.csv
# Saved data for app_name = L.A. Noire to most_game_comments/L.A. Noire.csv
# Saved data for app_name = The Clockwork Man to most_game_comments/The Clockwork Man.csv
# Saved data for app_name = The Clockwork Man: The Hidden World to most_game_comments/The Clockwork Man: The Hidden World.csv
# Saved data for app_name = Snuggle Truck to most_game_comments/Snuggle Truck.csv
# Saved data for app_name = Sherlock Holmes: The Mystery of The Mummy to most_game_comments/Sherlock Holmes: The Mystery of The Mummy.csv
# Saved data for app_name = Smash Cars to most_game_comments/Smash Cars.csv
# Saved data for app_name = Sherlock Holmes: The Awakened - Remastered to most_game_comments/Sherlock Holmes: The Awakened - Remastered.csv
# Saved data for app_name = Bunch Of Heroes to most_game_comments/Bunch Of Heroes.csv
# Saved data for app_name = Sherlock Holmes: The Secret of the Silver Earring to most_game_comments/Sherlock Holmes: The Secret of the Silver Earring.csv
# Saved data for app_name = Serious Sam Double D XXL to most_game_comments/Serious Sam Double D XXL.csv
# Saved data for app_name = Sherlock Holmes: The Mystery of The Persian Carpet to most_game_comments/Sherlock Holmes: The Mystery of The Persian Carpet.csv
# Saved data for app_name = Blocks That Matter to most_game_comments/Blocks That Matter.csv
# Saved data for app_name = Sherlock Holmes versus Jack the Ripper to most_game_comments/Sherlock Holmes versus Jack the Ripper.csv
# Saved data for app_name = Guardians of Middle-earth to most_game_comments/Guardians of Middle-earth.csv
# Saved data for app_name = Shadowgrounds: Survivor to most_game_comments/Shadowgrounds: Survivor.csv
# Saved data for app_name = Avadon: The Black Fortress to most_game_comments/Avadon: The Black Fortress.csv
# Saved data for app_name = Gumboy Tournament to most_game_comments/Gumboy Tournament.csv
# Saved data for app_name = Space Trader: Merchant Marine to most_game_comments/Space Trader: Merchant Marine.csv
# Saved data for app_name = Pacific Storm to most_game_comments/Pacific Storm.csv
# Saved data for app_name = Pacific Storm: Allies to most_game_comments/Pacific Storm: Allies.csv
# Saved data for app_name = Penguins Arena: Sedna's World to most_game_comments/Penguins Arena: Sedna's World.csv
# Saved data for app_name = Monaco to most_game_comments/Monaco.csv
# Saved data for app_name = The Binding of Isaac to most_game_comments/The Binding of Isaac.csv
# Saved data for app_name = Larva Mortus to most_game_comments/Larva Mortus.csv
# Saved data for app_name = APB Reloaded to most_game_comments/APB Reloaded.csv
# Saved data for app_name = Fallen Earth to most_game_comments/Fallen Earth.csv
# Saved data for app_name = Chains to most_game_comments/Chains.csv
# Saved data for app_name = Nikopol: Secrets of the Immortals to most_game_comments/Nikopol: Secrets of the Immortals.csv
# Saved data for app_name = Crash Time 2 to most_game_comments/Crash Time 2.csv
# Saved data for app_name = Overlord to most_game_comments/Overlord.csv
# Saved data for app_name = Soldiers: Heroes of World War II to most_game_comments/Soldiers: Heroes of World War II.csv
# Saved data for app_name = Costume Quest to most_game_comments/Costume Quest.csv
# Saved data for app_name = Stacking to most_game_comments/Stacking.csv
# Saved data for app_name = Iron Brigade to most_game_comments/Iron Brigade.csv
# Saved data for app_name = Cossacks II: Napoleonic Wars to most_game_comments/Cossacks II: Napoleonic Wars.csv
# Saved data for app_name = American Conquest to most_game_comments/American Conquest.csv
# Saved data for app_name = American Conquest - Fight Back to most_game_comments/American Conquest - Fight Back.csv
# Saved data for app_name = PROTOTYPE 2 to most_game_comments/PROTOTYPE 2.csv
# Saved data for app_name = Maelstrom to most_game_comments/Maelstrom.csv
# Saved data for app_name = Owlboy to most_game_comments/Owlboy.csv
# Saved data for app_name = Hospital Tycoon to most_game_comments/Hospital Tycoon.csv
# Saved data for app_name = Super Toy Cars to most_game_comments/Super Toy Cars.csv
# Saved data for app_name = Lightfish to most_game_comments/Lightfish.csv
# Saved data for app_name = Lumines to most_game_comments/Lumines.csv
# Saved data for app_name = Lumines: Advanced Pack to most_game_comments/Lumines: Advanced Pack.csv
# Saved data for app_name = Red Orchestra: Ostfront 41-45 to most_game_comments/Red Orchestra: Ostfront 41-45.csv
# Saved data for app_name = Manhunt to most_game_comments/Manhunt.csv
# Saved data for app_name = Max Payne to most_game_comments/Max Payne.csv
# Saved data for app_name = Max Payne 2: The Fall of Max Payne to most_game_comments/Max Payne 2: The Fall of Max Payne.csv
# Saved data for app_name = Grand Theft Auto to most_game_comments/Grand Theft Auto.csv
# Saved data for app_name = Grand Theft Auto 2 to most_game_comments/Grand Theft Auto 2.csv
# Saved data for app_name = Bully: Scholarship Edition to most_game_comments/Bully: Scholarship Edition.csv
# Saved data for app_name = Grand Theft Auto IV: The Complete Edition to most_game_comments/Grand Theft Auto IV: The Complete Edition.csv
# Saved data for app_name = Grand Theft Auto: Episodes from Liberty City to most_game_comments/Grand Theft Auto: Episodes from Liberty City.csv
# Saved data for app_name = Culpa Innata to most_game_comments/Culpa Innata.csv
# Saved data for app_name = Sacred Gold to most_game_comments/Sacred Gold.csv
# Saved data for app_name = DarkStar One to most_game_comments/DarkStar One.csv
# Saved data for app_name = Jack Keane to most_game_comments/Jack Keane.csv
# Saved data for app_name = FlatOut: Ultimate Carnage to most_game_comments/FlatOut: Ultimate Carnage.csv
# Saved data for app_name = Perimeter 2: New Earth to most_game_comments/Perimeter 2: New Earth.csv
# Saved data for app_name = SlamIt Pinball: Big Score to most_game_comments/SlamIt Pinball: Big Score.csv
# Saved data for app_name = Ankh 3: Battle of the Gods to most_game_comments/Ankh 3: Battle of the Gods.csv
# Saved data for app_name = BC Kings to most_game_comments/BC Kings.csv
# Saved data for app_name = Port Royale 2 to most_game_comments/Port Royale 2.csv
# Saved data for app_name = 9th Company - Roots of Terror to most_game_comments/9th Company - Roots of Terror.csv
# Saved data for app_name = Killing Floor to most_game_comments/Killing Floor.csv
# Saved data for app_name = Puzzle Quest to most_game_comments/Puzzle Quest.csv
# Saved data for app_name = 18 Wheels of Steel: American Long Haul to most_game_comments/18 Wheels of Steel: American Long Haul.csv
# Saved data for app_name = Hunting Unlimited 2008 to most_game_comments/Hunting Unlimited 2008.csv
# Saved data for app_name = Ride! Carnival Tycoon to most_game_comments/Ride! Carnival Tycoon.csv
# Saved data for app_name = Hot Dish to most_game_comments/Hot Dish.csv
# Saved data for app_name = Dr. Daisy: Pet Vet to most_game_comments/Dr. Daisy: Pet Vet.csv
# Saved data for app_name = Sprint Cars: Road to Knoxville to most_game_comments/Sprint Cars: Road to Knoxville.csv
# Saved data for app_name = Legend: Hand of God to most_game_comments/Legend: Hand of God.csv
# Saved data for app_name = Drakensang to most_game_comments/Drakensang.csv
# Saved data for app_name = Mission Runway to most_game_comments/Mission Runway.csv
# Saved data for app_name = Hunting Unlimited 2010 to most_game_comments/Hunting Unlimited 2010.csv
# Saved data for app_name = Overlord: Raising Hell to most_game_comments/Overlord: Raising Hell.csv
# Saved data for app_name = GRID to most_game_comments/GRID.csv
# Saved data for app_name = Rise of the Argonauts to most_game_comments/Rise of the Argonauts.csv
# Saved data for app_name = Damnation to most_game_comments/Damnation.csv
# Saved data for app_name = Operation Flashpoint: Dragon Rising to most_game_comments/Operation Flashpoint: Dragon Rising.csv
# Saved data for app_name = Half-Life: Blue Shift to most_game_comments/Half-Life: Blue Shift.csv
# Saved data for app_name = SiN Episodes: Emergence to most_game_comments/SiN Episodes: Emergence.csv
# Saved data for app_name = Ninja Reflex: Steamworks Edition to most_game_comments/Ninja Reflex: Steamworks Edition.csv
# Saved data for app_name = SiN: Gold to most_game_comments/SiN: Gold.csv
# Saved data for app_name = America's Army 3 to most_game_comments/America's Army 3.csv
# Saved data for app_name = Unreal II: The Awakening to most_game_comments/Unreal II: The Awakening.csv
# Saved data for app_name = Unreal Tournament 3: Black Edition to most_game_comments/Unreal Tournament 3: Black Edition.csv
# Saved data for app_name = Unreal Tournament 2004 to most_game_comments/Unreal Tournament 2004.csv
# Saved data for app_name = Unreal Tournament: Game of the Year Edition to most_game_comments/Unreal Tournament: Game of the Year Edition.csv
# Saved data for app_name = Unreal Gold to most_game_comments/Unreal Gold.csv
# Saved data for app_name = Prince of Persia: Warrior Within to most_game_comments/Prince of Persia: Warrior Within.csv
# Saved data for app_name = Far Cry to most_game_comments/Far Cry.csv
# Saved data for app_name = Prince of Persia: The Two Thrones to most_game_comments/Prince of Persia: The Two Thrones.csv
# Saved data for app_name = Tom Clancy's Rainbow Six: Vegas to most_game_comments/Tom Clancy's Rainbow Six: Vegas.csv
# Saved data for app_name = Tom Clancy's Splinter Cell to most_game_comments/Tom Clancy's Splinter Cell.csv
# Saved data for app_name = Tom Clancy's Splinter Cell: Chaos Theory to most_game_comments/Tom Clancy's Splinter Cell: Chaos Theory.csv
# Saved data for app_name = Tom Clancy's Splinter Cell: Double Agent to most_game_comments/Tom Clancy's Splinter Cell: Double Agent.csv
# Saved data for app_name = Prince of Persia: The Sands of Time to most_game_comments/Prince of Persia: The Sands of Time.csv
# Saved data for app_name = Tom Clancy's Ghost Recon: Desert Siege to most_game_comments/Tom Clancy's Ghost Recon: Desert Siege.csv
# Saved data for app_name = Darwinia to most_game_comments/Darwinia.csv
# Saved data for app_name = Tom Clancy's Rainbow Six: Lockdown to most_game_comments/Tom Clancy's Rainbow Six: Lockdown.csv
# Saved data for app_name = Rayman: Raving Rabbids to most_game_comments/Rayman: Raving Rabbids.csv
# Saved data for app_name = Uplink to most_game_comments/Uplink.csv
# Saved data for app_name = Assassin's Creed to most_game_comments/Assassin's Creed.csv
# Saved data for app_name = Tom Clancy's Rainbow Six: Vegas 2 to most_game_comments/Tom Clancy's Rainbow Six: Vegas 2.csv
# Saved data for app_name = Beyond Good & Evil to most_game_comments/Beyond Good & Evil.csv
# Saved data for app_name = Petz Horsez 2 to most_game_comments/Petz Horsez 2.csv
# Saved data for app_name = Heroes of Might & Magic V to most_game_comments/Heroes of Might & Magic V.csv
# Saved data for app_name = Brothers in Arms: Road to Hill 30 to most_game_comments/Brothers in Arms: Road to Hill 30.csv
# Saved data for app_name = DEFCON to most_game_comments/DEFCON.csv
# Saved data for app_name = Silent Hunter: Wolves of the Pacific to most_game_comments/Silent Hunter: Wolves of the Pacific.csv
# Saved data for app_name = Silent Hunter III to most_game_comments/Silent Hunter III.csv
# Saved data for app_name = Silent Hunter: Wolves of the Pacific U-Boat Missions to most_game_comments/Silent Hunter: Wolves of the Pacific U-Boat Missions.csv
# Saved data for app_name = Cold Fear to most_game_comments/Cold Fear.csv
# Saved data for app_name = Multiwinia to most_game_comments/Multiwinia.csv
# Saved data for app_name = Tom Clancy's Ghost Recon to most_game_comments/Tom Clancy's Ghost Recon.csv
# Saved data for app_name = The Settlers: Heritage of Kings to most_game_comments/The Settlers: Heritage of Kings.csv
# Saved data for app_name = IL-2 Sturmovik: 1946 to most_game_comments/IL-2 Sturmovik: 1946.csv
# Saved data for app_name = Heroes of Might & Magic V: Tribes of the East to most_game_comments/Heroes of Might & Magic V: Tribes of the East.csv
# Saved data for app_name = Heroes of Might & Magic V: Hammers of Fate to most_game_comments/Heroes of Might & Magic V: Hammers of Fate.csv
# Saved data for app_name = Brothers in Arms: Hell's Highway to most_game_comments/Brothers in Arms: Hell's Highway.csv
# Saved data for app_name = Harvest: Massive Encounter to most_game_comments/Harvest: Massive Encounter.csv
# Saved data for app_name = The Wonderful End of the World to most_game_comments/The Wonderful End of the World.csv
# Saved data for app_name = AaAaAA!!! - A Reckless Disregard for Gravity to most_game_comments/AaAaAA!!! - A Reckless Disregard for Gravity.csv
# Saved data for app_name = AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome to most_game_comments/AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome.csv
# Saved data for app_name = Warhammer 40,000: Dawn of War II to most_game_comments/Warhammer 40,000: Dawn of War II.csv
# Saved data for app_name = Oddworld: Abe's Oddysee to most_game_comments/Oddworld: Abe's Oddysee.csv
# Saved data for app_name = Oddworld: Abe's Exoddus to most_game_comments/Oddworld: Abe's Exoddus.csv
# Saved data for app_name = Oddworld: Munch's Oddysee to most_game_comments/Oddworld: Munch's Oddysee.csv
# Saved data for app_name = Oddworld: Stranger's Wrath HD to most_game_comments/Oddworld: Stranger's Wrath HD.csv
# Saved data for app_name = Planet Busters to most_game_comments/Planet Busters.csv
# Saved data for app_name = 7 Wonders II to most_game_comments/7 Wonders II.csv
# Saved data for app_name = Luxor: Amun Rising to most_game_comments/Luxor: Amun Rising.csv
# Saved data for app_name = Luxor 2 to most_game_comments/Luxor 2.csv
# Saved data for app_name = Luxor 3 to most_game_comments/Luxor 3.csv
# Saved data for app_name = Little Farm to most_game_comments/Little Farm.csv
# Saved data for app_name = Luxor to most_game_comments/Luxor.csv
# Saved data for app_name = Dangerous Waters to most_game_comments/Dangerous Waters.csv
# Saved data for app_name = Discovery! A Seek & Find Adventure to most_game_comments/Discovery! A Seek & Find Adventure.csv
# Saved data for app_name = Samantha Swift and the Hidden Roses of Athena to most_game_comments/Samantha Swift and the Hidden Roses of Athena.csv
# Saved data for app_name = 7 Wonders: The Treasures of Seven to most_game_comments/7 Wonders: The Treasures of Seven.csv
# Saved data for app_name = Luxor: Quest for the Afterlife to most_game_comments/Luxor: Quest for the Afterlife.csv
# Saved data for app_name = Samantha Swift and the Golden Touch to most_game_comments/Samantha Swift and the Golden Touch.csv
# Saved data for app_name = Space Empires IV Deluxe to most_game_comments/Space Empires IV Deluxe.csv
# Saved data for app_name = Virtual Villagers: A New Home to most_game_comments/Virtual Villagers: A New Home.csv
# Saved data for app_name = Virtual Villagers 2: The Lost Children to most_game_comments/Virtual Villagers 2: The Lost Children.csv
# Saved data for app_name = Plant Tycoon to most_game_comments/Plant Tycoon.csv
# Saved data for app_name = Fish Tycoon to most_game_comments/Fish Tycoon.csv
# Saved data for app_name = Virtual Villagers 3: The Secret City to most_game_comments/Virtual Villagers 3: The Secret City.csv
# Saved data for app_name = Virtual Families to most_game_comments/Virtual Families.csv
# Saved data for app_name = Disciples II: Rise of the Elves to most_game_comments/Disciples II: Rise of the Elves.csv
# Saved data for app_name = Everyday Shooter to most_game_comments/Everyday Shooter.csv
# Saved data for app_name = Disciples II: Gallean's Return to most_game_comments/Disciples II: Gallean's Return.csv
# Saved data for app_name = F.E.A.R. 2: Project Origin to most_game_comments/F.E.A.R. 2: Project Origin.csv
# Saved data for app_name = Chaos Theory to most_game_comments/Chaos Theory.csv
# Saved data for app_name = Trials 2: Second Edition to most_game_comments/Trials 2: Second Edition.csv
# Saved data for app_name = Monster Trucks Nitro to most_game_comments/Monster Trucks Nitro.csv
# Saved data for app_name = Insecticide Part 1 to most_game_comments/Insecticide Part 1.csv
# Saved data for app_name = Velvet Assassin to most_game_comments/Velvet Assassin.csv
# Saved data for app_name = Legendary to most_game_comments/Legendary.csv
# Saved data for app_name = Sid Meier's Civilization IV: Colonization to most_game_comments/Sid Meier's Civilization IV: Colonization.csv
# Saved data for app_name = Space Empires V to most_game_comments/Space Empires V.csv
# Saved data for app_name = Arx Fatalis to most_game_comments/Arx Fatalis.csv
# Saved data for app_name = Tribes: Ascend to most_game_comments/Tribes: Ascend.csv
# Saved data for app_name = Children of the Nile to most_game_comments/Children of the Nile.csv
# Saved data for app_name = Children of the Nile: Alexandria to most_game_comments/Children of the Nile: Alexandria.csv
# Saved data for app_name = Hinterland to most_game_comments/Hinterland.csv
# Saved data for app_name = Mosby's Confederacy to most_game_comments/Mosby's Confederacy.csv
# Saved data for app_name = Crysis Warhead to most_game_comments/Crysis Warhead.csv
# Saved data for app_name = Mirror's Edge to most_game_comments/Mirror's Edge.csv
# Saved data for app_name = Spore: Creepy & Cute Parts Pack to most_game_comments/Spore: Creepy & Cute Parts Pack.csv
# Saved data for app_name = Dragon Age: Origins to most_game_comments/Dragon Age: Origins.csv
# Saved data for app_name = Mass Effect (2007) to most_game_comments/Mass Effect (2007).csv
# Saved data for app_name = Dead Space to most_game_comments/Dead Space.csv
# Saved data for app_name = Command and Conquer: Red Alert 3 to most_game_comments/Command and Conquer: Red Alert 3.csv
# Saved data for app_name = Pirates, Vikings, & Knights II to most_game_comments/Pirates, Vikings, & Knights II.csv
# Saved data for app_name = Dystopia to most_game_comments/Dystopia.csv
# Saved data for app_name = Nuclear Dawn to most_game_comments/Nuclear Dawn.csv
# Saved data for app_name = Empires to most_game_comments/Empires.csv
# Saved data for app_name = On the Rain-Slick Precipice of Darkness, Episode One to most_game_comments/On the Rain-Slick Precipice of Darkness, Episode One.csv
# Saved data for app_name = On the Rain-Slick Precipice of Darkness, Episode Two to most_game_comments/On the Rain-Slick Precipice of Darkness, Episode Two.csv
# Saved data for app_name = DeathSpank to most_game_comments/DeathSpank.csv
# Saved data for app_name = DeathSpank: Thongs Of Virtue to most_game_comments/DeathSpank: Thongs Of Virtue.csv
# Saved data for app_name = The Baconing to most_game_comments/The Baconing.csv
# Saved data for app_name = Unstoppable Gorg to most_game_comments/Unstoppable Gorg.csv
# Saved data for app_name = Source Filmmaker to most_game_comments/Source Filmmaker.csv
# Saved data for app_name = Crazy Machines 2 to most_game_comments/Crazy Machines 2.csv
# Saved data for app_name = Crazy Machines to most_game_comments/Crazy Machines.csv
# Saved data for app_name = Helldorado to most_game_comments/Helldorado.csv
# Saved data for app_name = Mata Hari to most_game_comments/Mata Hari.csv
# Saved data for app_name = Defense Grid: The Awakening to most_game_comments/Defense Grid: The Awakening.csv
# Saved data for app_name = Mayhem Intergalactic to most_game_comments/Mayhem Intergalactic.csv
# Saved data for app_name = And Yet It Moves to most_game_comments/And Yet It Moves.csv
# Saved data for app_name = Zero Gear to most_game_comments/Zero Gear.csv
# Saved data for app_name = Earth 2160 to most_game_comments/Earth 2160.csv
# Saved data for app_name = Silent Hill: Homecoming to most_game_comments/Silent Hill: Homecoming.csv
# Saved data for app_name = Puzzle Chronicles to most_game_comments/Puzzle Chronicles.csv
# Saved data for app_name = Tank Universal to most_game_comments/Tank Universal.csv
# Saved data for app_name = Two Worlds: Epic Edition to most_game_comments/Two Worlds: Epic Edition.csv
# Saved data for app_name = Space Ark to most_game_comments/Space Ark.csv
# Saved data for app_name = Eternity's Child to most_game_comments/Eternity's Child.csv
# Saved data for app_name = Alice: Madness Returns to most_game_comments/Alice: Madness Returns.csv
# Saved data for app_name = Brothers in Arms: Earned in Blood to most_game_comments/Brothers in Arms: Earned in Blood.csv
# Saved data for app_name = Tom Clancy's Rainbow Six 3: Gold Edition to most_game_comments/Tom Clancy's Rainbow Six 3: Gold Edition.csv
# Saved data for app_name = Far Cry 2 to most_game_comments/Far Cry 2.csv
# Saved data for app_name = The Settlers: Rise of an Empire Gold Edition   to most_game_comments/The Settlers: Rise of an Empire Gold Edition  .csv
# Saved data for app_name = Prince of Persia to most_game_comments/Prince of Persia.csv
# Saved data for app_name = Team Fortress Classic to most_game_comments/Team Fortress Classic.csv
# Saved data for app_name = Quantum Conundrum to most_game_comments/Quantum Conundrum.csv
# Saved data for app_name = Global Ops: Commando Libya to most_game_comments/Global Ops: Commando Libya.csv
# Saved data for app_name = Naval War: Arctic Circle to most_game_comments/Naval War: Arctic Circle.csv
# Saved data for app_name = Nancy Drew: Shadow at the Water's Edge to most_game_comments/Nancy Drew: Shadow at the Water's Edge.csv
# Saved data for app_name = Puzzler World 2 to most_game_comments/Puzzler World 2.csv
# Saved data for app_name = Worms Revolution to most_game_comments/Worms Revolution.csv
# Saved data for app_name = Sideway to most_game_comments/Sideway.csv
# Saved data for app_name = Realm of the Mad God Exalt to most_game_comments/Realm of the Mad God Exalt.csv
# Saved data for app_name = Off-Road Drive to most_game_comments/Off-Road Drive.csv
# Saved data for app_name = Batman: Arkham City GOTY to most_game_comments/Batman: Arkham City GOTY.csv
# Saved data for app_name = A Game of Dwarves to most_game_comments/A Game of Dwarves.csv
# Saved data for app_name = Oil Rush to most_game_comments/Oil Rush.csv
# Saved data for app_name = SOL: Exodus to most_game_comments/SOL: Exodus.csv
# Saved data for app_name = Memento Mori to most_game_comments/Memento Mori.csv
# Saved data for app_name = XCOM: Enemy Unknown to most_game_comments/XCOM: Enemy Unknown.csv
# Saved data for app_name = Dungeons - The Dark Lord to most_game_comments/Dungeons - The Dark Lord.csv
# Saved data for app_name = Gettysburg: Armored Warfare to most_game_comments/Gettysburg: Armored Warfare.csv
# Saved data for app_name = Disciples III: Resurrection to most_game_comments/Disciples III: Resurrection.csv
# Saved data for app_name = Torchlight II to most_game_comments/Torchlight II.csv
# Saved data for app_name = Cave Story+ to most_game_comments/Cave Story+.csv
# Saved data for app_name = Before the Echo to most_game_comments/Before the Echo.csv
# Saved data for app_name = Sonic CD to most_game_comments/Sonic CD.csv
# Saved data for app_name = Geneforge 1 to most_game_comments/Geneforge 1.csv
# Saved data for app_name = Geneforge 3 to most_game_comments/Geneforge 3.csv
# Saved data for app_name = Geneforge 4 to most_game_comments/Geneforge 4.csv
# Saved data for app_name = Geneforge 5 to most_game_comments/Geneforge 5.csv
# Saved data for app_name = Galcon Legends to most_game_comments/Galcon Legends.csv
# Saved data for app_name = Revelations 2012 to most_game_comments/Revelations 2012.csv
# Saved data for app_name = Pox Nora to most_game_comments/Pox Nora.csv
# Saved data for app_name = EverQuest II to most_game_comments/EverQuest II.csv
# Saved data for app_name = Sins of a Solar Empire: Trinity to most_game_comments/Sins of a Solar Empire: Trinity.csv
# Saved data for app_name = Toki Tori 2+ to most_game_comments/Toki Tori 2+.csv
# Saved data for app_name = Serious Sam: The Random Encounter to most_game_comments/Serious Sam: The Random Encounter.csv
# Saved data for app_name = Airline Tycoon 2 to most_game_comments/Airline Tycoon 2.csv
# Saved data for app_name = Flatout 3 to most_game_comments/Flatout 3.csv
# Saved data for app_name = Really Big Sky to most_game_comments/Really Big Sky.csv
# Saved data for app_name = DiRT Showdown to most_game_comments/DiRT Showdown.csv
# Saved data for app_name = Orcs Must Die! 2 to most_game_comments/Orcs Must Die! 2.csv
# Saved data for app_name = Wolfenstein: The New Order to most_game_comments/Wolfenstein: The New Order.csv
# Saved data for app_name = Jurassic Park: The Game to most_game_comments/Jurassic Park: The Game.csv
# Saved data for app_name = Assassin's Creed Revelations to most_game_comments/Assassin's Creed Revelations.csv
# Saved data for app_name = Galactic Bowling to most_game_comments/Galactic Bowling.csv
# Saved data for app_name = Choplifter HD to most_game_comments/Choplifter HD.csv
# Saved data for app_name = Impire to most_game_comments/Impire.csv
# Saved data for app_name = Sleeping Dogs™ to most_game_comments/Sleeping Dogs™.csv
# Saved data for app_name = Galactic Civilizations II: Ultimate Edition to most_game_comments/Galactic Civilizations II: Ultimate Edition.csv
# Saved data for app_name = Leviathan: Warships to most_game_comments/Leviathan: Warships.csv
# Saved data for app_name = Ridge Racer™ Unbounded to most_game_comments/Ridge Racer™ Unbounded.csv
# Saved data for app_name = Scarygirl to most_game_comments/Scarygirl.csv
# Saved data for app_name = Scoregasm to most_game_comments/Scoregasm.csv
# Saved data for app_name = SONIC THE HEDGEHOG 4 Episode I to most_game_comments/SONIC THE HEDGEHOG 4 Episode I.csv
# Saved data for app_name = Nancy Drew: Alibi in Ashes to most_game_comments/Nancy Drew: Alibi in Ashes.csv
# Saved data for app_name = Hegemony Gold: Wars of Ancient Greece to most_game_comments/Hegemony Gold: Wars of Ancient Greece.csv
# Saved data for app_name = Demigod to most_game_comments/Demigod.csv
# Saved data for app_name = Dynamite Jack to most_game_comments/Dynamite Jack.csv
# Saved data for app_name = Alan Wake's American Nightmare to most_game_comments/Alan Wake's American Nightmare.csv
# Saved data for app_name = Real Warfare 2: Northern Crusades to most_game_comments/Real Warfare 2: Northern Crusades.csv
# Saved data for app_name = Call of Duty: Black Ops II to most_game_comments/Call of Duty: Black Ops II.csv
# Saved data for app_name = Call of Duty: Black Ops II - Multiplayer to most_game_comments/Call of Duty: Black Ops II - Multiplayer.csv
# Saved data for app_name = Hitman: Absolution to most_game_comments/Hitman: Absolution.csv
# Saved data for app_name = Tomb Raider to most_game_comments/Tomb Raider.csv
# Saved data for app_name = Titan Attacks to most_game_comments/Titan Attacks.csv
# Saved data for app_name = America's Army: Proving Grounds to most_game_comments/America's Army: Proving Grounds.csv
# Saved data for app_name = King's Bounty: Warriors of the North to most_game_comments/King's Bounty: Warriors of the North.csv
# Saved data for app_name = Fortune Summoners: Secret of the Elemental Stone to most_game_comments/Fortune Summoners: Secret of the Elemental Stone.csv
# Saved data for app_name = Containment: The Zombie Puzzler to most_game_comments/Containment: The Zombie Puzzler.csv
# Saved data for app_name = SONIC THE HEDGEHOG 4 Episode II to most_game_comments/SONIC THE HEDGEHOG 4 Episode II.csv
# Saved data for app_name = F1 Race Stars to most_game_comments/F1 Race Stars.csv
# Saved data for app_name = Binary Domain to most_game_comments/Binary Domain.csv
# Saved data for app_name = Crusader Kings II to most_game_comments/Crusader Kings II.csv
# Saved data for app_name = Dear Esther to most_game_comments/Dear Esther.csv
# Saved data for app_name = The Dark Eye: Chains of Satinav to most_game_comments/The Dark Eye: Chains of Satinav.csv
# Saved data for app_name = SATAZIUS to most_game_comments/SATAZIUS.csv
# Saved data for app_name = Fable - The Lost Chapters to most_game_comments/Fable - The Lost Chapters.csv
# Saved data for app_name = Superbrothers: Sword & Sworcery EP to most_game_comments/Superbrothers: Sword & Sworcery EP.csv
# Saved data for app_name = The Showdown Effect to most_game_comments/The Showdown Effect.csv
# Saved data for app_name = Max Payne 3 to most_game_comments/Max Payne 3.csv
# Saved data for app_name = LEGO® Harry Potter: Years 5-7 to most_game_comments/LEGO® Harry Potter: Years 5-7.csv
# Saved data for app_name = Waveform to most_game_comments/Waveform.csv
# Saved data for app_name = Snapshot to most_game_comments/Snapshot.csv
# Saved data for app_name = The Bridge to most_game_comments/The Bridge.csv
# Saved data for app_name = Awesomenauts to most_game_comments/Awesomenauts.csv
# Saved data for app_name = Serious Sam 2 to most_game_comments/Serious Sam 2.csv
# Saved data for app_name = Castle Crashers to most_game_comments/Castle Crashers.csv
# Saved data for app_name = Pineapple Smash Crew  to most_game_comments/Pineapple Smash Crew .csv
# Saved data for app_name = Pickers to most_game_comments/Pickers.csv
# Saved data for app_name = Call of Juarez Gunslinger to most_game_comments/Call of Juarez Gunslinger.csv
# Saved data for app_name = Infested Planet to most_game_comments/Infested Planet.csv
# Saved data for app_name = Confrontation to most_game_comments/Confrontation.csv
# Saved data for app_name = Rotastic to most_game_comments/Rotastic.csv
# Skipping value containing Retro: Retro City Rampage™ DX
# Saved data for app_name = Deep Black : Reloaded to most_game_comments/Deep Black : Reloaded.csv
# Saved data for app_name = Babel Rising to most_game_comments/Babel Rising.csv
# Saved data for app_name = Men of War: Condemned Heroes to most_game_comments/Men of War: Condemned Heroes.csv
# Saved data for app_name = Sins of a Solar Empire: Rebellion to most_game_comments/Sins of a Solar Empire: Rebellion.csv
# Saved data for app_name = Crusader Kings Complete to most_game_comments/Crusader Kings Complete.csv
# Saved data for app_name = Red Faction: Guerrilla Steam Edition to most_game_comments/Red Faction: Guerrilla Steam Edition.csv
# Saved data for app_name = Lumino City to most_game_comments/Lumino City.csv
# Saved data for app_name = BIT.TRIP CORE to most_game_comments/BIT.TRIP CORE.csv
# Saved data for app_name = BIT.TRIP VOID to most_game_comments/BIT.TRIP VOID.csv
# Saved data for app_name = BIT.TRIP FATE to most_game_comments/BIT.TRIP FATE.csv
# Saved data for app_name = S.T.A.L.K.E.R.: Clear Sky to most_game_comments/S.T.A.L.K.E.R.: Clear Sky.csv
# Saved data for app_name = Dishonored to most_game_comments/Dishonored.csv
# Saved data for app_name = Hell Yeah! to most_game_comments/Hell Yeah!.csv
# Saved data for app_name = 3DMark 11 to most_game_comments/3DMark 11.csv
# Saved data for app_name = Company of Heroes: Tales of Valor to most_game_comments/Company of Heroes: Tales of Valor.csv
# Saved data for app_name = Foreign Legion: Multi Massacre to most_game_comments/Foreign Legion: Multi Massacre.csv
# Saved data for app_name = The Testament of Sherlock Holmes to most_game_comments/The Testament of Sherlock Holmes.csv
# Saved data for app_name = 1000 Amps to most_game_comments/1000 Amps.csv
# Saved data for app_name = Warhammer 40,000: Dawn of War II - Chaos Rising to most_game_comments/Warhammer 40,000: Dawn of War II - Chaos Rising.csv
# Saved data for app_name = EverQuest Free-to-Play to most_game_comments/EverQuest Free-to-Play.csv
# Saved data for app_name = Insanely Twisted Shadow Planet to most_game_comments/Insanely Twisted Shadow Planet.csv
# Saved data for app_name = Jagged Alliance: Crossfire to most_game_comments/Jagged Alliance: Crossfire.csv
# Saved data for app_name = Luxor Evolved to most_game_comments/Luxor Evolved.csv
# Saved data for app_name = Yesterday to most_game_comments/Yesterday.csv
# Saved data for app_name = Auditorium to most_game_comments/Auditorium.csv
# Saved data for app_name = Chronicle: RuneScape Legends to most_game_comments/Chronicle: RuneScape Legends.csv
# Saved data for app_name = Jet Set Radio to most_game_comments/Jet Set Radio.csv
# Saved data for app_name = Warlock 2: the Exiled to most_game_comments/Warlock 2: the Exiled.csv
# Saved data for app_name = Avernum 4 to most_game_comments/Avernum 4.csv
# Saved data for app_name = Avernum 5 to most_game_comments/Avernum 5.csv
# Saved data for app_name = Avernum 6 to most_game_comments/Avernum 6.csv
# Saved data for app_name = Gunpoint to most_game_comments/Gunpoint.csv
# Saved data for app_name = Clan of Champions to most_game_comments/Clan of Champions.csv
# Saved data for app_name = ClaDun x2 to most_game_comments/ClaDun x2.csv
# Saved data for app_name = Tales from Space: Mutant Blobs Attack to most_game_comments/Tales from Space: Mutant Blobs Attack.csv
# Saved data for app_name = Crazy Machines Elements to most_game_comments/Crazy Machines Elements.csv
# Saved data for app_name = Saints Row IV to most_game_comments/Saints Row IV.csv
# Saved data for app_name = To the Moon to most_game_comments/To the Moon.csv
# Saved data for app_name = Dungeons & Dragons Online® to most_game_comments/Dungeons & Dragons Online®.csv
# Saved data for app_name = AirMech Strike to most_game_comments/AirMech Strike.csv
# Saved data for app_name = 3SwitcheD to most_game_comments/3SwitcheD.csv
# Saved data for app_name = iBomber Defense Pacific to most_game_comments/iBomber Defense Pacific.csv
# Saved data for app_name = Painkiller: Recurring Evil to most_game_comments/Painkiller: Recurring Evil.csv
# Saved data for app_name = Starscape to most_game_comments/Starscape.csv
# Saved data for app_name = Alien Spidy to most_game_comments/Alien Spidy.csv
# Saved data for app_name = Bang Bang Racing to most_game_comments/Bang Bang Racing.csv
# Saved data for app_name = Sine Mora to most_game_comments/Sine Mora.csv
# Saved data for app_name = Indie Game: The Movie to most_game_comments/Indie Game: The Movie.csv
# Saved data for app_name = Mr. Robot to most_game_comments/Mr. Robot.csv
# Saved data for app_name = SpeedRunners to most_game_comments/SpeedRunners.csv
# Saved data for app_name = Stellar Impact to most_game_comments/Stellar Impact.csv
# Saved data for app_name = Legend of Grimrock to most_game_comments/Legend of Grimrock.csv
# Saved data for app_name = Fireburst to most_game_comments/Fireburst.csv
# Saved data for app_name = Tony Hawk's Pro Skater HD to most_game_comments/Tony Hawk's Pro Skater HD.csv
# Saved data for app_name = Archeblade to most_game_comments/Archeblade.csv
# Saved data for app_name = Cubemen to most_game_comments/Cubemen.csv
# Saved data for app_name = Ys: The Oath in Felghana to most_game_comments/Ys: The Oath in Felghana.csv
# Saved data for app_name = Ys Origin to most_game_comments/Ys Origin.csv
# Saved data for app_name = eXceed - Gun Bullet Children to most_game_comments/eXceed - Gun Bullet Children.csv
# Saved data for app_name = eXceed 2nd - Vampire REX to most_game_comments/eXceed 2nd - Vampire REX.csv
# Saved data for app_name = eXceed 3rd - Jade Penetrate Black Package to most_game_comments/eXceed 3rd - Jade Penetrate Black Package.csv
# Saved data for app_name = Wizorb to most_game_comments/Wizorb.csv
# Saved data for app_name = Hack, Slash, Loot to most_game_comments/Hack, Slash, Loot.csv
# Saved data for app_name = Rayman Origins to most_game_comments/Rayman Origins.csv
# Saved data for app_name = Noitu Love 2 Devolution to most_game_comments/Noitu Love 2 Devolution.csv
# Saved data for app_name = English Country Tune to most_game_comments/English Country Tune.csv
# Saved data for app_name = A Virus Named TOM to most_game_comments/A Virus Named TOM.csv
# Saved data for app_name = AVSEQ to most_game_comments/AVSEQ.csv
# Saved data for app_name = Botanicula to most_game_comments/Botanicula.csv
# Saved data for app_name = Bumbledore to most_game_comments/Bumbledore.csv
# Saved data for app_name = Arena Wars 2 to most_game_comments/Arena Wars 2.csv
# Saved data for app_name = Symphony to most_game_comments/Symphony.csv
# Saved data for app_name = Jane's Advanced Strike Fighters to most_game_comments/Jane's Advanced Strike Fighters.csv
# Saved data for app_name = Sacred Citadel to most_game_comments/Sacred Citadel.csv
# Saved data for app_name = Moon Breakers to most_game_comments/Moon Breakers.csv
# Saved data for app_name = Myst V to most_game_comments/Myst V.csv
# Saved data for app_name = ENDLESS™ Space - Definitive Edition to most_game_comments/ENDLESS™ Space - Definitive Edition.csv
# Saved data for app_name = Shatter to most_game_comments/Shatter.csv
# Saved data for app_name = DOOM 3: BFG Edition to most_game_comments/DOOM 3: BFG Edition.csv
# Saved data for app_name = Avernum: Escape From the Pit to most_game_comments/Avernum: Escape From the Pit.csv
# Saved data for app_name = Tryst to most_game_comments/Tryst.csv
# Saved data for app_name = Assassin's Creed® III to most_game_comments/Assassin's Creed® III.csv
# Saved data for app_name = F1 2012 to most_game_comments/F1 2012.csv
# Saved data for app_name = Omerta - City of Gangsters to most_game_comments/Omerta - City of Gangsters.csv
# Saved data for app_name = STAR WARS™ Knights of the Old Republic™ II: The Sith Lords™ to most_game_comments/STAR WARS™ Knights of the Old Republic™ II: The Sith Lords™.csv
# Saved data for app_name = Lunar Flight to most_game_comments/Lunar Flight.csv
# Saved data for app_name = Midnight Mysteries: Salem Witch Trials to most_game_comments/Midnight Mysteries: Salem Witch Trials.csv
# Saved data for app_name = Midnight Mysteries 3: Devil on the Mississippi to most_game_comments/Midnight Mysteries 3: Devil on the Mississippi.csv
# Saved data for app_name = Midnight Mysteries 4: Haunted Houdini to most_game_comments/Midnight Mysteries 4: Haunted Houdini.csv
# Saved data for app_name = Batman™: Arkham Knight to most_game_comments/Batman™: Arkham Knight.csv
# Saved data for app_name = Blades of Time to most_game_comments/Blades of Time.csv
# Saved data for app_name = Colour Bind to most_game_comments/Colour Bind.csv
# Saved data for app_name = Game of Thrones  to most_game_comments/Game of Thrones .csv
# Saved data for app_name = Apotheon to most_game_comments/Apotheon.csv
# Saved data for app_name = The Witcher: Enhanced Edition to most_game_comments/The Witcher: Enhanced Edition.csv
# Saved data for app_name = Batman™: Arkham Origins to most_game_comments/Batman™: Arkham Origins.csv
# Saved data for app_name = Drunken Robot Pornography to most_game_comments/Drunken Robot Pornography.csv
# Saved data for app_name = Guns of Icarus Online to most_game_comments/Guns of Icarus Online.csv
# Saved data for app_name = Resident Evil: Operation Raccoon City to most_game_comments/Resident Evil: Operation Raccoon City.csv
# Saved data for app_name = Street Fighter X Tekken to most_game_comments/Street Fighter X Tekken.csv
# Saved data for app_name = Call of Duty: Ghosts to most_game_comments/Call of Duty: Ghosts.csv
# Saved data for app_name = Stealth Bastard Deluxe to most_game_comments/Stealth Bastard Deluxe.csv
# Saved data for app_name = The Witcher 2: Assassins of Kings Enhanced Edition to most_game_comments/The Witcher 2: Assassins of Kings Enhanced Edition.csv
# Saved data for app_name = Sherlock Holmes and The Hound of The Baskervilles to most_game_comments/Sherlock Holmes and The Hound of The Baskervilles.csv
# Saved data for app_name = Hero Academy to most_game_comments/Hero Academy.csv
# Saved data for app_name = A Valley Without Wind to most_game_comments/A Valley Without Wind.csv
# Saved data for app_name = AZMD! Scorepocalypse  to most_game_comments/AZMD! Scorepocalypse .csv
# Saved data for app_name = Analogue: A Hate Story to most_game_comments/Analogue: A Hate Story.csv
# Saved data for app_name = Dungeonbowl Knockout Edition to most_game_comments/Dungeonbowl Knockout Edition.csv
# Saved data for app_name = Mini Motor Racing EVO to most_game_comments/Mini Motor Racing EVO.csv
# Saved data for app_name = Strike Suit Zero to most_game_comments/Strike Suit Zero.csv
# Saved data for app_name = Roller Coaster Rampage to most_game_comments/Roller Coaster Rampage.csv
# Saved data for app_name = Magrunner: Dark Pulse to most_game_comments/Magrunner: Dark Pulse.csv
# Saved data for app_name = Call of Duty: Advanced Warfare to most_game_comments/Call of Duty: Advanced Warfare.csv
# Saved data for app_name = Cortex Command to most_game_comments/Cortex Command.csv
# Saved data for app_name = Fieldrunners to most_game_comments/Fieldrunners.csv
# Saved data for app_name = RAW - Realms of Ancient War to most_game_comments/RAW - Realms of Ancient War.csv
# Saved data for app_name = Cannon Fodder 3 to most_game_comments/Cannon Fodder 3.csv
# Saved data for app_name = Splice to most_game_comments/Splice.csv
# Saved data for app_name = Lone Survivor: The Director's Cut to most_game_comments/Lone Survivor: The Director's Cut.csv
# Saved data for app_name = Highborn to most_game_comments/Highborn.csv
# Saved data for app_name = Blacklight: Retribution to most_game_comments/Blacklight: Retribution.csv
# Saved data for app_name = Triple Town to most_game_comments/Triple Town.csv
# Saved data for app_name = Dark Messiah of Might & Magic Single Player to most_game_comments/Dark Messiah of Might & Magic Single Player.csv
# Saved data for app_name = Watchmen: The End Is Nigh to most_game_comments/Watchmen: The End Is Nigh.csv
# Saved data for app_name = Spirits to most_game_comments/Spirits.csv
# Saved data for app_name = Nancy Drew: Tomb of the Lost Queen to most_game_comments/Nancy Drew: Tomb of the Lost Queen.csv
# Saved data for app_name = Fray to most_game_comments/Fray.csv
# Saved data for app_name = Angry Birds Space to most_game_comments/Angry Birds Space.csv
# Saved data for app_name = Sanctum 2 to most_game_comments/Sanctum 2.csv
# Saved data for app_name = F.E.A.R. to most_game_comments/F.E.A.R..csv
# Saved data for app_name = Rune Classic to most_game_comments/Rune Classic.csv
# Saved data for app_name = The Witness to most_game_comments/The Witness.csv
# Saved data for app_name = F.E.A.R. 3 to most_game_comments/F.E.A.R. 3.csv
# Saved data for app_name = Alien Shooter 2 Conscription to most_game_comments/Alien Shooter 2 Conscription.csv
# Saved data for app_name = Battle vs Chess to most_game_comments/Battle vs Chess.csv
# Saved data for app_name = Check vs. Mate to most_game_comments/Check vs. Mate.csv
# Saved data for app_name = Viking: Battle for Asgard to most_game_comments/Viking: Battle for Asgard.csv
# Saved data for app_name = Unmechanical to most_game_comments/Unmechanical.csv
# Saved data for app_name = They Bleed Pixels to most_game_comments/They Bleed Pixels.csv
# Saved data for app_name = Primal Fears to most_game_comments/Primal Fears.csv
# Saved data for app_name = LEGO® Harry Potter: Years 1-4 to most_game_comments/LEGO® Harry Potter: Years 1-4.csv
# Saved data for app_name = Magical Diary: Horse Hall to most_game_comments/Magical Diary: Horse Hall.csv
# Saved data for app_name = Offspring Fling! to most_game_comments/Offspring Fling!.csv
# Saved data for app_name = Deadlight to most_game_comments/Deadlight.csv
# ...
# Saved data for app_name = Duskers to most_game_comments/Duskers.csv
# Saved data for app_name = Pool Nation to most_game_comments/Pool Nation.csv
# Saved data for app_name = Obscure to most_game_comments/Obscure.csv
# Saved data for app_name = Obscure 2 to most_game_comments/Obscure 2.csv
# Saved data for app_name = Theme Park Studio to most_game_comments/Theme Park Studio.csv
# Saved data for app_name = Resident Evil 4 to most_game_comments/Resident Evil 4.csv
# Saved data for app_name = Ground Control Anthology to most_game_comments/Ground Control Anthology.csv
# Saved data for app_name = Ground Control II to most_game_comments/Ground Control II.csv
# Saved data for app_name = Lords of the Realm III to most_game_comments/Lords of the Realm III.csv
# Saved data for app_name = MoonBase Commander to most_game_comments/MoonBase Commander.csv
# Saved data for app_name = Lords of the Realm to most_game_comments/Lords of the Realm.csv
# Saved data for app_name = Silent Storm to most_game_comments/Silent Storm.csv
# Saved data for app_name = Cricket Revolution to most_game_comments/Cricket Revolution.csv
# Saved data for app_name = Abyss Odyssey to most_game_comments/Abyss Odyssey.csv
# Saved data for app_name = Pro Cycling Manager 2014 to most_game_comments/Pro Cycling Manager 2014.csv
# Saved data for app_name = 1954 Alcatraz to most_game_comments/1954 Alcatraz.csv
# Saved data for app_name = Journey of a Roach to most_game_comments/Journey of a Roach.csv
# Saved data for app_name = Edna & Harvey: The Breakout to most_game_comments/Edna & Harvey: The Breakout.csv
# Saved data for app_name = Escape Goat 2 to most_game_comments/Escape Goat 2.csv
# Saved data for app_name = KickBeat Steam Edition to most_game_comments/KickBeat Steam Edition.csv
# Saved data for app_name = Max: The Curse of Brotherhood to most_game_comments/Max: The Curse of Brotherhood.csv
# Saved data for app_name = Viscera Cleanup Detail: Shadow Warrior to most_game_comments/Viscera Cleanup Detail: Shadow Warrior.csv
# Saved data for app_name = Cities: Skylines to most_game_comments/Cities: Skylines.csv
# Saved data for app_name = PixelJunk™ Shooter to most_game_comments/PixelJunk™ Shooter.csv
# Saved data for app_name = The 7th Guest to most_game_comments/The 7th Guest.csv
# Saved data for app_name = The 11th Hour to most_game_comments/The 11th Hour.csv
# Saved data for app_name = Bad Mojo Redux to most_game_comments/Bad Mojo Redux.csv
# Saved data for app_name = Eschalon: Book 1 to most_game_comments/Eschalon: Book 1.csv
# Saved data for app_name = Jagged Alliance Flashback to most_game_comments/Jagged Alliance Flashback.csv
# Saved data for app_name = Shadows: Heretic Kingdoms to most_game_comments/Shadows: Heretic Kingdoms.csv
# Saved data for app_name = Adventure Park to most_game_comments/Adventure Park.csv
# Saved data for app_name = Truck Racer to most_game_comments/Truck Racer.csv
# Saved data for app_name = Enemy Front to most_game_comments/Enemy Front.csv
# Saved data for app_name = Eschalon: Book 2 to most_game_comments/Eschalon: Book 2.csv
# Saved data for app_name = Child of Light to most_game_comments/Child of Light.csv
# Saved data for app_name = WRC 4 FIA WORLD RALLY CHAMPIONSHIP to most_game_comments/WRC 4 FIA WORLD RALLY CHAMPIONSHIP.csv
# Saved data for app_name = MotoGP™14 to most_game_comments/MotoGP™14.csv
# Saved data for app_name = Monsters & Munitions to most_game_comments/Monsters & Munitions.csv
# Saved data for app_name = Vigil: Blood Bitterness to most_game_comments/Vigil: Blood Bitterness.csv
# Saved data for app_name = Madballs in...Babo: Invasion to most_game_comments/Madballs in...Babo: Invasion.csv
# Saved data for app_name = Project Nimbus: Complete Edition to most_game_comments/Project Nimbus: Complete Edition.csv
# Saved data for app_name = Darkout to most_game_comments/Darkout.csv
# Saved data for app_name = Not The Robots to most_game_comments/Not The Robots.csv
# Saved data for app_name = Rebuild 3: Gangs of Deadsville to most_game_comments/Rebuild 3: Gangs of Deadsville.csv
# Saved data for app_name = Secret Files: Sam Peters to most_game_comments/Secret Files: Sam Peters.csv
# Saved data for app_name = Inherit the Earth: Quest for the Orb to most_game_comments/Inherit the Earth: Quest for the Orb.csv
# Saved data for app_name = Baldur's Gate II: Enhanced Edition to most_game_comments/Baldur's Gate II: Enhanced Edition.csv
# Saved data for app_name = Fuse to most_game_comments/Fuse.csv
# Saved data for app_name = The Talos Principle to most_game_comments/The Talos Principle.csv
# Saved data for app_name = LogoMaker 4 to most_game_comments/LogoMaker 4.csv
# Saved data for app_name = Blast Em! to most_game_comments/Blast Em!.csv
# Saved data for app_name = Mosaico  to most_game_comments/Mosaico .csv
# Saved data for app_name = Elder Sign: Omens to most_game_comments/Elder Sign: Omens.csv
# Saved data for app_name = J.U.L.I.A.: Among the Stars to most_game_comments/J.U.L.I.A.: Among the Stars.csv
# Saved data for app_name = Max Gentlemen to most_game_comments/Max Gentlemen.csv
# Saved data for app_name = Infinity Wars - Animated Trading Card Game to most_game_comments/Infinity Wars - Animated Trading Card Game.csv
# Saved data for app_name = Bloody Trapland to most_game_comments/Bloody Trapland.csv
# Saved data for app_name = Signal Ops to most_game_comments/Signal Ops.csv
# Saved data for app_name = Riptide GP2 to most_game_comments/Riptide GP2.csv
# Saved data for app_name = Violett to most_game_comments/Violett.csv
# Saved data for app_name = Hyper Light Drifter to most_game_comments/Hyper Light Drifter.csv
# Saved data for app_name = Eschalon: Book 3 to most_game_comments/Eschalon: Book 3.csv
# Saved data for app_name = Race To Mars to most_game_comments/Race To Mars.csv
# Saved data for app_name = Loren The Amazon Princess to most_game_comments/Loren The Amazon Princess.csv
# Saved data for app_name = Oozi: Earth Adventure to most_game_comments/Oozi: Earth Adventure.csv
# Saved data for app_name = Ring Runner: Flight of the Sages to most_game_comments/Ring Runner: Flight of the Sages.csv
# Saved data for app_name = Survivor Squad to most_game_comments/Survivor Squad.csv
# Saved data for app_name = Probability 0 to most_game_comments/Probability 0.csv
# Saved data for app_name = 99 Spirits to most_game_comments/99 Spirits.csv
# Saved data for app_name = Deus Ex: The Fall to most_game_comments/Deus Ex: The Fall.csv
# Saved data for app_name = Talisman: Prologue to most_game_comments/Talisman: Prologue.csv
# Saved data for app_name = Blood Knights to most_game_comments/Blood Knights.csv
# Saved data for app_name = Tank Operations to most_game_comments/Tank Operations.csv
# Saved data for app_name = Knights of Honor to most_game_comments/Knights of Honor.csv
# Saved data for app_name = The Vanishing of Ethan Carter to most_game_comments/The Vanishing of Ethan Carter.csv
# Saved data for app_name = Finn and Jake's Epic Quest to most_game_comments/Finn and Jake's Epic Quest.csv
# Saved data for app_name = Dragon Nest Europe to most_game_comments/Dragon Nest Europe.csv
# Saved data for app_name = Scania Truck Driving Simulator to most_game_comments/Scania Truck Driving Simulator.csv
# Saved data for app_name = Professional Farmer 2014 to most_game_comments/Professional Farmer 2014.csv
# Saved data for app_name = Type:Rider to most_game_comments/Type:Rider.csv
# Saved data for app_name = Hearts of Iron III to most_game_comments/Hearts of Iron III.csv
# Saved data for app_name = Citizens of Earth to most_game_comments/Citizens of Earth.csv
# Saved data for app_name = Montague's Mount to most_game_comments/Montague's Mount.csv
# Saved data for app_name = Gauntlet™  to most_game_comments/Gauntlet™ .csv
# Saved data for app_name = Alpha Prime to most_game_comments/Alpha Prime.csv
# Saved data for app_name = King's Bounty: The Legend to most_game_comments/King's Bounty: The Legend.csv
# Saved data for app_name = Dominions 4 to most_game_comments/Dominions 4.csv
# Saved data for app_name = Just Cause 2: Multiplayer Mod to most_game_comments/Just Cause 2: Multiplayer Mod.csv
# Saved data for app_name = Supreme Ruler 2020: Gold to most_game_comments/Supreme Ruler 2020: Gold.csv
# Saved data for app_name = Wasteland 1 - The Original Classic to most_game_comments/Wasteland 1 - The Original Classic.csv
# Saved data for app_name = Alone in the Dark to most_game_comments/Alone in the Dark.csv
# Saved data for app_name = Alone in the Dark: The New Nightmare to most_game_comments/Alone in the Dark: The New Nightmare.csv
# Saved data for app_name = East India Company to most_game_comments/East India Company.csv
# Saved data for app_name = Heli Heroes to most_game_comments/Heli Heroes.csv
# Saved data for app_name = Chicken Shoot Gold to most_game_comments/Chicken Shoot Gold.csv
# Saved data for app_name = Sneaky Sneaky to most_game_comments/Sneaky Sneaky.csv
# Saved data for app_name = Zigfrak to most_game_comments/Zigfrak.csv
# Saved data for app_name = Drifter to most_game_comments/Drifter.csv
# Saved data for app_name = Particulars to most_game_comments/Particulars.csv
# Saved data for app_name = Beast Boxing Turbo to most_game_comments/Beast Boxing Turbo.csv
# Saved data for app_name = Shufflepuck Cantina Deluxe to most_game_comments/Shufflepuck Cantina Deluxe.csv
# Saved data for app_name = Savant - Ascent to most_game_comments/Savant - Ascent.csv
# Saved data for app_name = Hero of the Kingdom to most_game_comments/Hero of the Kingdom.csv
# Saved data for app_name = Eden Star to most_game_comments/Eden Star.csv
# Saved data for app_name = Finding Teddy to most_game_comments/Finding Teddy.csv
# Saved data for app_name = 3079 -- Block Action RPG to most_game_comments/3079 -- Block Action RPG.csv
# Saved data for app_name = Guise Of The Wolf to most_game_comments/Guise Of The Wolf.csv
# Saved data for app_name = Void Destroyer to most_game_comments/Void Destroyer.csv
# Saved data for app_name = Tales of Maj'Eyal to most_game_comments/Tales of Maj'Eyal.csv
# Saved data for app_name = Fading Hearts to most_game_comments/Fading Hearts.csv
# Saved data for app_name = Nightmares from the Deep: The Cursed Heart to most_game_comments/Nightmares from the Deep: The Cursed Heart.csv
# Saved data for app_name = Two Brothers to most_game_comments/Two Brothers.csv
# Saved data for app_name = Nimble Quest to most_game_comments/Nimble Quest.csv
# Saved data for app_name = Majesty 2 to most_game_comments/Majesty 2.csv
# Saved data for app_name = Home Sheep Home: Farmageddon Party Edition to most_game_comments/Home Sheep Home: Farmageddon Party Edition.csv
# Saved data for app_name = Wooden Sen'SeY to most_game_comments/Wooden Sen'SeY.csv
# Saved data for app_name = OMG Zombies! to most_game_comments/OMG Zombies!.csv
# Saved data for app_name = Agricultural Simulator: Historical Farming to most_game_comments/Agricultural Simulator: Historical Farming.csv
# Saved data for app_name = Majesty: Gold Edition to most_game_comments/Majesty: Gold Edition.csv
# Saved data for app_name = YOU DON'T KNOW JACK Vol. 2 to most_game_comments/YOU DON'T KNOW JACK Vol. 2.csv
# Saved data for app_name = YOU DON'T KNOW JACK Vol. 3 to most_game_comments/YOU DON'T KNOW JACK Vol. 3.csv
# Saved data for app_name = YOU DON'T KNOW JACK Vol. 4 The Ride to most_game_comments/YOU DON'T KNOW JACK Vol. 4 The Ride.csv
# Saved data for app_name = Vampire: The Masquerade - Bloodlines to most_game_comments/Vampire: The Masquerade - Bloodlines.csv
# Saved data for app_name = YOU DON'T KNOW JACK MOVIES to most_game_comments/YOU DON'T KNOW JACK MOVIES.csv
# Saved data for app_name = YOU DON'T KNOW JACK SPORTS to most_game_comments/YOU DON'T KNOW JACK SPORTS.csv
# Saved data for app_name = YOU DON'T KNOW JACK TELEVISION to most_game_comments/YOU DON'T KNOW JACK TELEVISION.csv
# Saved data for app_name = Agarest Zero to most_game_comments/Agarest Zero.csv
# Saved data for app_name = The Last Tinker: City of Colors to most_game_comments/The Last Tinker: City of Colors.csv
# Saved data for app_name = Marc Eckō's Getting Up: Contents Under Pressure to most_game_comments/Marc Eckō's Getting Up: Contents Under Pressure.csv
# Saved data for app_name = Assassin's Creed Liberation to most_game_comments/Assassin's Creed Liberation.csv
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 45
#      43 output_dir = "most_game_comments"
#      44 column_to_split_by = "app_name"
# ---> 45 split_csv_by_column(input_file, output_dir, column_to_split_by)
#
# Cell In[6], line 38, in split_csv_by_column(file_path, output_path, column_name)
#      36 subset_df = df[df[column_name] == value]
#      37 output_file = f"{output_path}/{value}.csv"
# ---> 38 subset_df.to_csv(output_file, index=False)
#      39 print(f"Saved data for {column_name} = {value} to {output_file}")
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'most_game_comments/Valiant Hearts: The Great War™ '

# %%
#The final 获取评论 2Gb

def split_csv_by_column(file_path, output_path, column_name):
    """
    根据某列的值将CSV文件拆分为多个CSV文件

    :param file_path: 原CSV文件路径
    :param output_path: 拆分后的CSV文件输出路径
    :param column_name: 用于拆分数据的列名
    """
    # 检查输出文件夹是否存在，如果不存在则创建之
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # 使用pandas的read_csv函数读取CSV文件
    df = pd.read_csv(file_path)

    # 获取指定列的所有唯一值
    unique_values = df[column_name].unique()

    # 定义无法作为文件名的字符
    invalid_file_chars = ['#']

    # 遍历唯一值列表，为每个唯一值创建一个单独的CSV文件
    for value in unique_values:
        # 检查列名是否含有无法作为文件名的字符
        if any(char in str(value) for char in invalid_file_chars):
            print(f'Skipping invalid filename for value: {value}')
            continue  # 如果列名包含无效字符，跳过并处理下一个值

        subset_df = df[df[column_name] == value]
        output_file = f"{output_path}/{value}.csv"

        try:
            subset_df.to_csv(output_file, index=False)
            print(f"Saved data for {column_name} = {value} to {output_file}")
        except OSError as e:
            print(f"Skipping due to OSError: {e}")

# 使用示例
input_file = "dataset.csv"
output_dir = "most_game_comments"
column_to_split_by = "app_name"
split_csv_by_column(input_file, output_dir, column_to_split_by)
# Out:
# Saved data for app_name = Counter-Strike to most_game_comments/Counter-Strike.csv
# Saved data for app_name = Rag Doll Kung Fu to most_game_comments/Rag Doll Kung Fu.csv
# Saved data for app_name = Silo 2 to most_game_comments/Silo 2.csv
# Saved data for app_name = Call of Duty: World at War to most_game_comments/Call of Duty: World at War.csv
# Saved data for app_name = nan to most_game_comments/nan.csv
# Saved data for app_name = King's Quest Collection to most_game_comments/King's Quest Collection.csv
# Saved data for app_name = Space Quest Collection to most_game_comments/Space Quest Collection.csv
# Saved data for app_name = Aces of the Galaxy to most_game_comments/Aces of the Galaxy.csv
# Saved data for app_name = TimeShift to most_game_comments/TimeShift.csv
# Saved data for app_name = 3D Ultra Minigolf Adventures Deluxe to most_game_comments/3D Ultra Minigolf Adventures Deluxe.csv
# Saved data for app_name = Prototype to most_game_comments/Prototype.csv
# Saved data for app_name = Call of Duty: Modern Warfare 2 to most_game_comments/Call of Duty: Modern Warfare 2.csv
# Saved data for app_name = Postal 3 to most_game_comments/Postal 3.csv
# Saved data for app_name = Runespell: Overture to most_game_comments/Runespell: Overture.csv
# Saved data for app_name = Dead Mountaineer's Hotel to most_game_comments/Dead Mountaineer's Hotel.csv
# Saved data for app_name = Stroke of Fate: Operation Valkyrie to most_game_comments/Stroke of Fate: Operation Valkyrie.csv
# Saved data for app_name = PT Boats: Knights of the Sea to most_game_comments/PT Boats: Knights of the Sea.csv
# Saved data for app_name = Kingdoms of Amalur: Reckoning™ to most_game_comments/Kingdoms of Amalur: Reckoning™.csv
# Saved data for app_name = PT Boats: South Gambit to most_game_comments/PT Boats: South Gambit.csv
# Saved data for app_name = Orcs Must Die! to most_game_comments/Orcs Must Die!.csv
# Saved data for app_name = Disciples III: Reincarnation to most_game_comments/Disciples III: Reincarnation.csv
# Saved data for app_name = A.V.A. Alliance of Valiant Arms™ to most_game_comments/A.V.A. Alliance of Valiant Arms™.csv
# Saved data for app_name = Gatling Gears to most_game_comments/Gatling Gears.csv
# Saved data for app_name = Shank 2 to most_game_comments/Shank 2.csv
# Saved data for app_name = WARP to most_game_comments/WARP.csv
# Saved data for app_name = iBomber Defense to most_game_comments/iBomber Defense.csv
# Saved data for app_name = Storm in a Teacup to most_game_comments/Storm in a Teacup.csv
# Saved data for app_name = Inside a Star-filled Sky  to most_game_comments/Inside a Star-filled Sky .csv
# Saved data for app_name = BEEP to most_game_comments/BEEP.csv
# Saved data for app_name = The Club to most_game_comments/The Club.csv
# Saved data for app_name = Portal 2 - The Final Hours to most_game_comments/Portal 2 - The Final Hours.csv
# Saved data for app_name = Super Monday Night Combat to most_game_comments/Super Monday Night Combat.csv
# Saved data for app_name = ORION: Prelude to most_game_comments/ORION: Prelude.csv
# Saved data for app_name = Total War: EMPIRE - Definitive Edition to most_game_comments/Total War: EMPIRE - Definitive Edition.csv
# Saved data for app_name = A New Beginning - Final Cut to most_game_comments/A New Beginning - Final Cut.csv
# Saved data for app_name = Lume to most_game_comments/Lume.csv
# Saved data for app_name = Critical Mass to most_game_comments/Critical Mass.csv
# Saved data for app_name = Ms. Splosion Man to most_game_comments/Ms. Splosion Man.csv
# Saved data for app_name = Age of Empires® III (2007) to most_game_comments/Age of Empires® III (2007).csv
# Saved data for app_name = Terraria to most_game_comments/Terraria.csv
# Saved data for app_name = Tobe's Vertical Adventure to most_game_comments/Tobe's Vertical Adventure.csv
# Saved data for app_name = The Cursed Crusade to most_game_comments/The Cursed Crusade.csv
# Saved data for app_name = Aliens vs. Predator to most_game_comments/Aliens vs. Predator.csv
# Saved data for app_name = Bastion to most_game_comments/Bastion.csv
# Saved data for app_name = Space Pirates and Zombies to most_game_comments/Space Pirates and Zombies.csv
# Saved data for app_name = Breath of Death VII  to most_game_comments/Breath of Death VII .csv
# Saved data for app_name = Cthulhu Saves the World  to most_game_comments/Cthulhu Saves the World .csv
# Saved data for app_name = Arma 3 to most_game_comments/Arma 3.csv
# Saved data for app_name = Waves to most_game_comments/Waves.csv
# Saved data for app_name = War Inc. Battlezone to most_game_comments/War Inc. Battlezone.csv
# Saved data for app_name = Starpoint Gemini to most_game_comments/Starpoint Gemini.csv
# Saved data for app_name = Ticket to Ride to most_game_comments/Ticket to Ride.csv
# Saved data for app_name = Memoir '44 Online to most_game_comments/Memoir '44 Online.csv
# Saved data for app_name = Vessel to most_game_comments/Vessel.csv
# Saved data for app_name = Project Zomboid to most_game_comments/Project Zomboid.csv
# Saved data for app_name = Death Rally to most_game_comments/Death Rally.csv
# Saved data for app_name = Alan Wake to most_game_comments/Alan Wake.csv
# Saved data for app_name = Legend of Fae to most_game_comments/Legend of Fae.csv
# Saved data for app_name = Fowl Space to most_game_comments/Fowl Space.csv
# Saved data for app_name = Achron to most_game_comments/Achron.csv
# Saved data for app_name = Sherlock Holmes: Nemesis to most_game_comments/Sherlock Holmes: Nemesis.csv
# Saved data for app_name = inMomentum to most_game_comments/inMomentum.csv
# Saved data for app_name = Dracula: Origin to most_game_comments/Dracula: Origin.csv
# Saved data for app_name = Data Jammers: FastForward to most_game_comments/Data Jammers: FastForward.csv
# Saved data for app_name = Astro Tripper to most_game_comments/Astro Tripper.csv
# Saved data for app_name = Mutant Storm Reloaded to most_game_comments/Mutant Storm Reloaded.csv
# Saved data for app_name = L.A. Noire to most_game_comments/L.A. Noire.csv
# Saved data for app_name = The Clockwork Man to most_game_comments/The Clockwork Man.csv
# Saved data for app_name = The Clockwork Man: The Hidden World to most_game_comments/The Clockwork Man: The Hidden World.csv
# Saved data for app_name = Snuggle Truck to most_game_comments/Snuggle Truck.csv
# Saved data for app_name = Sherlock Holmes: The Mystery of The Mummy to most_game_comments/Sherlock Holmes: The Mystery of The Mummy.csv
# Saved data for app_name = Smash Cars to most_game_comments/Smash Cars.csv
# Saved data for app_name = Sherlock Holmes: The Awakened - Remastered to most_game_comments/Sherlock Holmes: The Awakened - Remastered.csv
# Saved data for app_name = Bunch Of Heroes to most_game_comments/Bunch Of Heroes.csv
# Saved data for app_name = Sherlock Holmes: The Secret of the Silver Earring to most_game_comments/Sherlock Holmes: The Secret of the Silver Earring.csv
# Saved data for app_name = Serious Sam Double D XXL to most_game_comments/Serious Sam Double D XXL.csv
# Saved data for app_name = Sherlock Holmes: The Mystery of The Persian Carpet to most_game_comments/Sherlock Holmes: The Mystery of The Persian Carpet.csv
# Saved data for app_name = Blocks That Matter to most_game_comments/Blocks That Matter.csv
# Saved data for app_name = Sherlock Holmes versus Jack the Ripper to most_game_comments/Sherlock Holmes versus Jack the Ripper.csv
# Saved data for app_name = Guardians of Middle-earth to most_game_comments/Guardians of Middle-earth.csv
# Saved data for app_name = Shadowgrounds: Survivor to most_game_comments/Shadowgrounds: Survivor.csv
# Saved data for app_name = Avadon: The Black Fortress to most_game_comments/Avadon: The Black Fortress.csv
# Saved data for app_name = Gumboy Tournament to most_game_comments/Gumboy Tournament.csv
# Saved data for app_name = Space Trader: Merchant Marine to most_game_comments/Space Trader: Merchant Marine.csv
# Saved data for app_name = Pacific Storm to most_game_comments/Pacific Storm.csv
# Saved data for app_name = Pacific Storm: Allies to most_game_comments/Pacific Storm: Allies.csv
# Saved data for app_name = Penguins Arena: Sedna's World to most_game_comments/Penguins Arena: Sedna's World.csv
# Saved data for app_name = Monaco to most_game_comments/Monaco.csv
# Saved data for app_name = The Binding of Isaac to most_game_comments/The Binding of Isaac.csv
# Saved data for app_name = Larva Mortus to most_game_comments/Larva Mortus.csv
# Saved data for app_name = APB Reloaded to most_game_comments/APB Reloaded.csv
# Saved data for app_name = Fallen Earth to most_game_comments/Fallen Earth.csv
# Saved data for app_name = Chains to most_game_comments/Chains.csv
# Saved data for app_name = Nikopol: Secrets of the Immortals to most_game_comments/Nikopol: Secrets of the Immortals.csv
# Saved data for app_name = Crash Time 2 to most_game_comments/Crash Time 2.csv
# Saved data for app_name = Overlord to most_game_comments/Overlord.csv
# Saved data for app_name = Soldiers: Heroes of World War II to most_game_comments/Soldiers: Heroes of World War II.csv
# Saved data for app_name = Costume Quest to most_game_comments/Costume Quest.csv
# Saved data for app_name = Stacking to most_game_comments/Stacking.csv
# Saved data for app_name = Iron Brigade to most_game_comments/Iron Brigade.csv
# Saved data for app_name = Cossacks II: Napoleonic Wars to most_game_comments/Cossacks II: Napoleonic Wars.csv
# Saved data for app_name = American Conquest to most_game_comments/American Conquest.csv
# Saved data for app_name = American Conquest - Fight Back to most_game_comments/American Conquest - Fight Back.csv
# Saved data for app_name = PROTOTYPE 2 to most_game_comments/PROTOTYPE 2.csv
# Saved data for app_name = Maelstrom to most_game_comments/Maelstrom.csv
# Saved data for app_name = Owlboy to most_game_comments/Owlboy.csv
# Saved data for app_name = Hospital Tycoon to most_game_comments/Hospital Tycoon.csv
# Saved data for app_name = Super Toy Cars to most_game_comments/Super Toy Cars.csv
# Saved data for app_name = Lightfish to most_game_comments/Lightfish.csv
# Saved data for app_name = Lumines to most_game_comments/Lumines.csv
# Saved data for app_name = Lumines: Advanced Pack to most_game_comments/Lumines: Advanced Pack.csv
# Saved data for app_name = Red Orchestra: Ostfront 41-45 to most_game_comments/Red Orchestra: Ostfront 41-45.csv
# Saved data for app_name = Manhunt to most_game_comments/Manhunt.csv
# Saved data for app_name = Max Payne to most_game_comments/Max Payne.csv
# Saved data for app_name = Max Payne 2: The Fall of Max Payne to most_game_comments/Max Payne 2: The Fall of Max Payne.csv
# Saved data for app_name = Grand Theft Auto to most_game_comments/Grand Theft Auto.csv
# Saved data for app_name = Grand Theft Auto 2 to most_game_comments/Grand Theft Auto 2.csv
# Saved data for app_name = Bully: Scholarship Edition to most_game_comments/Bully: Scholarship Edition.csv
# Saved data for app_name = Grand Theft Auto IV: The Complete Edition to most_game_comments/Grand Theft Auto IV: The Complete Edition.csv
# Saved data for app_name = Grand Theft Auto: Episodes from Liberty City to most_game_comments/Grand Theft Auto: Episodes from Liberty City.csv
# Saved data for app_name = Culpa Innata to most_game_comments/Culpa Innata.csv
# Saved data for app_name = Sacred Gold to most_game_comments/Sacred Gold.csv
# Saved data for app_name = DarkStar One to most_game_comments/DarkStar One.csv
# Saved data for app_name = Jack Keane to most_game_comments/Jack Keane.csv
# Saved data for app_name = FlatOut: Ultimate Carnage to most_game_comments/FlatOut: Ultimate Carnage.csv
# Saved data for app_name = Perimeter 2: New Earth to most_game_comments/Perimeter 2: New Earth.csv
# Saved data for app_name = SlamIt Pinball: Big Score to most_game_comments/SlamIt Pinball: Big Score.csv
# Saved data for app_name = Ankh 3: Battle of the Gods to most_game_comments/Ankh 3: Battle of the Gods.csv
# Saved data for app_name = BC Kings to most_game_comments/BC Kings.csv
# Saved data for app_name = Port Royale 2 to most_game_comments/Port Royale 2.csv
# Saved data for app_name = 9th Company - Roots of Terror to most_game_comments/9th Company - Roots of Terror.csv
# Saved data for app_name = Killing Floor to most_game_comments/Killing Floor.csv
# Saved data for app_name = Puzzle Quest to most_game_comments/Puzzle Quest.csv
# Saved data for app_name = 18 Wheels of Steel: American Long Haul to most_game_comments/18 Wheels of Steel: American Long Haul.csv
# Saved data for app_name = Hunting Unlimited 2008 to most_game_comments/Hunting Unlimited 2008.csv
# Saved data for app_name = Ride! Carnival Tycoon to most_game_comments/Ride! Carnival Tycoon.csv
# Saved data for app_name = Hot Dish to most_game_comments/Hot Dish.csv
# Saved data for app_name = Dr. Daisy: Pet Vet to most_game_comments/Dr. Daisy: Pet Vet.csv
# Saved data for app_name = Sprint Cars: Road to Knoxville to most_game_comments/Sprint Cars: Road to Knoxville.csv
# Saved data for app_name = Legend: Hand of God to most_game_comments/Legend: Hand of God.csv
# Saved data for app_name = Drakensang to most_game_comments/Drakensang.csv
# Saved data for app_name = Mission Runway to most_game_comments/Mission Runway.csv
# Saved data for app_name = Hunting Unlimited 2010 to most_game_comments/Hunting Unlimited 2010.csv
# Saved data for app_name = Overlord: Raising Hell to most_game_comments/Overlord: Raising Hell.csv
# Saved data for app_name = GRID to most_game_comments/GRID.csv
# Saved data for app_name = Rise of the Argonauts to most_game_comments/Rise of the Argonauts.csv
# Saved data for app_name = Damnation to most_game_comments/Damnation.csv
# Saved data for app_name = Operation Flashpoint: Dragon Rising to most_game_comments/Operation Flashpoint: Dragon Rising.csv
# Saved data for app_name = Half-Life: Blue Shift to most_game_comments/Half-Life: Blue Shift.csv
# Saved data for app_name = SiN Episodes: Emergence to most_game_comments/SiN Episodes: Emergence.csv
# Saved data for app_name = Ninja Reflex: Steamworks Edition to most_game_comments/Ninja Reflex: Steamworks Edition.csv
# Saved data for app_name = SiN: Gold to most_game_comments/SiN: Gold.csv
# Saved data for app_name = America's Army 3 to most_game_comments/America's Army 3.csv
# Saved data for app_name = Unreal II: The Awakening to most_game_comments/Unreal II: The Awakening.csv
# Saved data for app_name = Unreal Tournament 3: Black Edition to most_game_comments/Unreal Tournament 3: Black Edition.csv
# Saved data for app_name = Unreal Tournament 2004 to most_game_comments/Unreal Tournament 2004.csv
# Saved data for app_name = Unreal Tournament: Game of the Year Edition to most_game_comments/Unreal Tournament: Game of the Year Edition.csv
# Saved data for app_name = Unreal Gold to most_game_comments/Unreal Gold.csv
# Saved data for app_name = Prince of Persia: Warrior Within to most_game_comments/Prince of Persia: Warrior Within.csv
# Saved data for app_name = Far Cry to most_game_comments/Far Cry.csv
# Saved data for app_name = Prince of Persia: The Two Thrones to most_game_comments/Prince of Persia: The Two Thrones.csv
# Saved data for app_name = Tom Clancy's Rainbow Six: Vegas to most_game_comments/Tom Clancy's Rainbow Six: Vegas.csv
# Saved data for app_name = Tom Clancy's Splinter Cell to most_game_comments/Tom Clancy's Splinter Cell.csv
# Saved data for app_name = Tom Clancy's Splinter Cell: Chaos Theory to most_game_comments/Tom Clancy's Splinter Cell: Chaos Theory.csv
# Saved data for app_name = Tom Clancy's Splinter Cell: Double Agent to most_game_comments/Tom Clancy's Splinter Cell: Double Agent.csv
# Saved data for app_name = Prince of Persia: The Sands of Time to most_game_comments/Prince of Persia: The Sands of Time.csv
# Saved data for app_name = Tom Clancy's Ghost Recon: Desert Siege to most_game_comments/Tom Clancy's Ghost Recon: Desert Siege.csv
# Saved data for app_name = Darwinia to most_game_comments/Darwinia.csv
# Saved data for app_name = Tom Clancy's Rainbow Six: Lockdown to most_game_comments/Tom Clancy's Rainbow Six: Lockdown.csv
# Saved data for app_name = Rayman: Raving Rabbids to most_game_comments/Rayman: Raving Rabbids.csv
# Saved data for app_name = Uplink to most_game_comments/Uplink.csv
# Saved data for app_name = Assassin's Creed to most_game_comments/Assassin's Creed.csv
# Saved data for app_name = Tom Clancy's Rainbow Six: Vegas 2 to most_game_comments/Tom Clancy's Rainbow Six: Vegas 2.csv
# Saved data for app_name = Beyond Good & Evil to most_game_comments/Beyond Good & Evil.csv
# Saved data for app_name = Petz Horsez 2 to most_game_comments/Petz Horsez 2.csv
# Saved data for app_name = Heroes of Might & Magic V to most_game_comments/Heroes of Might & Magic V.csv
# Saved data for app_name = Brothers in Arms: Road to Hill 30 to most_game_comments/Brothers in Arms: Road to Hill 30.csv
# Saved data for app_name = DEFCON to most_game_comments/DEFCON.csv
# Saved data for app_name = Silent Hunter: Wolves of the Pacific to most_game_comments/Silent Hunter: Wolves of the Pacific.csv
# Saved data for app_name = Silent Hunter III to most_game_comments/Silent Hunter III.csv
# Saved data for app_name = Silent Hunter: Wolves of the Pacific U-Boat Missions to most_game_comments/Silent Hunter: Wolves of the Pacific U-Boat Missions.csv
# Saved data for app_name = Cold Fear to most_game_comments/Cold Fear.csv
# Saved data for app_name = Multiwinia to most_game_comments/Multiwinia.csv
# Saved data for app_name = Tom Clancy's Ghost Recon to most_game_comments/Tom Clancy's Ghost Recon.csv
# Saved data for app_name = The Settlers: Heritage of Kings to most_game_comments/The Settlers: Heritage of Kings.csv
# Saved data for app_name = IL-2 Sturmovik: 1946 to most_game_comments/IL-2 Sturmovik: 1946.csv
# Saved data for app_name = Heroes of Might & Magic V: Tribes of the East to most_game_comments/Heroes of Might & Magic V: Tribes of the East.csv
# Saved data for app_name = Heroes of Might & Magic V: Hammers of Fate to most_game_comments/Heroes of Might & Magic V: Hammers of Fate.csv
# Saved data for app_name = Brothers in Arms: Hell's Highway to most_game_comments/Brothers in Arms: Hell's Highway.csv
# Saved data for app_name = Harvest: Massive Encounter to most_game_comments/Harvest: Massive Encounter.csv
# Saved data for app_name = The Wonderful End of the World to most_game_comments/The Wonderful End of the World.csv
# Saved data for app_name = AaAaAA!!! - A Reckless Disregard for Gravity to most_game_comments/AaAaAA!!! - A Reckless Disregard for Gravity.csv
# Saved data for app_name = AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome to most_game_comments/AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome.csv
# Saved data for app_name = Warhammer 40,000: Dawn of War II to most_game_comments/Warhammer 40,000: Dawn of War II.csv
# Saved data for app_name = Oddworld: Abe's Oddysee to most_game_comments/Oddworld: Abe's Oddysee.csv
# Saved data for app_name = Oddworld: Abe's Exoddus to most_game_comments/Oddworld: Abe's Exoddus.csv
# Saved data for app_name = Oddworld: Munch's Oddysee to most_game_comments/Oddworld: Munch's Oddysee.csv
# Saved data for app_name = Oddworld: Stranger's Wrath HD to most_game_comments/Oddworld: Stranger's Wrath HD.csv
# Saved data for app_name = Planet Busters to most_game_comments/Planet Busters.csv
# Saved data for app_name = 7 Wonders II to most_game_comments/7 Wonders II.csv
# Saved data for app_name = Luxor: Amun Rising to most_game_comments/Luxor: Amun Rising.csv
# Saved data for app_name = Luxor 2 to most_game_comments/Luxor 2.csv
# Saved data for app_name = Luxor 3 to most_game_comments/Luxor 3.csv
# Saved data for app_name = Little Farm to most_game_comments/Little Farm.csv
# Saved data for app_name = Luxor to most_game_comments/Luxor.csv
# Saved data for app_name = Dangerous Waters to most_game_comments/Dangerous Waters.csv
# Saved data for app_name = Discovery! A Seek & Find Adventure to most_game_comments/Discovery! A Seek & Find Adventure.csv
# Saved data for app_name = Samantha Swift and the Hidden Roses of Athena to most_game_comments/Samantha Swift and the Hidden Roses of Athena.csv
# Saved data for app_name = 7 Wonders: The Treasures of Seven to most_game_comments/7 Wonders: The Treasures of Seven.csv
# Saved data for app_name = Luxor: Quest for the Afterlife to most_game_comments/Luxor: Quest for the Afterlife.csv
# Saved data for app_name = Samantha Swift and the Golden Touch to most_game_comments/Samantha Swift and the Golden Touch.csv
# Saved data for app_name = Space Empires IV Deluxe to most_game_comments/Space Empires IV Deluxe.csv
# Saved data for app_name = Virtual Villagers: A New Home to most_game_comments/Virtual Villagers: A New Home.csv
# Saved data for app_name = Virtual Villagers 2: The Lost Children to most_game_comments/Virtual Villagers 2: The Lost Children.csv
# Saved data for app_name = Plant Tycoon to most_game_comments/Plant Tycoon.csv
# Saved data for app_name = Fish Tycoon to most_game_comments/Fish Tycoon.csv
# Saved data for app_name = Virtual Villagers 3: The Secret City to most_game_comments/Virtual Villagers 3: The Secret City.csv
# Saved data for app_name = Virtual Families to most_game_comments/Virtual Families.csv
# Saved data for app_name = Disciples II: Rise of the Elves to most_game_comments/Disciples II: Rise of the Elves.csv
# Saved data for app_name = Everyday Shooter to most_game_comments/Everyday Shooter.csv
# Saved data for app_name = Disciples II: Gallean's Return to most_game_comments/Disciples II: Gallean's Return.csv
# Saved data for app_name = F.E.A.R. 2: Project Origin to most_game_comments/F.E.A.R. 2: Project Origin.csv
# Saved data for app_name = Chaos Theory to most_game_comments/Chaos Theory.csv
# Saved data for app_name = Trials 2: Second Edition to most_game_comments/Trials 2: Second Edition.csv
# Saved data for app_name = Monster Trucks Nitro to most_game_comments/Monster Trucks Nitro.csv
# Saved data for app_name = Insecticide Part 1 to most_game_comments/Insecticide Part 1.csv
# Saved data for app_name = Velvet Assassin to most_game_comments/Velvet Assassin.csv
# Saved data for app_name = Legendary to most_game_comments/Legendary.csv
# Saved data for app_name = Sid Meier's Civilization IV: Colonization to most_game_comments/Sid Meier's Civilization IV: Colonization.csv
# Saved data for app_name = Space Empires V to most_game_comments/Space Empires V.csv
# Saved data for app_name = Arx Fatalis to most_game_comments/Arx Fatalis.csv
# Saved data for app_name = Tribes: Ascend to most_game_comments/Tribes: Ascend.csv
# Saved data for app_name = Children of the Nile to most_game_comments/Children of the Nile.csv
# Saved data for app_name = Children of the Nile: Alexandria to most_game_comments/Children of the Nile: Alexandria.csv
# Saved data for app_name = Hinterland to most_game_comments/Hinterland.csv
# Saved data for app_name = Mosby's Confederacy to most_game_comments/Mosby's Confederacy.csv
# Saved data for app_name = Crysis Warhead to most_game_comments/Crysis Warhead.csv
# Saved data for app_name = Mirror's Edge to most_game_comments/Mirror's Edge.csv
# Saved data for app_name = Spore: Creepy & Cute Parts Pack to most_game_comments/Spore: Creepy & Cute Parts Pack.csv
# Saved data for app_name = Dragon Age: Origins to most_game_comments/Dragon Age: Origins.csv
# Saved data for app_name = Mass Effect (2007) to most_game_comments/Mass Effect (2007).csv
# Saved data for app_name = Dead Space to most_game_comments/Dead Space.csv
# Saved data for app_name = Command and Conquer: Red Alert 3 to most_game_comments/Command and Conquer: Red Alert 3.csv
# Saved data for app_name = Pirates, Vikings, & Knights II to most_game_comments/Pirates, Vikings, & Knights II.csv
# Saved data for app_name = Dystopia to most_game_comments/Dystopia.csv
# Saved data for app_name = Nuclear Dawn to most_game_comments/Nuclear Dawn.csv
# Saved data for app_name = Empires to most_game_comments/Empires.csv
# Saved data for app_name = On the Rain-Slick Precipice of Darkness, Episode One to most_game_comments/On the Rain-Slick Precipice of Darkness, Episode One.csv
# Saved data for app_name = On the Rain-Slick Precipice of Darkness, Episode Two to most_game_comments/On the Rain-Slick Precipice of Darkness, Episode Two.csv
# Saved data for app_name = DeathSpank to most_game_comments/DeathSpank.csv
# Saved data for app_name = DeathSpank: Thongs Of Virtue to most_game_comments/DeathSpank: Thongs Of Virtue.csv
# Saved data for app_name = The Baconing to most_game_comments/The Baconing.csv
# Saved data for app_name = Unstoppable Gorg to most_game_comments/Unstoppable Gorg.csv
# Saved data for app_name = Source Filmmaker to most_game_comments/Source Filmmaker.csv
# Saved data for app_name = Crazy Machines 2 to most_game_comments/Crazy Machines 2.csv
# Saved data for app_name = Crazy Machines to most_game_comments/Crazy Machines.csv
# Saved data for app_name = Helldorado to most_game_comments/Helldorado.csv
# Saved data for app_name = Mata Hari to most_game_comments/Mata Hari.csv
# Saved data for app_name = Defense Grid: The Awakening to most_game_comments/Defense Grid: The Awakening.csv
# Saved data for app_name = Mayhem Intergalactic to most_game_comments/Mayhem Intergalactic.csv
# Saved data for app_name = And Yet It Moves to most_game_comments/And Yet It Moves.csv
# Saved data for app_name = Zero Gear to most_game_comments/Zero Gear.csv
# Saved data for app_name = Earth 2160 to most_game_comments/Earth 2160.csv
# Saved data for app_name = Silent Hill: Homecoming to most_game_comments/Silent Hill: Homecoming.csv
# Saved data for app_name = Puzzle Chronicles to most_game_comments/Puzzle Chronicles.csv
# Saved data for app_name = Tank Universal to most_game_comments/Tank Universal.csv
# Saved data for app_name = Two Worlds: Epic Edition to most_game_comments/Two Worlds: Epic Edition.csv
# Saved data for app_name = Space Ark to most_game_comments/Space Ark.csv
# Saved data for app_name = Eternity's Child to most_game_comments/Eternity's Child.csv
# Saved data for app_name = Alice: Madness Returns to most_game_comments/Alice: Madness Returns.csv
# Saved data for app_name = Brothers in Arms: Earned in Blood to most_game_comments/Brothers in Arms: Earned in Blood.csv
# Saved data for app_name = Tom Clancy's Rainbow Six 3: Gold Edition to most_game_comments/Tom Clancy's Rainbow Six 3: Gold Edition.csv
# Saved data for app_name = Far Cry 2 to most_game_comments/Far Cry 2.csv
# Saved data for app_name = The Settlers: Rise of an Empire Gold Edition   to most_game_comments/The Settlers: Rise of an Empire Gold Edition  .csv
# Saved data for app_name = Prince of Persia to most_game_comments/Prince of Persia.csv
# Saved data for app_name = Team Fortress Classic to most_game_comments/Team Fortress Classic.csv
# Saved data for app_name = Quantum Conundrum to most_game_comments/Quantum Conundrum.csv
# Saved data for app_name = Global Ops: Commando Libya to most_game_comments/Global Ops: Commando Libya.csv
# Saved data for app_name = Naval War: Arctic Circle to most_game_comments/Naval War: Arctic Circle.csv
# Saved data for app_name = Nancy Drew: Shadow at the Water's Edge to most_game_comments/Nancy Drew: Shadow at the Water's Edge.csv
# Saved data for app_name = Puzzler World 2 to most_game_comments/Puzzler World 2.csv
# Saved data for app_name = Worms Revolution to most_game_comments/Worms Revolution.csv
# Saved data for app_name = Sideway to most_game_comments/Sideway.csv
# Saved data for app_name = Realm of the Mad God Exalt to most_game_comments/Realm of the Mad God Exalt.csv
# Saved data for app_name = Off-Road Drive to most_game_comments/Off-Road Drive.csv
# Saved data for app_name = Batman: Arkham City GOTY to most_game_comments/Batman: Arkham City GOTY.csv
# Saved data for app_name = A Game of Dwarves to most_game_comments/A Game of Dwarves.csv
# Saved data for app_name = Oil Rush to most_game_comments/Oil Rush.csv
# Saved data for app_name = SOL: Exodus to most_game_comments/SOL: Exodus.csv
# Saved data for app_name = Memento Mori to most_game_comments/Memento Mori.csv
# Saved data for app_name = XCOM: Enemy Unknown to most_game_comments/XCOM: Enemy Unknown.csv
# Saved data for app_name = Dungeons - The Dark Lord to most_game_comments/Dungeons - The Dark Lord.csv
# Saved data for app_name = Gettysburg: Armored Warfare to most_game_comments/Gettysburg: Armored Warfare.csv
# Saved data for app_name = Disciples III: Resurrection to most_game_comments/Disciples III: Resurrection.csv
# Saved data for app_name = Torchlight II to most_game_comments/Torchlight II.csv
# Saved data for app_name = Cave Story+ to most_game_comments/Cave Story+.csv
# Saved data for app_name = Before the Echo to most_game_comments/Before the Echo.csv
# Saved data for app_name = Sonic CD to most_game_comments/Sonic CD.csv
# Saved data for app_name = Geneforge 1 to most_game_comments/Geneforge 1.csv
# Saved data for app_name = Geneforge 3 to most_game_comments/Geneforge 3.csv
# Saved data for app_name = Geneforge 4 to most_game_comments/Geneforge 4.csv
# Saved data for app_name = Geneforge 5 to most_game_comments/Geneforge 5.csv
# Saved data for app_name = Galcon Legends to most_game_comments/Galcon Legends.csv
# Saved data for app_name = Revelations 2012 to most_game_comments/Revelations 2012.csv
# Saved data for app_name = Pox Nora to most_game_comments/Pox Nora.csv
# Saved data for app_name = EverQuest II to most_game_comments/EverQuest II.csv
# Saved data for app_name = Sins of a Solar Empire: Trinity to most_game_comments/Sins of a Solar Empire: Trinity.csv
# Saved data for app_name = Toki Tori 2+ to most_game_comments/Toki Tori 2+.csv
# Saved data for app_name = Serious Sam: The Random Encounter to most_game_comments/Serious Sam: The Random Encounter.csv
# Saved data for app_name = Airline Tycoon 2 to most_game_comments/Airline Tycoon 2.csv
# Saved data for app_name = Flatout 3 to most_game_comments/Flatout 3.csv
# Saved data for app_name = Really Big Sky to most_game_comments/Really Big Sky.csv
# Saved data for app_name = DiRT Showdown to most_game_comments/DiRT Showdown.csv
# Saved data for app_name = Orcs Must Die! 2 to most_game_comments/Orcs Must Die! 2.csv
# Saved data for app_name = Wolfenstein: The New Order to most_game_comments/Wolfenstein: The New Order.csv
# Saved data for app_name = Jurassic Park: The Game to most_game_comments/Jurassic Park: The Game.csv
# Saved data for app_name = Assassin's Creed Revelations to most_game_comments/Assassin's Creed Revelations.csv
# Saved data for app_name = Galactic Bowling to most_game_comments/Galactic Bowling.csv
# Saved data for app_name = Choplifter HD to most_game_comments/Choplifter HD.csv
# Saved data for app_name = Impire to most_game_comments/Impire.csv
# Saved data for app_name = Sleeping Dogs™ to most_game_comments/Sleeping Dogs™.csv
# Saved data for app_name = Galactic Civilizations II: Ultimate Edition to most_game_comments/Galactic Civilizations II: Ultimate Edition.csv
# Saved data for app_name = Leviathan: Warships to most_game_comments/Leviathan: Warships.csv
# Saved data for app_name = Ridge Racer™ Unbounded to most_game_comments/Ridge Racer™ Unbounded.csv
# Saved data for app_name = Scarygirl to most_game_comments/Scarygirl.csv
# Saved data for app_name = Scoregasm to most_game_comments/Scoregasm.csv
# Saved data for app_name = SONIC THE HEDGEHOG 4 Episode I to most_game_comments/SONIC THE HEDGEHOG 4 Episode I.csv
# Saved data for app_name = Nancy Drew: Alibi in Ashes to most_game_comments/Nancy Drew: Alibi in Ashes.csv
# Saved data for app_name = Hegemony Gold: Wars of Ancient Greece to most_game_comments/Hegemony Gold: Wars of Ancient Greece.csv
# Saved data for app_name = Demigod to most_game_comments/Demigod.csv
# Saved data for app_name = Dynamite Jack to most_game_comments/Dynamite Jack.csv
# Saved data for app_name = Alan Wake's American Nightmare to most_game_comments/Alan Wake's American Nightmare.csv
# Saved data for app_name = Real Warfare 2: Northern Crusades to most_game_comments/Real Warfare 2: Northern Crusades.csv
# Saved data for app_name = Call of Duty: Black Ops II to most_game_comments/Call of Duty: Black Ops II.csv
# Saved data for app_name = Call of Duty: Black Ops II - Multiplayer to most_game_comments/Call of Duty: Black Ops II - Multiplayer.csv
# Saved data for app_name = Hitman: Absolution to most_game_comments/Hitman: Absolution.csv
# Saved data for app_name = Tomb Raider to most_game_comments/Tomb Raider.csv
# Saved data for app_name = Titan Attacks to most_game_comments/Titan Attacks.csv
# Saved data for app_name = America's Army: Proving Grounds to most_game_comments/America's Army: Proving Grounds.csv
# Saved data for app_name = King's Bounty: Warriors of the North to most_game_comments/King's Bounty: Warriors of the North.csv
# Saved data for app_name = Fortune Summoners: Secret of the Elemental Stone to most_game_comments/Fortune Summoners: Secret of the Elemental Stone.csv
# Saved data for app_name = Containment: The Zombie Puzzler to most_game_comments/Containment: The Zombie Puzzler.csv
# Saved data for app_name = SONIC THE HEDGEHOG 4 Episode II to most_game_comments/SONIC THE HEDGEHOG 4 Episode II.csv
# Saved data for app_name = F1 Race Stars to most_game_comments/F1 Race Stars.csv
# Saved data for app_name = Binary Domain to most_game_comments/Binary Domain.csv
# Saved data for app_name = Crusader Kings II to most_game_comments/Crusader Kings II.csv
# Saved data for app_name = Dear Esther to most_game_comments/Dear Esther.csv
# Saved data for app_name = The Dark Eye: Chains of Satinav to most_game_comments/The Dark Eye: Chains of Satinav.csv
# Saved data for app_name = SATAZIUS to most_game_comments/SATAZIUS.csv
# Saved data for app_name = Fable - The Lost Chapters to most_game_comments/Fable - The Lost Chapters.csv
# Saved data for app_name = Superbrothers: Sword & Sworcery EP to most_game_comments/Superbrothers: Sword & Sworcery EP.csv
# Saved data for app_name = The Showdown Effect to most_game_comments/The Showdown Effect.csv
# Saved data for app_name = Max Payne 3 to most_game_comments/Max Payne 3.csv
# Saved data for app_name = LEGO® Harry Potter: Years 5-7 to most_game_comments/LEGO® Harry Potter: Years 5-7.csv
# Saved data for app_name = Waveform to most_game_comments/Waveform.csv
# Saved data for app_name = Snapshot to most_game_comments/Snapshot.csv
# Saved data for app_name = The Bridge to most_game_comments/The Bridge.csv
# Saved data for app_name = Awesomenauts to most_game_comments/Awesomenauts.csv
# Saved data for app_name = Serious Sam 2 to most_game_comments/Serious Sam 2.csv
# Saved data for app_name = Castle Crashers to most_game_comments/Castle Crashers.csv
# Saved data for app_name = Pineapple Smash Crew  to most_game_comments/Pineapple Smash Crew .csv
# Saved data for app_name = Pickers to most_game_comments/Pickers.csv
# Saved data for app_name = Call of Juarez Gunslinger to most_game_comments/Call of Juarez Gunslinger.csv
# Saved data for app_name = Infested Planet to most_game_comments/Infested Planet.csv
# Saved data for app_name = Confrontation to most_game_comments/Confrontation.csv
# Saved data for app_name = Rotastic to most_game_comments/Rotastic.csv
# Saved data for app_name = Retro City Rampage™ DX to most_game_comments/Retro City Rampage™ DX.csv
# Saved data for app_name = Deep Black : Reloaded to most_game_comments/Deep Black : Reloaded.csv
# Saved data for app_name = Babel Rising to most_game_comments/Babel Rising.csv
# Saved data for app_name = Men of War: Condemned Heroes to most_game_comments/Men of War: Condemned Heroes.csv
# Saved data for app_name = Sins of a Solar Empire: Rebellion to most_game_comments/Sins of a Solar Empire: Rebellion.csv
# Saved data for app_name = Crusader Kings Complete to most_game_comments/Crusader Kings Complete.csv
# Saved data for app_name = Red Faction: Guerrilla Steam Edition to most_game_comments/Red Faction: Guerrilla Steam Edition.csv
# Saved data for app_name = Lumino City to most_game_comments/Lumino City.csv
# Saved data for app_name = BIT.TRIP CORE to most_game_comments/BIT.TRIP CORE.csv
# Saved data for app_name = BIT.TRIP VOID to most_game_comments/BIT.TRIP VOID.csv
# Saved data for app_name = BIT.TRIP FATE to most_game_comments/BIT.TRIP FATE.csv
# Saved data for app_name = S.T.A.L.K.E.R.: Clear Sky to most_game_comments/S.T.A.L.K.E.R.: Clear Sky.csv
# Saved data for app_name = Dishonored to most_game_comments/Dishonored.csv
# Saved data for app_name = Hell Yeah! to most_game_comments/Hell Yeah!.csv
# Saved data for app_name = 3DMark 11 to most_game_comments/3DMark 11.csv
# Saved data for app_name = Company of Heroes: Tales of Valor to most_game_comments/Company of Heroes: Tales of Valor.csv
# Saved data for app_name = Foreign Legion: Multi Massacre to most_game_comments/Foreign Legion: Multi Massacre.csv
# Saved data for app_name = The Testament of Sherlock Holmes to most_game_comments/The Testament of Sherlock Holmes.csv
# Saved data for app_name = 1000 Amps to most_game_comments/1000 Amps.csv
# Saved data for app_name = Warhammer 40,000: Dawn of War II - Chaos Rising to most_game_comments/Warhammer 40,000: Dawn of War II - Chaos Rising.csv
# Saved data for app_name = EverQuest Free-to-Play to most_game_comments/EverQuest Free-to-Play.csv
# Saved data for app_name = Insanely Twisted Shadow Planet to most_game_comments/Insanely Twisted Shadow Planet.csv
# Saved data for app_name = Jagged Alliance: Crossfire to most_game_comments/Jagged Alliance: Crossfire.csv
# Saved data for app_name = Luxor Evolved to most_game_comments/Luxor Evolved.csv
# Saved data for app_name = Yesterday to most_game_comments/Yesterday.csv
# Saved data for app_name = Auditorium to most_game_comments/Auditorium.csv
# Saved data for app_name = Chronicle: RuneScape Legends to most_game_comments/Chronicle: RuneScape Legends.csv
# Saved data for app_name = Jet Set Radio to most_game_comments/Jet Set Radio.csv
# Saved data for app_name = Warlock 2: the Exiled to most_game_comments/Warlock 2: the Exiled.csv
# Saved data for app_name = Avernum 4 to most_game_comments/Avernum 4.csv
# Saved data for app_name = Avernum 5 to most_game_comments/Avernum 5.csv
# Saved data for app_name = Avernum 6 to most_game_comments/Avernum 6.csv
# Saved data for app_name = Gunpoint to most_game_comments/Gunpoint.csv
# Saved data for app_name = Clan of Champions to most_game_comments/Clan of Champions.csv
# Saved data for app_name = ClaDun x2 to most_game_comments/ClaDun x2.csv
# Saved data for app_name = Tales from Space: Mutant Blobs Attack to most_game_comments/Tales from Space: Mutant Blobs Attack.csv
# Saved data for app_name = Crazy Machines Elements to most_game_comments/Crazy Machines Elements.csv
# Saved data for app_name = Saints Row IV to most_game_comments/Saints Row IV.csv
# Saved data for app_name = To the Moon to most_game_comments/To the Moon.csv
# Saved data for app_name = Dungeons & Dragons Online® to most_game_comments/Dungeons & Dragons Online®.csv
# Saved data for app_name = AirMech Strike to most_game_comments/AirMech Strike.csv
# Saved data for app_name = 3SwitcheD to most_game_comments/3SwitcheD.csv
# Saved data for app_name = iBomber Defense Pacific to most_game_comments/iBomber Defense Pacific.csv
# Saved data for app_name = Painkiller: Recurring Evil to most_game_comments/Painkiller: Recurring Evil.csv
# Saved data for app_name = Starscape to most_game_comments/Starscape.csv
# Saved data for app_name = Alien Spidy to most_game_comments/Alien Spidy.csv
# Saved data for app_name = Bang Bang Racing to most_game_comments/Bang Bang Racing.csv
# Saved data for app_name = Sine Mora to most_game_comments/Sine Mora.csv
# Saved data for app_name = Indie Game: The Movie to most_game_comments/Indie Game: The Movie.csv
# Saved data for app_name = Mr. Robot to most_game_comments/Mr. Robot.csv
# Saved data for app_name = SpeedRunners to most_game_comments/SpeedRunners.csv
# Saved data for app_name = Stellar Impact to most_game_comments/Stellar Impact.csv
# Saved data for app_name = Legend of Grimrock to most_game_comments/Legend of Grimrock.csv
# Saved data for app_name = Fireburst to most_game_comments/Fireburst.csv
# Saved data for app_name = Tony Hawk's Pro Skater HD to most_game_comments/Tony Hawk's Pro Skater HD.csv
# Saved data for app_name = Archeblade to most_game_comments/Archeblade.csv
# Saved data for app_name = Cubemen to most_game_comments/Cubemen.csv
# Saved data for app_name = Ys: The Oath in Felghana to most_game_comments/Ys: The Oath in Felghana.csv
# Saved data for app_name = Ys Origin to most_game_comments/Ys Origin.csv
# Saved data for app_name = eXceed - Gun Bullet Children to most_game_comments/eXceed - Gun Bullet Children.csv
# Saved data for app_name = eXceed 2nd - Vampire REX to most_game_comments/eXceed 2nd - Vampire REX.csv
# Saved data for app_name = eXceed 3rd - Jade Penetrate Black Package to most_game_comments/eXceed 3rd - Jade Penetrate Black Package.csv
# Saved data for app_name = Wizorb to most_game_comments/Wizorb.csv
# Saved data for app_name = Hack, Slash, Loot to most_game_comments/Hack, Slash, Loot.csv
# Saved data for app_name = Rayman Origins to most_game_comments/Rayman Origins.csv
# Saved data for app_name = Noitu Love 2 Devolution to most_game_comments/Noitu Love 2 Devolution.csv
# Saved data for app_name = English Country Tune to most_game_comments/English Country Tune.csv
# Saved data for app_name = A Virus Named TOM to most_game_comments/A Virus Named TOM.csv
# Saved data for app_name = AVSEQ to most_game_comments/AVSEQ.csv
# Saved data for app_name = Botanicula to most_game_comments/Botanicula.csv
# Saved data for app_name = Bumbledore to most_game_comments/Bumbledore.csv
# Saved data for app_name = Arena Wars 2 to most_game_comments/Arena Wars 2.csv
# Saved data for app_name = Symphony to most_game_comments/Symphony.csv
# Saved data for app_name = Jane's Advanced Strike Fighters to most_game_comments/Jane's Advanced Strike Fighters.csv
# Saved data for app_name = Sacred Citadel to most_game_comments/Sacred Citadel.csv
# Saved data for app_name = Moon Breakers to most_game_comments/Moon Breakers.csv
# Saved data for app_name = Myst V to most_game_comments/Myst V.csv
# Saved data for app_name = ENDLESS™ Space - Definitive Edition to most_game_comments/ENDLESS™ Space - Definitive Edition.csv
# Saved data for app_name = Shatter to most_game_comments/Shatter.csv
# Saved data for app_name = DOOM 3: BFG Edition to most_game_comments/DOOM 3: BFG Edition.csv
# Saved data for app_name = Avernum: Escape From the Pit to most_game_comments/Avernum: Escape From the Pit.csv
# Saved data for app_name = Tryst to most_game_comments/Tryst.csv
# Saved data for app_name = Assassin's Creed® III to most_game_comments/Assassin's Creed® III.csv
# Saved data for app_name = F1 2012 to most_game_comments/F1 2012.csv
# Saved data for app_name = Omerta - City of Gangsters to most_game_comments/Omerta - City of Gangsters.csv
# Saved data for app_name = STAR WARS™ Knights of the Old Republic™ II: The Sith Lords™ to most_game_comments/STAR WARS™ Knights of the Old Republic™ II: The Sith Lords™.csv
# Saved data for app_name = Lunar Flight to most_game_comments/Lunar Flight.csv
# Saved data for app_name = Midnight Mysteries: Salem Witch Trials to most_game_comments/Midnight Mysteries: Salem Witch Trials.csv
# Saved data for app_name = Midnight Mysteries 3: Devil on the Mississippi to most_game_comments/Midnight Mysteries 3: Devil on the Mississippi.csv
# Saved data for app_name = Midnight Mysteries 4: Haunted Houdini to most_game_comments/Midnight Mysteries 4: Haunted Houdini.csv
# Saved data for app_name = Batman™: Arkham Knight to most_game_comments/Batman™: Arkham Knight.csv
# Saved data for app_name = Blades of Time to most_game_comments/Blades of Time.csv
# Saved data for app_name = Colour Bind to most_game_comments/Colour Bind.csv
# Saved data for app_name = Game of Thrones  to most_game_comments/Game of Thrones .csv
# Saved data for app_name = Apotheon to most_game_comments/Apotheon.csv
# Saved data for app_name = The Witcher: Enhanced Edition to most_game_comments/The Witcher: Enhanced Edition.csv
# Saved data for app_name = Batman™: Arkham Origins to most_game_comments/Batman™: Arkham Origins.csv
# Saved data for app_name = Drunken Robot Pornography to most_game_comments/Drunken Robot Pornography.csv
# Saved data for app_name = Guns of Icarus Online to most_game_comments/Guns of Icarus Online.csv
# Saved data for app_name = Resident Evil: Operation Raccoon City to most_game_comments/Resident Evil: Operation Raccoon City.csv
# Saved data for app_name = Street Fighter X Tekken to most_game_comments/Street Fighter X Tekken.csv
# Saved data for app_name = Call of Duty: Ghosts to most_game_comments/Call of Duty: Ghosts.csv
# Saved data for app_name = Stealth Bastard Deluxe to most_game_comments/Stealth Bastard Deluxe.csv
# Saved data for app_name = The Witcher 2: Assassins of Kings Enhanced Edition to most_game_comments/The Witcher 2: Assassins of Kings Enhanced Edition.csv
# Saved data for app_name = Sherlock Holmes and The Hound of The Baskervilles to most_game_comments/Sherlock Holmes and The Hound of The Baskervilles.csv
# Saved data for app_name = Hero Academy to most_game_comments/Hero Academy.csv
# Saved data for app_name = A Valley Without Wind to most_game_comments/A Valley Without Wind.csv
# Saved data for app_name = AZMD! Scorepocalypse  to most_game_comments/AZMD! Scorepocalypse .csv
# Saved data for app_name = Analogue: A Hate Story to most_game_comments/Analogue: A Hate Story.csv
# Saved data for app_name = Dungeonbowl Knockout Edition to most_game_comments/Dungeonbowl Knockout Edition.csv
# Saved data for app_name = Mini Motor Racing EVO to most_game_comments/Mini Motor Racing EVO.csv
# Saved data for app_name = Strike Suit Zero to most_game_comments/Strike Suit Zero.csv
# Saved data for app_name = Roller Coaster Rampage to most_game_comments/Roller Coaster Rampage.csv
# Saved data for app_name = Magrunner: Dark Pulse to most_game_comments/Magrunner: Dark Pulse.csv
# Saved data for app_name = Call of Duty: Advanced Warfare to most_game_comments/Call of Duty: Advanced Warfare.csv
# Saved data for app_name = Cortex Command to most_game_comments/Cortex Command.csv
# Saved data for app_name = Fieldrunners to most_game_comments/Fieldrunners.csv
# Saved data for app_name = RAW - Realms of Ancient War to most_game_comments/RAW - Realms of Ancient War.csv
# Saved data for app_name = Cannon Fodder 3 to most_game_comments/Cannon Fodder 3.csv
# Saved data for app_name = Splice to most_game_comments/Splice.csv
# Saved data for app_name = Lone Survivor: The Director's Cut to most_game_comments/Lone Survivor: The Director's Cut.csv
# Saved data for app_name = Highborn to most_game_comments/Highborn.csv
# Saved data for app_name = Blacklight: Retribution to most_game_comments/Blacklight: Retribution.csv
# Saved data for app_name = Triple Town to most_game_comments/Triple Town.csv
# Saved data for app_name = Dark Messiah of Might & Magic Single Player to most_game_comments/Dark Messiah of Might & Magic Single Player.csv
# Saved data for app_name = Watchmen: The End Is Nigh to most_game_comments/Watchmen: The End Is Nigh.csv
# Saved data for app_name = Spirits to most_game_comments/Spirits.csv
# Saved data for app_name = Nancy Drew: Tomb of the Lost Queen to most_game_comments/Nancy Drew: Tomb of the Lost Queen.csv
# Saved data for app_name = Fray to most_game_comments/Fray.csv
# Saved data for app_name = Angry Birds Space to most_game_comments/Angry Birds Space.csv
# Saved data for app_name = Sanctum 2 to most_game_comments/Sanctum 2.csv
# Saved data for app_name = F.E.A.R. to most_game_comments/F.E.A.R..csv
# Saved data for app_name = Rune Classic to most_game_comments/Rune Classic.csv
# Saved data for app_name = The Witness to most_game_comments/The Witness.csv
# Saved data for app_name = F.E.A.R. 3 to most_game_comments/F.E.A.R. 3.csv
# Saved data for app_name = Alien Shooter 2 Conscription to most_game_comments/Alien Shooter 2 Conscription.csv
# Saved data for app_name = Battle vs Chess to most_game_comments/Battle vs Chess.csv
# Saved data for app_name = Check vs. Mate to most_game_comments/Check vs. Mate.csv
# Saved data for app_name = Viking: Battle for Asgard to most_game_comments/Viking: Battle for Asgard.csv
# Saved data for app_name = Unmechanical to most_game_comments/Unmechanical.csv
# Saved data for app_name = They Bleed Pixels to most_game_comments/They Bleed Pixels.csv
# Saved data for app_name = Primal Fears to most_game_comments/Primal Fears.csv
# Saved data for app_name = LEGO® Harry Potter: Years 1-4 to most_game_comments/LEGO® Harry Potter: Years 1-4.csv
# Saved data for app_name = Magical Diary: Horse Hall to most_game_comments/Magical Diary: Horse Hall.csv
# Saved data for app_name = Offspring Fling! to most_game_comments/Offspring Fling!.csv
# ...
# Saved data for app_name = Worms to most_game_comments/Worms.csv
# Saved data for app_name = Worms Blast to most_game_comments/Worms Blast.csv
# Saved data for app_name = Worms Pinball to most_game_comments/Worms Pinball.csv
# Saved data for app_name = Star Ruler to most_game_comments/Star Ruler.csv
# Saved data for app_name = Evochron Mercenary to most_game_comments/Evochron Mercenary.csv
# Saved data for app_name = Jade Empire: Special Edition to most_game_comments/Jade Empire: Special Edition.csv
# Saved data for app_name = Crazy Taxi to most_game_comments/Crazy Taxi.csv
# Saved data for app_name = SEGA Bass Fishing to most_game_comments/SEGA Bass Fishing.csv
# Saved data for app_name = Sonic Adventure DX to most_game_comments/Sonic Adventure DX.csv
# Saved data for app_name = Space Channel 5: Part 2 to most_game_comments/Space Channel 5: Part 2.csv
# Saved data for app_name = Sonic Generations to most_game_comments/Sonic Generations.csv
# Saved data for app_name = TrackMania United Forever to most_game_comments/TrackMania United Forever.csv
# Saved data for app_name = Closure to most_game_comments/Closure.csv
# Saved data for app_name = Runaway: A Road Adventure to most_game_comments/Runaway: A Road Adventure.csv
# Saved data for app_name = Runaway: The Dream of the Turtle to most_game_comments/Runaway: The Dream of the Turtle.csv
# Saved data for app_name = Clones to most_game_comments/Clones.csv
# Saved data for app_name = Loki to most_game_comments/Loki.csv
# Saved data for app_name = The Elder Scrolls V: Skyrim to most_game_comments/The Elder Scrolls V: Skyrim.csv
# Saved data for app_name = Winter Voices to most_game_comments/Winter Voices.csv
# Saved data for app_name = Cities in Motion to most_game_comments/Cities in Motion.csv
# Saved data for app_name = Majesty 2 Collection to most_game_comments/Majesty 2 Collection.csv
# Saved data for app_name = Defenders of Ardania to most_game_comments/Defenders of Ardania.csv
# Saved data for app_name = Pride of Nations to most_game_comments/Pride of Nations.csv
# Saved data for app_name = Sengoku to most_game_comments/Sengoku.csv
# Saved data for app_name = Supreme Ruler Cold War to most_game_comments/Supreme Ruler Cold War.csv
# Saved data for app_name = Azada to most_game_comments/Azada.csv
# Saved data for app_name = X-Blades to most_game_comments/X-Blades.csv
# Saved data for app_name = Two Worlds II to most_game_comments/Two Worlds II.csv
# Saved data for app_name = Two Worlds II Castle Defense to most_game_comments/Two Worlds II Castle Defense.csv
# Saved data for app_name = Sid Meier's Railroads! to most_game_comments/Sid Meier's Railroads!.csv
# Saved data for app_name = Railroad Tycoon 3 to most_game_comments/Railroad Tycoon 3.csv
# Saved data for app_name = Railroad Tycoon 2: Platinum to most_game_comments/Railroad Tycoon 2: Platinum.csv
# Saved data for app_name = X-COM: Terror from the Deep to most_game_comments/X-COM: Terror from the Deep.csv
# Saved data for app_name = X-COM: Apocalypse to most_game_comments/X-COM: Apocalypse.csv
# Saved data for app_name = BioShock to most_game_comments/BioShock.csv
# Saved data for app_name = X-COM: Interceptor to most_game_comments/X-COM: Interceptor.csv
# Saved data for app_name = X-COM: UFO Defense to most_game_comments/X-COM: UFO Defense.csv
# Saved data for app_name = X-COM: Enforcer to most_game_comments/X-COM: Enforcer.csv
# Saved data for app_name = Bejeweled 3 to most_game_comments/Bejeweled 3.csv
# Saved data for app_name = Men of War to most_game_comments/Men of War.csv
# Saved data for app_name = Death Track: Resurrection to most_game_comments/Death Track: Resurrection.csv
# Saved data for app_name = NecroVisioN to most_game_comments/NecroVisioN.csv
# Saved data for app_name = Call of Duty 4: Modern Warfare to most_game_comments/Call of Duty 4: Modern Warfare.csv
# Saved data for app_name = Counter-Strike: Condition Zero to most_game_comments/Counter-Strike: Condition Zero.csv
# Saved data for app_name = Tomb Raider: Anniversary to most_game_comments/Tomb Raider: Anniversary.csv
# Saved data for app_name = APOX to most_game_comments/APOX.csv
# Saved data for app_name = Fate of the World to most_game_comments/Fate of the World.csv
# Saved data for app_name = Puzzle Bots to most_game_comments/Puzzle Bots.csv
# Saved data for app_name = Gemini Rue to most_game_comments/Gemini Rue.csv
# Saved data for app_name = The Blackwell Legacy to most_game_comments/The Blackwell Legacy.csv
# Saved data for app_name = Blackwell Convergence to most_game_comments/Blackwell Convergence.csv
# Saved data for app_name = Blackwell Deception to most_game_comments/Blackwell Deception.csv
# Saved data for app_name = Championship Manager 2007 to most_game_comments/Championship Manager 2007.csv
# Saved data for app_name = Championship Manager 2008 to most_game_comments/Championship Manager 2008.csv
# Saved data for app_name = Kane & Lynch: Dead Men to most_game_comments/Kane & Lynch: Dead Men.csv
# Saved data for app_name = Conflict: Denied Ops to most_game_comments/Conflict: Denied Ops.csv
# Saved data for app_name = Tomb Raider: Underworld to most_game_comments/Tomb Raider: Underworld.csv
# Saved data for app_name = Battlestations: Pacific to most_game_comments/Battlestations: Pacific.csv
# Saved data for app_name = Just Cause 2 to most_game_comments/Just Cause 2.csv
# Saved data for app_name = Sam & Max 201: Ice Station Santa to most_game_comments/Sam & Max 201: Ice Station Santa.csv
# Saved data for app_name = Sam & Max 202: Moai Better Blues to most_game_comments/Sam & Max 202: Moai Better Blues.csv
# Saved data for app_name = Sam & Max 203: Night of the Raving Dead to most_game_comments/Sam & Max 203: Night of the Raving Dead.csv
# Saved data for app_name = Sam & Max 204: Chariots of the Dogs to most_game_comments/Sam & Max 204: Chariots of the Dogs.csv
# Saved data for app_name = Sam & Max 205: What's New Beelzebub? to most_game_comments/Sam & Max 205: What's New Beelzebub?.csv
# Saved data for app_name = Bone: Out from Boneville to most_game_comments/Bone: Out from Boneville.csv
# Saved data for app_name = Bone: The Great Cow Race to most_game_comments/Bone: The Great Cow Race.csv
# Saved data for app_name = Telltale Texas Hold'Em to most_game_comments/Telltale Texas Hold'Em.csv
# Saved data for app_name = Strong Bad Episode 1: Homestar Ruiner to most_game_comments/Strong Bad Episode 1: Homestar Ruiner.csv
# Saved data for app_name = Strong Bad Episode 2: Strong Badia the Free to most_game_comments/Strong Bad Episode 2: Strong Badia the Free.csv
# Saved data for app_name = Strong Bad Episode 3: Baddest of the Bands to most_game_comments/Strong Bad Episode 3: Baddest of the Bands.csv
# Saved data for app_name = Strong Bad Episode 5: 8-Bit Is Enough to most_game_comments/Strong Bad Episode 5: 8-Bit Is Enough.csv
# Saved data for app_name = Geometry Wars: Retro Evolved to most_game_comments/Geometry Wars: Retro Evolved.csv
# Saved data for app_name = EVE Online to most_game_comments/EVE Online.csv
# Saved data for app_name = RACE 07 to most_game_comments/RACE 07.csv
# Saved data for app_name = GTR 2 - FIA GT Racing Game to most_game_comments/GTR 2 - FIA GT Racing Game.csv
# Saved data for app_name = Sid Meier's Civilization IV: Beyond the Sword to most_game_comments/Sid Meier's Civilization IV: Beyond the Sword.csv
# Saved data for app_name = BioShock 2 to most_game_comments/BioShock 2.csv
# Saved data for app_name = BioShock Infinite to most_game_comments/BioShock Infinite.csv
# Saved data for app_name = Freedom Force to most_game_comments/Freedom Force.csv
# Saved data for app_name = Freedom Force vs. the 3rd Reich to most_game_comments/Freedom Force vs. the 3rd Reich.csv
# Saved data for app_name = Sid Meier's Civilization V to most_game_comments/Sid Meier's Civilization V.csv
# Saved data for app_name = Axel & Pixel to most_game_comments/Axel & Pixel.csv
# Saved data for app_name = Borderlands GOTY to most_game_comments/Borderlands GOTY.csv
# Saved data for app_name = Wolfenstein 3D: Spear of Destiny to most_game_comments/Wolfenstein 3D: Spear of Destiny.csv
# Saved data for app_name = Return to Castle Wolfenstein to most_game_comments/Return to Castle Wolfenstein.csv
# Saved data for app_name = Farming Simulator 2011 to most_game_comments/Farming Simulator 2011.csv
# Saved data for app_name = Blue Toad Murder Files - The Mysteries of Little Riddle to most_game_comments/Blue Toad Murder Files - The Mysteries of Little Riddle.csv
# Saved data for app_name = DOOM 3 to most_game_comments/DOOM 3.csv
# Saved data for app_name = Guardians of Graxia to most_game_comments/Guardians of Graxia.csv
# Saved data for app_name = HeXen II to most_game_comments/HeXen II.csv
# Saved data for app_name = SkyDrift to most_game_comments/SkyDrift.csv
# Saved data for app_name = Anomaly Warzone Earth to most_game_comments/Anomaly Warzone Earth.csv
# Saved data for app_name = Iron Front : Liberation 1944 to most_game_comments/Iron Front : Liberation 1944.csv
# Saved data for app_name = Master Levels for DOOM II to most_game_comments/Master Levels for DOOM II.csv
# Saved data for app_name = Sanctum to most_game_comments/Sanctum.csv
# Saved data for app_name = E.Y.E: Divine Cybermancy to most_game_comments/E.Y.E: Divine Cybermancy.csv
# Saved data for app_name = Commander Keen Complete Pack to most_game_comments/Commander Keen Complete Pack.csv
# Saved data for app_name = Cloning Clyde to most_game_comments/Cloning Clyde.csv
# Saved data for app_name = Ancients of Ooga to most_game_comments/Ancients of Ooga.csv
# Saved data for app_name = Post Apocalyptic Mayhem to most_game_comments/Post Apocalyptic Mayhem.csv
# Saved data for app_name = RAGE to most_game_comments/RAGE.csv
# Saved data for app_name = Hydrophobia: Prophecy to most_game_comments/Hydrophobia: Prophecy.csv
# Saved data for app_name = DETOUR to most_game_comments/DETOUR.csv
# Saved data for app_name = Hitogata Happa to most_game_comments/Hitogata Happa.csv
# Saved data for app_name = GundeadliGne to most_game_comments/GundeadliGne.csv
# Saved data for app_name = A.R.E.S. to most_game_comments/A.R.E.S..csv
# Saved data for app_name = B.U.T.T.O.N. to most_game_comments/B.U.T.T.O.N..csv
# Saved data for app_name = Xotic to most_game_comments/Xotic.csv
# Saved data for app_name = Shadow Harvest: Phantom Ops to most_game_comments/Shadow Harvest: Phantom Ops.csv
# Saved data for app_name = SpaceChem to most_game_comments/SpaceChem.csv
# Saved data for app_name = Agricultural Simulator 2011: Extended Edition to most_game_comments/Agricultural Simulator 2011: Extended Edition.csv
# Saved data for app_name = Warhammer 40,000: Dawn of War - Winter Assault to most_game_comments/Warhammer 40,000: Dawn of War - Winter Assault.csv
# Saved data for app_name = Revenge of the Titans to most_game_comments/Revenge of the Titans.csv
# Saved data for app_name = Company of Heroes: Opposing Fronts to most_game_comments/Company of Heroes: Opposing Fronts.csv
# Saved data for app_name = Supreme Commander to most_game_comments/Supreme Commander.csv
# Saved data for app_name = Dinner Date to most_game_comments/Dinner Date.csv
# Saved data for app_name = Supreme Commander: Forged Alliance to most_game_comments/Supreme Commander: Forged Alliance.csv
# Saved data for app_name = Jamestown to most_game_comments/Jamestown.csv
# Saved data for app_name = The Dream Machine to most_game_comments/The Dream Machine.csv
# Saved data for app_name = Nidhogg to most_game_comments/Nidhogg.csv
# Saved data for app_name = Warhammer 40,000: Dawn of War - Soulstorm to most_game_comments/Warhammer 40,000: Dawn of War - Soulstorm.csv
# Saved data for app_name = Back to the Future: Ep 2 - Get Tannen! to most_game_comments/Back to the Future: Ep 2 - Get Tannen!.csv
# Saved data for app_name = Back to the Future: Ep 3 - Citizen Brown to most_game_comments/Back to the Future: Ep 3 - Citizen Brown.csv
# Saved data for app_name = Back to the Future: Ep 5 - OUTATIME to most_game_comments/Back to the Future: Ep 5 - OUTATIME.csv
# Saved data for app_name = Puzzle Agent 2 to most_game_comments/Puzzle Agent 2.csv
# Saved data for app_name = Frontlines: Fuel of War to most_game_comments/Frontlines: Fuel of War.csv
# Saved data for app_name = Hector: Ep 1 to most_game_comments/Hector: Ep 1.csv
# Saved data for app_name = Hector: Ep 2 to most_game_comments/Hector: Ep 2.csv
# Saved data for app_name = Hector: Ep 3 to most_game_comments/Hector: Ep 3.csv
# Saved data for app_name = Saints Row 2 to most_game_comments/Saints Row 2.csv
# Saved data for app_name = Gish to most_game_comments/Gish.csv
# Saved data for app_name = Capsized to most_game_comments/Capsized.csv
# Saved data for app_name = ibb & obb to most_game_comments/ibb & obb.csv
# Saved data for app_name = The Cat and the Coup to most_game_comments/The Cat and the Coup.csv
# Saved data for app_name = Air Conflicts - Secret Wars to most_game_comments/Air Conflicts - Secret Wars.csv
# Saved data for app_name = Defy Gravity to most_game_comments/Defy Gravity.csv
# Saved data for app_name = Nexuiz to most_game_comments/Nexuiz.csv
# Saved data for app_name = Slam Bolt Scrappers to most_game_comments/Slam Bolt Scrappers.csv
# Saved data for app_name = Solar 2 to most_game_comments/Solar 2.csv
# Saved data for app_name = Desperados 2: Cooper’s Revenge to most_game_comments/Desperados 2: Cooper’s Revenge.csv
# Saved data for app_name = Kohan: Immortal Sovereigns to most_game_comments/Kohan: Immortal Sovereigns.csv
# Saved data for app_name = Kohan: Ahriman's Gift to most_game_comments/Kohan: Ahriman's Gift.csv
# Saved data for app_name = Kohan II: Kings of War to most_game_comments/Kohan II: Kings of War.csv
# Saved data for app_name = Tycoon City: New York to most_game_comments/Tycoon City: New York.csv
# Saved data for app_name = Act of War: High Treason to most_game_comments/Act of War: High Treason.csv
# Saved data for app_name = Death to Spies to most_game_comments/Death to Spies.csv
# Saved data for app_name = TRAUMA to most_game_comments/TRAUMA.csv
# Saved data for app_name = Frozen Synapse to most_game_comments/Frozen Synapse.csv
# Saved data for app_name = Toy Soldiers to most_game_comments/Toy Soldiers.csv
# Saved data for app_name = Hard Reset to most_game_comments/Hard Reset.csv
# Saved data for app_name = Codename: Panzers - Cold War to most_game_comments/Codename: Panzers - Cold War.csv
# Saved data for app_name = Naval Warfare to most_game_comments/Naval Warfare.csv
# Saved data for app_name = Demolition, Inc. to most_game_comments/Demolition, Inc..csv
# Saved data for app_name = Ghostbusters: The Video Game to most_game_comments/Ghostbusters: The Video Game.csv
# Saved data for app_name = Champions Online to most_game_comments/Champions Online.csv
# Saved data for app_name = Alien Hallway to most_game_comments/Alien Hallway.csv
# Saved data for app_name = Star Trek Online to most_game_comments/Star Trek Online.csv
# Saved data for app_name = Dungeons & Dragons: Daggerdale to most_game_comments/Dungeons & Dragons: Daggerdale.csv
# Saved data for app_name = Yar's Revenge to most_game_comments/Yar's Revenge.csv
# Saved data for app_name = Renegade Ops to most_game_comments/Renegade Ops.csv
# Saved data for app_name = Blade Kitten to most_game_comments/Blade Kitten.csv
# Saved data for app_name = Garshasp: The Monster Slayer to most_game_comments/Garshasp: The Monster Slayer.csv
# Saved data for app_name = Garshasp: Temple of the Dragon to most_game_comments/Garshasp: Temple of the Dragon.csv
# Saved data for app_name = Haunted House to most_game_comments/Haunted House.csv
# Saved data for app_name = Star Raiders  to most_game_comments/Star Raiders .csv
# Saved data for app_name = NightSky to most_game_comments/NightSky.csv
# Saved data for app_name = The UnderGarden to most_game_comments/The UnderGarden.csv
# Saved data for app_name = Bulletstorm to most_game_comments/Bulletstorm.csv
# Saved data for app_name = Crysis 2 to most_game_comments/Crysis 2.csv
# Saved data for app_name = Ghostbusters: Sanctum of Slime to most_game_comments/Ghostbusters: Sanctum of Slime.csv
# Saved data for app_name = Spiral Knights to most_game_comments/Spiral Knights.csv
# Saved data for app_name = Puzzle Pirates to most_game_comments/Puzzle Pirates.csv

# %%
from textblob import TextBlob

def analyze_sentiment(csv_directory, column_name, output_dir):
    """
    对 CSV 文件中指定列的情感进行分析，并保存结果

    :param csv_directory: 包含 CSV 文件的目录
    :param column_name: 需要分析情感的列名
    :param output_dir: 输出目录
    """
    # 确保输出目录存在
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # 获取 CSV 文件夹中的所有文件
    files = [f for f in os.listdir(csv_directory) if f.endswith('.csv')]

    # 遍历每个文件，读取 CSV 文件并提取指定的列
    for file in files:
        df = pd.read_csv(os.path.join(csv_directory, file))

        # 确保列名存在
        if column_name in df.columns:
            sentiments = []

            # 对选定的列进行情感分析
            for text in df[column_name]:
                sentiment = TextBlob(str(text)).sentiment.polarity
                sentiments.append(sentiment)

            # 计算积极，消极和中立的评论数量
            positive_comments = sum(1 for sentiment in sentiments if sentiment > 0)
            negative_comments = sum(1 for sentiment in sentiments if sentiment < 0)
            neutral_comments = sum(1 for sentiment in sentiments if sentiment == 0)
            total_comments = len(sentiments)
            if total_comments > 0:
                percentage_positive = (positive_comments / total_comments) * 100
            else:
                percentage_positive = 0


            # 保存结果到新的CSV文件
            output_file = os.path.join(output_dir, file)
            results_df = pd.DataFrame({
                'total_comments': [total_comments],
                'positive_comments': [positive_comments],
                'negative_comments': [negative_comments],
                'neutral_comments': [neutral_comments],
                'percentage_positive': [percentage_positive],
            })
            results_df.to_csv(output_file, index=False)
            print(f'Saved results for {file} to {output_file}')

# 使用示例
csv_dir = "most_game_comments"
column_to_analyze = "review_text"
output_dir = "sentiment_analysis_results"
analyze_sentiment(csv_dir, column_to_analyze, output_dir)
# Out:
# Saved results for RESCUE 2.csv to sentiment_analysis_results/RESCUE 2.csv
# Saved results for Nightclub Emporium.csv to sentiment_analysis_results/Nightclub Emporium.csv
# Saved results for Legacy of Kain: Soul Reaver 2.csv to sentiment_analysis_results/Legacy of Kain: Soul Reaver 2.csv
# Saved results for BIOS.csv to sentiment_analysis_results/BIOS.csv
# Saved results for Pavel Quest.csv to sentiment_analysis_results/Pavel Quest.csv
# Saved results for Stargunner.csv to sentiment_analysis_results/Stargunner.csv
# Saved results for Nanomedix Inc.csv to sentiment_analysis_results/Nanomedix Inc.csv
# Saved results for Shatter.csv to sentiment_analysis_results/Shatter.csv
# Saved results for Space Scaven.csv to sentiment_analysis_results/Space Scaven.csv
# Saved results for Zombie Pirates.csv to sentiment_analysis_results/Zombie Pirates.csv
# Saved results for ArcaniA.csv to sentiment_analysis_results/ArcaniA.csv
# Saved results for Dead Hungry Diner.csv to sentiment_analysis_results/Dead Hungry Diner.csv
# Saved results for Battle Ranch.csv to sentiment_analysis_results/Battle Ranch.csv
# Saved results for Plague Inc: Evolved.csv to sentiment_analysis_results/Plague Inc: Evolved.csv
# Saved results for Umbrella Corps.csv to sentiment_analysis_results/Umbrella Corps.csv
# Saved results for ARK: Survival Evolved.csv to sentiment_analysis_results/ARK: Survival Evolved.csv
# Saved results for Kitchen Simulator 2015.csv to sentiment_analysis_results/Kitchen Simulator 2015.csv
# Saved results for Putt-Putt Joins the Circus.csv to sentiment_analysis_results/Putt-Putt Joins the Circus.csv
# Saved results for Trainz: Classic Cabon City.csv to sentiment_analysis_results/Trainz: Classic Cabon City.csv
# Saved results for Dracula: Origin.csv to sentiment_analysis_results/Dracula: Origin.csv
# Saved results for 100% Orange Juice.csv to sentiment_analysis_results/100% Orange Juice.csv
# Saved results for Metal Planet.csv to sentiment_analysis_results/Metal Planet.csv
# Saved results for Empires Of Creation.csv to sentiment_analysis_results/Empires Of Creation.csv
# Saved results for Crystal Towers 2.csv to sentiment_analysis_results/Crystal Towers 2.csv
# Saved results for Tiny Troopers.csv to sentiment_analysis_results/Tiny Troopers.csv
# Saved results for Rail Cargo Simulator.csv to sentiment_analysis_results/Rail Cargo Simulator.csv
# Saved results for The Banner Saga.csv to sentiment_analysis_results/The Banner Saga.csv
# Saved results for J.U.L.I.A.: Among the Stars.csv to sentiment_analysis_results/J.U.L.I.A.: Among the Stars.csv
# Saved results for The Repopulation.csv to sentiment_analysis_results/The Repopulation.csv
# Saved results for Lighthockey.csv to sentiment_analysis_results/Lighthockey.csv
# Saved results for Call of Duty: Black Ops II.csv to sentiment_analysis_results/Call of Duty: Black Ops II.csv
# Saved results for Shroud of the Avatar: Forsaken Virtues.csv to sentiment_analysis_results/Shroud of the Avatar: Forsaken Virtues.csv
# Saved results for Mirrored - Chapter 1.csv to sentiment_analysis_results/Mirrored - Chapter 1.csv
# Saved results for Paint it Back.csv to sentiment_analysis_results/Paint it Back.csv
# Saved results for Deja Vu II: MacVenture Series.csv to sentiment_analysis_results/Deja Vu II: MacVenture Series.csv
# Saved results for VRC PRO.csv to sentiment_analysis_results/VRC PRO.csv
# Saved results for Virtual Desktop.csv to sentiment_analysis_results/Virtual Desktop.csv
# Saved results for Vinyl.csv to sentiment_analysis_results/Vinyl.csv
# Saved results for Captain Morgane and the Golden Turtle.csv to sentiment_analysis_results/Captain Morgane and the Golden Turtle.csv
# Saved results for Take the Dream IX.csv to sentiment_analysis_results/Take the Dream IX.csv
# Saved results for Nancy Drew: Secret of the Scarlet Hand .csv to sentiment_analysis_results/Nancy Drew: Secret of the Scarlet Hand .csv
# Saved results for Area-X.csv to sentiment_analysis_results/Area-X.csv
# Saved results for Absolute Drift.csv to sentiment_analysis_results/Absolute Drift.csv
# Saved results for Worlds Adrift Island Creator.csv to sentiment_analysis_results/Worlds Adrift Island Creator.csv
# Saved results for Shadow Warrior 2.csv to sentiment_analysis_results/Shadow Warrior 2.csv
# Saved results for Trapper's Delight.csv to sentiment_analysis_results/Trapper's Delight.csv
# Saved results for Fairy Fencer F.csv to sentiment_analysis_results/Fairy Fencer F.csv
# Saved results for NightSky.csv to sentiment_analysis_results/NightSky.csv
# Saved results for Rotieer.csv to sentiment_analysis_results/Rotieer.csv
# Saved results for Zombie Army Trilogy.csv to sentiment_analysis_results/Zombie Army Trilogy.csv
# Saved results for Robotex.csv to sentiment_analysis_results/Robotex.csv
# Saved results for Red Game Without A Great Name.csv to sentiment_analysis_results/Red Game Without A Great Name.csv
# Saved results for Adventures of Shuggy.csv to sentiment_analysis_results/Adventures of Shuggy.csv
# Saved results for Volgarr the Viking.csv to sentiment_analysis_results/Volgarr the Viking.csv
# Saved results for Binaries.csv to sentiment_analysis_results/Binaries.csv
# Saved results for Infested Planet.csv to sentiment_analysis_results/Infested Planet.csv
# Saved results for Disney Tangled.csv to sentiment_analysis_results/Disney Tangled.csv
# Saved results for Commandos 3: Destination Berlin.csv to sentiment_analysis_results/Commandos 3: Destination Berlin.csv
# Saved results for The Tower - Fantogame.csv to sentiment_analysis_results/The Tower - Fantogame.csv
# Saved results for Jeklynn Heights.csv to sentiment_analysis_results/Jeklynn Heights.csv
# Saved results for Ankh - Anniversary Edition.csv to sentiment_analysis_results/Ankh - Anniversary Edition.csv
# Saved results for Goetia.csv to sentiment_analysis_results/Goetia.csv
# Saved results for Trigger Runners.csv to sentiment_analysis_results/Trigger Runners.csv
# Saved results for The Evil Within.csv to sentiment_analysis_results/The Evil Within.csv
# Saved results for Alpha Runner.csv to sentiment_analysis_results/Alpha Runner.csv
# Saved results for Sniper Elite 3.csv to sentiment_analysis_results/Sniper Elite 3.csv
# Saved results for Earn to Die 2.csv to sentiment_analysis_results/Earn to Die 2.csv
# Saved results for Satellite Rush.csv to sentiment_analysis_results/Satellite Rush.csv
# Saved results for Dustbowl.csv to sentiment_analysis_results/Dustbowl.csv
# Saved results for The Rise of Chubtan.csv to sentiment_analysis_results/The Rise of Chubtan.csv
# Saved results for Youtubers Life.csv to sentiment_analysis_results/Youtubers Life.csv
# Saved results for Drawn: The Painted Tower.csv to sentiment_analysis_results/Drawn: The Painted Tower.csv
# Saved results for The Kings' Crusade.csv to sentiment_analysis_results/The Kings' Crusade.csv
# Saved results for Memoria.csv to sentiment_analysis_results/Memoria.csv
# Saved results for The Sun and Moon.csv to sentiment_analysis_results/The Sun and Moon.csv
# Saved results for Killbot.csv to sentiment_analysis_results/Killbot.csv
# Saved results for Corona MotorSport.csv to sentiment_analysis_results/Corona MotorSport.csv
# Saved results for Railroad Tycoon 3.csv to sentiment_analysis_results/Railroad Tycoon 3.csv
# Saved results for Mines of Mars.csv to sentiment_analysis_results/Mines of Mars.csv
# Saved results for Pub Encounter.csv to sentiment_analysis_results/Pub Encounter.csv
# Saved results for Brawlhalla.csv to sentiment_analysis_results/Brawlhalla.csv
# Saved results for Eldritch.csv to sentiment_analysis_results/Eldritch.csv
# Saved results for Escape This.csv to sentiment_analysis_results/Escape This.csv
# Saved results for Power & Revolution.csv to sentiment_analysis_results/Power & Revolution.csv
# Saved results for Zone 22.csv to sentiment_analysis_results/Zone 22.csv
# Saved results for Beat Hazard.csv to sentiment_analysis_results/Beat Hazard.csv
# Saved results for Zombasite.csv to sentiment_analysis_results/Zombasite.csv
# Saved results for Puzzle Cube.csv to sentiment_analysis_results/Puzzle Cube.csv
# Saved results for Motorcycle Club.csv to sentiment_analysis_results/Motorcycle Club.csv
# Saved results for Team Indie.csv to sentiment_analysis_results/Team Indie.csv
# Saved results for Fantastic Contraption.csv to sentiment_analysis_results/Fantastic Contraption.csv
# Saved results for Ahros: One warrior chronicle.csv to sentiment_analysis_results/Ahros: One warrior chronicle.csv
# Saved results for Ceres.csv to sentiment_analysis_results/Ceres.csv
# Saved results for Seduce Me the Otome.csv to sentiment_analysis_results/Seduce Me the Otome.csv
# Saved results for Sid Meier's Civilization III: Complete.csv to sentiment_analysis_results/Sid Meier's Civilization III: Complete.csv
# Saved results for Bik - A Space Adventure.csv to sentiment_analysis_results/Bik - A Space Adventure.csv
# Saved results for Dracula: The Resurrection.csv to sentiment_analysis_results/Dracula: The Resurrection.csv
# Saved results for Zezenia Online.csv to sentiment_analysis_results/Zezenia Online.csv
# Saved results for Chivalry: Medieval Warfare.csv to sentiment_analysis_results/Chivalry: Medieval Warfare.csv
# Saved results for Hardland.csv to sentiment_analysis_results/Hardland.csv
# Saved results for Judgement.csv to sentiment_analysis_results/Judgement.csv
# Saved results for Clash of Puppets.csv to sentiment_analysis_results/Clash of Puppets.csv
# Saved results for Obscuritas.csv to sentiment_analysis_results/Obscuritas.csv
# Saved results for Deus Ex: The Fall.csv to sentiment_analysis_results/Deus Ex: The Fall.csv
# Saved results for Mushroom 11.csv to sentiment_analysis_results/Mushroom 11.csv
# Saved results for Into the Dark.csv to sentiment_analysis_results/Into the Dark.csv
# Saved results for Entropy Rising.csv to sentiment_analysis_results/Entropy Rising.csv
# Saved results for Emily: Displaced.csv to sentiment_analysis_results/Emily: Displaced.csv
# Saved results for Hostile Waters: Antaeus Rising.csv to sentiment_analysis_results/Hostile Waters: Antaeus Rising.csv
# Saved results for Supreme Commander 2.csv to sentiment_analysis_results/Supreme Commander 2.csv
# Saved results for Oddworld: Abe's Oddysee.csv to sentiment_analysis_results/Oddworld: Abe's Oddysee.csv
# Saved results for Cards of Cthulhu.csv to sentiment_analysis_results/Cards of Cthulhu.csv
# Saved results for Alice's Patchwork.csv to sentiment_analysis_results/Alice's Patchwork.csv
# Saved results for Neon Space.csv to sentiment_analysis_results/Neon Space.csv
# Saved results for Final Exam.csv to sentiment_analysis_results/Final Exam.csv
# Saved results for Five Nights at Freddy's.csv to sentiment_analysis_results/Five Nights at Freddy's.csv
# Saved results for Diaries of a Spaceport Janitor.csv to sentiment_analysis_results/Diaries of a Spaceport Janitor.csv
# Saved results for Age of Survival.csv to sentiment_analysis_results/Age of Survival.csv
# Saved results for The Underground Man.csv to sentiment_analysis_results/The Underground Man.csv
# Saved results for Dark Fall 2: Lights Out.csv to sentiment_analysis_results/Dark Fall 2: Lights Out.csv
# Saved results for Deep Eclipse.csv to sentiment_analysis_results/Deep Eclipse.csv
# Saved results for Abalone.csv to sentiment_analysis_results/Abalone.csv
# Saved results for Whack a Vote: Hammering the Polls.csv to sentiment_analysis_results/Whack a Vote: Hammering the Polls.csv
# Saved results for TerraTech.csv to sentiment_analysis_results/TerraTech.csv
# Saved results for Crawlers and Brawlers.csv to sentiment_analysis_results/Crawlers and Brawlers.csv
# Saved results for Tales of Zestiria.csv to sentiment_analysis_results/Tales of Zestiria.csv
# Saved results for Bacteria.csv to sentiment_analysis_results/Bacteria.csv
# Saved results for Luna Sky.csv to sentiment_analysis_results/Luna Sky.csv
# Saved results for DLC Quest.csv to sentiment_analysis_results/DLC Quest.csv
# Saved results for Neocolonialism.csv to sentiment_analysis_results/Neocolonialism.csv
# Saved results for Last Will.csv to sentiment_analysis_results/Last Will.csv
# Saved results for Iron Fisticle.csv to sentiment_analysis_results/Iron Fisticle.csv
# Saved results for My Lady.csv to sentiment_analysis_results/My Lady.csv
# Saved results for Heroes of Might & Magic V: Hammers of Fate.csv to sentiment_analysis_results/Heroes of Might & Magic V: Hammers of Fate.csv
# Saved results for Forsaken Fortress Strategy.csv to sentiment_analysis_results/Forsaken Fortress Strategy.csv
# Saved results for Rampage Knights.csv to sentiment_analysis_results/Rampage Knights.csv
# Saved results for Perimeter.csv to sentiment_analysis_results/Perimeter.csv
# Saved results for Fibbage XL.csv to sentiment_analysis_results/Fibbage XL.csv
# Saved results for Ironclads: American Civil War.csv to sentiment_analysis_results/Ironclads: American Civil War.csv
# Saved results for Vektor Wars.csv to sentiment_analysis_results/Vektor Wars.csv
# Saved results for Viking Brothers.csv to sentiment_analysis_results/Viking Brothers.csv
# Saved results for Atlantis 2: Beyond Atlantis.csv to sentiment_analysis_results/Atlantis 2: Beyond Atlantis.csv
# Saved results for King Arthur II - The Role-playing Wargame.csv to sentiment_analysis_results/King Arthur II - The Role-playing Wargame.csv
# Saved results for Lance A Lot: Classic Edition.csv to sentiment_analysis_results/Lance A Lot: Classic Edition.csv
# Saved results for Sam & Max 201: Ice Station Santa.csv to sentiment_analysis_results/Sam & Max 201: Ice Station Santa.csv
# Saved results for BattleLore: Command.csv to sentiment_analysis_results/BattleLore: Command.csv
# Saved results for Samurai Gunn.csv to sentiment_analysis_results/Samurai Gunn.csv
# Saved results for Nancy Drew: Secret of the Old Clock.csv to sentiment_analysis_results/Nancy Drew: Secret of the Old Clock.csv
# Saved results for The 11th Hour.csv to sentiment_analysis_results/The 11th Hour.csv
# Saved results for BattleTime.csv to sentiment_analysis_results/BattleTime.csv
# Saved results for Fine China.csv to sentiment_analysis_results/Fine China.csv
# Saved results for Decisive Campaigns: The Blitzkrieg from Warsaw to Paris.csv to sentiment_analysis_results/Decisive Campaigns: The Blitzkrieg from Warsaw to Paris.csv
# Saved results for Vortex Attack.csv to sentiment_analysis_results/Vortex Attack.csv
# Saved results for Bejeweled 3.csv to sentiment_analysis_results/Bejeweled 3.csv
# Saved results for Battletank LOBA.csv to sentiment_analysis_results/Battletank LOBA.csv
# Saved results for Draconian Wars.csv to sentiment_analysis_results/Draconian Wars.csv
# Saved results for Spooky Heroes.csv to sentiment_analysis_results/Spooky Heroes.csv
# Saved results for Warriors of Vilvatikta.csv to sentiment_analysis_results/Warriors of Vilvatikta.csv
# Saved results for Unity of Command.csv to sentiment_analysis_results/Unity of Command.csv
# Saved results for Crazy Taxi.csv to sentiment_analysis_results/Crazy Taxi.csv
# Saved results for The Fifth Expedition.csv to sentiment_analysis_results/The Fifth Expedition.csv
# Saved results for Alcatraz Builder.csv to sentiment_analysis_results/Alcatraz Builder.csv
# Saved results for Survival VR.csv to sentiment_analysis_results/Survival VR.csv
# Saved results for GemBreak.csv to sentiment_analysis_results/GemBreak.csv
# Saved results for Wheels of Aurelia.csv to sentiment_analysis_results/Wheels of Aurelia.csv
# Saved results for LOVE.csv to sentiment_analysis_results/LOVE.csv
# Saved results for Boson X.csv to sentiment_analysis_results/Boson X.csv
# Saved results for Constricting Cubes.csv to sentiment_analysis_results/Constricting Cubes.csv
# Saved results for Stars.csv to sentiment_analysis_results/Stars.csv
# Saved results for Strong Bad Episode 1: Homestar Ruiner.csv to sentiment_analysis_results/Strong Bad Episode 1: Homestar Ruiner.csv
# Saved results for Sid Meier's Starships.csv to sentiment_analysis_results/Sid Meier's Starships.csv
# Saved results for MagixHome VR.csv to sentiment_analysis_results/MagixHome VR.csv
# Saved results for Dungeon Crawlers HD.csv to sentiment_analysis_results/Dungeon Crawlers HD.csv
# Saved results for Platformines.csv to sentiment_analysis_results/Platformines.csv
# Saved results for WARMODE.csv to sentiment_analysis_results/WARMODE.csv
# Saved results for Inside My Radio.csv to sentiment_analysis_results/Inside My Radio.csv
# Saved results for Boneless Zombie.csv to sentiment_analysis_results/Boneless Zombie.csv
# Saved results for MOAI 3: Trade Mission Collector's Edition.csv to sentiment_analysis_results/MOAI 3: Trade Mission Collector's Edition.csv
# Saved results for Fort Defense.csv to sentiment_analysis_results/Fort Defense.csv
# Saved results for Eschalon: Book 1.csv to sentiment_analysis_results/Eschalon: Book 1.csv
# Saved results for Scarab Tales.csv to sentiment_analysis_results/Scarab Tales.csv
# Saved results for Sherlock Holmes Consulting Detective: The Case of the Tin Soldier.csv to sentiment_analysis_results/Sherlock Holmes Consulting Detective: The Case of the Tin Soldier.csv
# Saved results for Blackwell Deception.csv to sentiment_analysis_results/Blackwell Deception.csv
# Saved results for Plankton.csv to sentiment_analysis_results/Plankton.csv
# Saved results for iPi Recorder 2.csv to sentiment_analysis_results/iPi Recorder 2.csv
# Saved results for Dark Void.csv to sentiment_analysis_results/Dark Void.csv
# Saved results for Lost girl`s [diary].csv to sentiment_analysis_results/Lost girl`s [diary].csv
# Saved results for The Witch's Yarn.csv to sentiment_analysis_results/The Witch's Yarn.csv
# Saved results for X-COM: Enforcer.csv to sentiment_analysis_results/X-COM: Enforcer.csv
# Saved results for Amygdala.csv to sentiment_analysis_results/Amygdala.csv
# Saved results for CONSORTIUM.csv to sentiment_analysis_results/CONSORTIUM.csv
# Saved results for Rock 'N' Roll Defense.csv to sentiment_analysis_results/Rock 'N' Roll Defense.csv
# Saved results for Let's Eat! Seaside Cafe.csv to sentiment_analysis_results/Let's Eat! Seaside Cafe.csv
# Saved results for MilitAnt.csv to sentiment_analysis_results/MilitAnt.csv
# Saved results for Galagan's Island: Reprymian Rising.csv to sentiment_analysis_results/Galagan's Island: Reprymian Rising.csv
# Saved results for Teddy Floppy Ear - Kayaking.csv to sentiment_analysis_results/Teddy Floppy Ear - Kayaking.csv
# Saved results for GT Legends.csv to sentiment_analysis_results/GT Legends.csv
# Saved results for Plants vs. Zombies: Game of the Year.csv to sentiment_analysis_results/Plants vs. Zombies: Game of the Year.csv
# Saved results for NBA 2K16.csv to sentiment_analysis_results/NBA 2K16.csv
# Saved results for Blender.csv to sentiment_analysis_results/Blender.csv
# Saved results for Dragon Saga.csv to sentiment_analysis_results/Dragon Saga.csv
# Saved results for Fairies vs. Darklings: Arcane Edition.csv to sentiment_analysis_results/Fairies vs. Darklings: Arcane Edition.csv
# Saved results for Flat Path.csv to sentiment_analysis_results/Flat Path.csv
# Saved results for Serial Cleaner.csv to sentiment_analysis_results/Serial Cleaner.csv
# Saved results for Peggle Extreme.csv to sentiment_analysis_results/Peggle Extreme.csv
# Saved results for Breakout Invaders.csv to sentiment_analysis_results/Breakout Invaders.csv
# Saved results for Yumsters! 2: Around the World!.csv to sentiment_analysis_results/Yumsters! 2: Around the World!.csv
# Saved results for Toonstruck.csv to sentiment_analysis_results/Toonstruck.csv
# Saved results for UFO Online: Invasion.csv to sentiment_analysis_results/UFO Online: Invasion.csv
# Saved results for Planet Coaster.csv to sentiment_analysis_results/Planet Coaster.csv
# Saved results for Spirit Of War.csv to sentiment_analysis_results/Spirit Of War.csv
# Saved results for Putt-Putt and Pep's Balloon-o-Rama.csv to sentiment_analysis_results/Putt-Putt and Pep's Balloon-o-Rama.csv
# Saved results for Darwinia.csv to sentiment_analysis_results/Darwinia.csv
# Saved results for Polynomial 2.csv to sentiment_analysis_results/Polynomial 2.csv
# Saved results for Time Rifters.csv to sentiment_analysis_results/Time Rifters.csv
# Saved results for Obscure.csv to sentiment_analysis_results/Obscure.csv
# Saved results for Ke-Tsu-No-Ana.csv to sentiment_analysis_results/Ke-Tsu-No-Ana.csv
# Saved results for eden - 3D Screensaver.csv to sentiment_analysis_results/eden - 3D Screensaver.csv
# Saved results for STAR WARS™: X-Wing Special Edition.csv to sentiment_analysis_results/STAR WARS™: X-Wing Special Edition.csv
# Saved results for Sniper Ghost Warrior 2.csv to sentiment_analysis_results/Sniper Ghost Warrior 2.csv
# Saved results for Philia : the Sequel to Elansar.csv to sentiment_analysis_results/Philia : the Sequel to Elansar.csv
# Saved results for Vanguards.csv to sentiment_analysis_results/Vanguards.csv
# Saved results for Breezeblox.csv to sentiment_analysis_results/Breezeblox.csv
# Saved results for Pirate Hell.csv to sentiment_analysis_results/Pirate Hell.csv
# Saved results for My Tribe .csv to sentiment_analysis_results/My Tribe .csv
# Saved results for Eradicator.csv to sentiment_analysis_results/Eradicator.csv
# Saved results for Planetoid Pioneers.csv to sentiment_analysis_results/Planetoid Pioneers.csv
# Saved results for Keen Dreams.csv to sentiment_analysis_results/Keen Dreams.csv
# Saved results for Sickness.csv to sentiment_analysis_results/Sickness.csv
# Saved results for Baseball Mogul 2015.csv to sentiment_analysis_results/Baseball Mogul 2015.csv
# Saved results for Trace Vector.csv to sentiment_analysis_results/Trace Vector.csv
# Saved results for 5089: The Action RPG.csv to sentiment_analysis_results/5089: The Action RPG.csv
# Saved results for Devil's Bluff.csv to sentiment_analysis_results/Devil's Bluff.csv
# Saved results for Amazing Adventures Around the World.csv to sentiment_analysis_results/Amazing Adventures Around the World.csv
# Saved results for Three Heroes.csv to sentiment_analysis_results/Three Heroes.csv
# Saved results for Inside The Code.csv to sentiment_analysis_results/Inside The Code.csv
# Saved results for Chicken Little.csv to sentiment_analysis_results/Chicken Little.csv
# Saved results for The Wizard's Pen.csv to sentiment_analysis_results/The Wizard's Pen.csv
# Saved results for Hollywood Visionary.csv to sentiment_analysis_results/Hollywood Visionary.csv
# Saved results for CRAPPY ZOMBIE GAME.csv to sentiment_analysis_results/CRAPPY ZOMBIE GAME.csv
# Saved results for Sam & Max 301: The Penal Zone.csv to sentiment_analysis_results/Sam & Max 301: The Penal Zone.csv
# Saved results for Zombillie.csv to sentiment_analysis_results/Zombillie.csv
# Saved results for Astebreed: Definitive Edition.csv to sentiment_analysis_results/Astebreed: Definitive Edition.csv
# Saved results for One Small Fire At A Time.csv to sentiment_analysis_results/One Small Fire At A Time.csv
# Saved results for Tile Miner.csv to sentiment_analysis_results/Tile Miner.csv
# Saved results for ShareX.csv to sentiment_analysis_results/ShareX.csv
# Saved results for Shadowrun: Hong Kong - Extended Edition.csv to sentiment_analysis_results/Shadowrun: Hong Kong - Extended Edition.csv
# Saved results for Tales From The Dragon Mountain: The Strix.csv to sentiment_analysis_results/Tales From The Dragon Mountain: The Strix.csv
# Saved results for ASTROKILL.csv to sentiment_analysis_results/ASTROKILL.csv
# Saved results for Sniper Tactical.csv to sentiment_analysis_results/Sniper Tactical.csv
# Saved results for The Asskickers.csv to sentiment_analysis_results/The Asskickers.csv
# Saved results for BoomTown! Deluxe.csv to sentiment_analysis_results/BoomTown! Deluxe.csv
# Saved results for Sparkle 3 Genesis.csv to sentiment_analysis_results/Sparkle 3 Genesis.csv
# Saved results for Outlast.csv to sentiment_analysis_results/Outlast.csv
# Saved results for Tex Murphy: Overseer.csv to sentiment_analysis_results/Tex Murphy: Overseer.csv
# Saved results for Feeding Frenzy 2: Shipwreck Showdown Deluxe.csv to sentiment_analysis_results/Feeding Frenzy 2: Shipwreck Showdown Deluxe.csv
# Saved results for 80 Days.csv to sentiment_analysis_results/80 Days.csv
# Saved results for Sceelix - Procedural Power.csv to sentiment_analysis_results/Sceelix - Procedural Power.csv
# Saved results for Hover Hazard.csv to sentiment_analysis_results/Hover Hazard.csv
# Saved results for Spermination.csv to sentiment_analysis_results/Spermination.csv
# Saved results for Automobilista.csv to sentiment_analysis_results/Automobilista.csv
# Saved results for ENDLESS™ Space - Definitive Edition.csv to sentiment_analysis_results/ENDLESS™ Space - Definitive Edition.csv
# Saved results for Nancy Drew: Shadow at the Water's Edge.csv to sentiment_analysis_results/Nancy Drew: Shadow at the Water's Edge.csv
# Saved results for War Operations.csv to sentiment_analysis_results/War Operations.csv
# Saved results for Proxy Blade Zero.csv to sentiment_analysis_results/Proxy Blade Zero.csv
# Saved results for Make America Great Again.csv to sentiment_analysis_results/Make America Great Again.csv
# Saved results for Ninja Cats vs Samurai Dogs.csv to sentiment_analysis_results/Ninja Cats vs Samurai Dogs.csv
# Saved results for Catacomb Kids.csv to sentiment_analysis_results/Catacomb Kids.csv
# Saved results for Tex Murphy: Mean Streets.csv to sentiment_analysis_results/Tex Murphy: Mean Streets.csv
# Saved results for Killing Floor 2.csv to sentiment_analysis_results/Killing Floor 2.csv
# Saved results for Super Destronaut.csv to sentiment_analysis_results/Super Destronaut.csv
# Saved results for Pink Heaven.csv to sentiment_analysis_results/Pink Heaven.csv
# Saved results for KAMI.csv to sentiment_analysis_results/KAMI.csv
# Saved results for Samphi.csv to sentiment_analysis_results/Samphi.csv
# Saved results for Poly Runner VR.csv to sentiment_analysis_results/Poly Runner VR.csv
# Saved results for Don Bradman Cricket 14.csv to sentiment_analysis_results/Don Bradman Cricket 14.csv
# Saved results for Toribash.csv to sentiment_analysis_results/Toribash.csv
# Saved results for Maze Sounds.csv to sentiment_analysis_results/Maze Sounds.csv
# Saved results for Rambo The Video Game.csv to sentiment_analysis_results/Rambo The Video Game.csv
# Saved results for Shadow Ninja: Apocalypse.csv to sentiment_analysis_results/Shadow Ninja: Apocalypse.csv
# Saved results for Marble Mayhem: Fragile Ball.csv to sentiment_analysis_results/Marble Mayhem: Fragile Ball.csv
# Saved results for Riders of Icarus.csv to sentiment_analysis_results/Riders of Icarus.csv
# Saved results for Caveblazers.csv to sentiment_analysis_results/Caveblazers.csv
# Saved results for Mitsurugi Kamui Hikae.csv to sentiment_analysis_results/Mitsurugi Kamui Hikae.csv
# Saved results for Icebound.csv to sentiment_analysis_results/Icebound.csv
# Saved results for Finn and Jake's Epic Quest.csv to sentiment_analysis_results/Finn and Jake's Epic Quest.csv
# Saved results for Master of Orion 1.csv to sentiment_analysis_results/Master of Orion 1.csv
# Saved results for Quadrant.csv to sentiment_analysis_results/Quadrant.csv
# Saved results for Pacific Storm: Allies.csv to sentiment_analysis_results/Pacific Storm: Allies.csv
# Saved results for Double Dragon Neon.csv to sentiment_analysis_results/Double Dragon Neon.csv
# Saved results for Golf With Your Friends.csv to sentiment_analysis_results/Golf With Your Friends.csv
# Saved results for Clicker Heroes.csv to sentiment_analysis_results/Clicker Heroes.csv
# Saved results for Duck Dynasty.csv to sentiment_analysis_results/Duck Dynasty.csv
# Saved results for ShipLord.csv to sentiment_analysis_results/ShipLord.csv
# Saved results for Karma Miwa.csv to sentiment_analysis_results/Karma Miwa.csv
# Saved results for Cosmos Crash VR.csv to sentiment_analysis_results/Cosmos Crash VR.csv
# Saved results for Castaway Paradise.csv to sentiment_analysis_results/Castaway Paradise.csv
# Saved results for SWR JST DX Selective Memory Erase Effect.csv to sentiment_analysis_results/SWR JST DX Selective Memory Erase Effect.csv
# Saved results for Six Sides of the World.csv to sentiment_analysis_results/Six Sides of the World.csv
# Saved results for Holodrive.csv to sentiment_analysis_results/Holodrive.csv
# Saved results for Violett.csv to sentiment_analysis_results/Violett.csv
# Saved results for Ancient Go.csv to sentiment_analysis_results/Ancient Go.csv
# Saved results for Energy Hook.csv to sentiment_analysis_results/Energy Hook.csv
# Saved results for Egyptian Senet.csv to sentiment_analysis_results/Egyptian Senet.csv
# Saved results for The Light Empire.csv to sentiment_analysis_results/The Light Empire.csv
# Saved results for Phantasmagoria 2.csv to sentiment_analysis_results/Phantasmagoria 2.csv
# Saved results for Autumn.csv to sentiment_analysis_results/Autumn.csv
# Saved results for Feesh.csv to sentiment_analysis_results/Feesh.csv
# Saved results for VR Karts SteamVR.csv to sentiment_analysis_results/VR Karts SteamVR.csv
# Saved results for Solar Division.csv to sentiment_analysis_results/Solar Division.csv
# Saved results for Super Ubie Island REMIX.csv to sentiment_analysis_results/Super Ubie Island REMIX.csv
# Saved results for LEGO® The Lord of the Rings™.csv to sentiment_analysis_results/LEGO® The Lord of the Rings™.csv
# Saved results for Macabre.csv to sentiment_analysis_results/Macabre.csv
# Saved results for The Lost City Of Malathedra.csv to sentiment_analysis_results/The Lost City Of Malathedra.csv
# Saved results for Legend of Fae.csv to sentiment_analysis_results/Legend of Fae.csv
# Saved results for The Haunted: Hells Reach.csv to sentiment_analysis_results/The Haunted: Hells Reach.csv
# Saved results for TriBlaster.csv to sentiment_analysis_results/TriBlaster.csv
# Saved results for The Bottom of the Well.csv to sentiment_analysis_results/The Bottom of the Well.csv
# Saved results for Gravi.csv to sentiment_analysis_results/Gravi.csv
# Saved results for Voyage: Journey to the Moon.csv to sentiment_analysis_results/Voyage: Journey to the Moon.csv
# Saved results for Call of Juarez: The Cartel.csv to sentiment_analysis_results/Call of Juarez: The Cartel.csv
# Saved results for Empires.csv to sentiment_analysis_results/Empires.csv
# Saved results for Weapon of Choice.csv to sentiment_analysis_results/Weapon of Choice.csv
# Saved results for Karos.csv to sentiment_analysis_results/Karos.csv
# Saved results for Agent Walker: Secret Journey.csv to sentiment_analysis_results/Agent Walker: Secret Journey.csv
# Saved results for Threads of Destiny.csv to sentiment_analysis_results/Threads of Destiny.csv
# Saved results for Northmark: Hour of the Wolf.csv to sentiment_analysis_results/Northmark: Hour of the Wolf.csv
# Saved results for Frontlines: Fuel of War.csv to sentiment_analysis_results/Frontlines: Fuel of War.csv
# Saved results for Steel Storm: A.M.M.O..csv to sentiment_analysis_results/Steel Storm: A.M.M.O..csv
# Saved results for Stairs.csv to sentiment_analysis_results/Stairs.csv
# Saved results for The Crystal Nebula.csv to sentiment_analysis_results/The Crystal Nebula.csv
# Saved results for Grim Legends 3: The Dark City.csv to sentiment_analysis_results/Grim Legends 3: The Dark City.csv
# Saved results for Carmageddon Max Pack.csv to sentiment_analysis_results/Carmageddon Max Pack.csv
# Saved results for TableTop Cricket.csv to sentiment_analysis_results/TableTop Cricket.csv
# Saved results for Crash And Burn Racing.csv to sentiment_analysis_results/Crash And Burn Racing.csv
# Saved results for TOTM.csv to sentiment_analysis_results/TOTM.csv
# Saved results for Mission Runway.csv to sentiment_analysis_results/Mission Runway.csv
# Saved results for Wildlife Camp.csv to sentiment_analysis_results/Wildlife Camp.csv
# Saved results for Roogoo.csv to sentiment_analysis_results/Roogoo.csv
# Saved results for ENIGMA:.csv to sentiment_analysis_results/ENIGMA:.csv
# Saved results for EvilQuest.csv to sentiment_analysis_results/EvilQuest.csv
# Saved results for Tomb Raider I.csv to sentiment_analysis_results/Tomb Raider I.csv
# Saved results for CodeSpells.csv to sentiment_analysis_results/CodeSpells.csv
# Saved results for FATALE.csv to sentiment_analysis_results/FATALE.csv
# Saved results for Railroad Lines.csv to sentiment_analysis_results/Railroad Lines.csv
# Saved results for Color Assembler.csv to sentiment_analysis_results/Color Assembler.csv
# Saved results for DRAGON BALL XENOVERSE 2.csv to sentiment_analysis_results/DRAGON BALL XENOVERSE 2.csv
# Saved results for The Long Dark.csv to sentiment_analysis_results/The Long Dark.csv
# Saved results for Turmoil.csv to sentiment_analysis_results/Turmoil.csv
# Saved results for Aviator - Bush Pilot.csv to sentiment_analysis_results/Aviator - Bush Pilot.csv
# Saved results for QuestRun.csv to sentiment_analysis_results/QuestRun.csv
# Saved results for X-Plane 10 Global - 64 Bit.csv to sentiment_analysis_results/X-Plane 10 Global - 64 Bit.csv
# Saved results for Screencheat.csv to sentiment_analysis_results/Screencheat.csv
# Saved results for Rogue Legacy.csv to sentiment_analysis_results/Rogue Legacy.csv
# Saved results for Feudalism.csv to sentiment_analysis_results/Feudalism.csv
# Saved results for Battle Forever.csv to sentiment_analysis_results/Battle Forever.csv
# Saved results for Battle Dome.csv to sentiment_analysis_results/Battle Dome.csv
# Saved results for Azure Striker Gunvolt.csv to sentiment_analysis_results/Azure Striker Gunvolt.csv
# Saved results for Diehard Dungeon.csv to sentiment_analysis_results/Diehard Dungeon.csv
# Saved results for Book of Demons.csv to sentiment_analysis_results/Book of Demons.csv
# Saved results for SOL: Exodus.csv to sentiment_analysis_results/SOL: Exodus.csv
# Saved results for The Emerald Maiden: Symphony of Dreams.csv to sentiment_analysis_results/The Emerald Maiden: Symphony of Dreams.csv
# Saved results for Cyber Sentinel.csv to sentiment_analysis_results/Cyber Sentinel.csv
# Saved results for Crystal Chip Collector.csv to sentiment_analysis_results/Crystal Chip Collector.csv
# Saved results for Into Blue Valley.csv to sentiment_analysis_results/Into Blue Valley.csv
# Saved results for Liftoff.csv to sentiment_analysis_results/Liftoff.csv
# Saved results for The Hole Story.csv to sentiment_analysis_results/The Hole Story.csv
# Saved results for Dyad.csv to sentiment_analysis_results/Dyad.csv
# Saved results for Half-Life 2: Episode One.csv to sentiment_analysis_results/Half-Life 2: Episode One.csv
# Saved results for Car Mechanic Manager.csv to sentiment_analysis_results/Car Mechanic Manager.csv
# Saved results for Kill to Collect.csv to sentiment_analysis_results/Kill to Collect.csv
# Saved results for Command and Conquer: Red Alert 3 - Uprising.csv to sentiment_analysis_results/Command and Conquer: Red Alert 3 - Uprising.csv
# Saved results for No Turning Back: The Pixel Art Action-Adventure Roguelike.csv to sentiment_analysis_results/No Turning Back: The Pixel Art Action-Adventure Roguelike.csv
# Saved results for Sacred Citadel.csv to sentiment_analysis_results/Sacred Citadel.csv
# Saved results for Reigning Cats.csv to sentiment_analysis_results/Reigning Cats.csv
# Saved results for Signal Ops.csv to sentiment_analysis_results/Signal Ops.csv
# Saved results for Card City Nights.csv to sentiment_analysis_results/Card City Nights.csv
# Saved results for Ultimate General: Gettysburg.csv to sentiment_analysis_results/Ultimate General: Gettysburg.csv
# Saved results for Walkover.csv to sentiment_analysis_results/Walkover.csv
# Saved results for FORGOTTEN BALL.csv to sentiment_analysis_results/FORGOTTEN BALL.csv
# Saved results for Square Heroes.csv to sentiment_analysis_results/Square Heroes.csv
# Saved results for Karma. Incarnation 1.csv to sentiment_analysis_results/Karma. Incarnation 1.csv
# Saved results for Nexus : One Core.csv to sentiment_analysis_results/Nexus : One Core.csv
# Saved results for Lapland Solitaire.csv to sentiment_analysis_results/Lapland Solitaire.csv
# Saved results for Life Goes On.csv to sentiment_analysis_results/Life Goes On.csv
# Saved results for Vector Strain.csv to sentiment_analysis_results/Vector Strain.csv
# Saved results for Link: The Unleashed Nexus.csv to sentiment_analysis_results/Link: The Unleashed Nexus.csv
# Saved results for Purino Party.csv to sentiment_analysis_results/Purino Party.csv
# Saved results for Hardware Engineers.csv to sentiment_analysis_results/Hardware Engineers.csv
# Saved results for The Black Watchmen.csv to sentiment_analysis_results/The Black Watchmen.csv
# Saved results for Jagged Alliance - Back in Action.csv to sentiment_analysis_results/Jagged Alliance - Back in Action.csv
# Saved results for Sym.csv to sentiment_analysis_results/Sym.csv
# Saved results for Nancy Drew Dossier: Resorting to Danger!.csv to sentiment_analysis_results/Nancy Drew Dossier: Resorting to Danger!.csv
# Saved results for Truffle Saga.csv to sentiment_analysis_results/Truffle Saga.csv
# Saved results for A Stroke of Fate: Operation Bunker.csv to sentiment_analysis_results/A Stroke of Fate: Operation Bunker.csv
# Saved results for Sacred 3.csv to sentiment_analysis_results/Sacred 3.csv
# Saved results for A-Gents.csv to sentiment_analysis_results/A-Gents.csv
# Saved results for All My Gods.csv to sentiment_analysis_results/All My Gods.csv
# Saved results for Alien Shooter.csv to sentiment_analysis_results/Alien Shooter.csv
# Saved results for Starr Mazer: DSP.csv to sentiment_analysis_results/Starr Mazer: DSP.csv
# Saved results for Last Days of Spring 2.csv to sentiment_analysis_results/Last Days of Spring 2.csv
# Saved results for Disciples II: Rise of the Elves.csv to sentiment_analysis_results/Disciples II: Rise of the Elves.csv
# Saved results for Armored Hunter GUNHOUND EX.csv to sentiment_analysis_results/Armored Hunter GUNHOUND EX.csv
# Saved results for Sakura Fantasy Chapter 1.csv to sentiment_analysis_results/Sakura Fantasy Chapter 1.csv
# Saved results for 1Heart.csv to sentiment_analysis_results/1Heart.csv
# Saved results for Lords of the Realm II.csv to sentiment_analysis_results/Lords of the Realm II.csv
# Saved results for Ratings War.csv to sentiment_analysis_results/Ratings War.csv
# Saved results for Zavix Tower.csv to sentiment_analysis_results/Zavix Tower.csv
# Saved results for Down To One.csv to sentiment_analysis_results/Down To One.csv
# Saved results for Plug & Play.csv to sentiment_analysis_results/Plug & Play.csv
# Saved results for Darkstone.csv to sentiment_analysis_results/Darkstone.csv
# Saved results for Bloons TD Battles.csv to sentiment_analysis_results/Bloons TD Battles.csv
# Saved results for Badland Bandits.csv to sentiment_analysis_results/Badland Bandits.csv
# Saved results for My Lands.csv to sentiment_analysis_results/My Lands.csv
# Saved results for BRINK.csv to sentiment_analysis_results/BRINK.csv
# Saved results for World of Diving.csv to sentiment_analysis_results/World of Diving.csv
# Saved results for Bloo Kid 2.csv to sentiment_analysis_results/Bloo Kid 2.csv
# Saved results for EPΘCH.csv to sentiment_analysis_results/EPΘCH.csv
# Saved results for Depth Hunter 2: Deep Dive.csv to sentiment_analysis_results/Depth Hunter 2: Deep Dive.csv
# Saved results for Mars Colony: Challenger.csv to sentiment_analysis_results/Mars Colony: Challenger.csv
# Saved results for Jagged Alliance: Crossfire.csv to sentiment_analysis_results/Jagged Alliance: Crossfire.csv
# Saved results for Control Craft 2.csv to sentiment_analysis_results/Control Craft 2.csv
# Saved results for Air Missions: HIND.csv to sentiment_analysis_results/Air Missions: HIND.csv
# Saved results for Kaboom Monsters.csv to sentiment_analysis_results/Kaboom Monsters.csv
# Saved results for Amnesia™: Memories.csv to sentiment_analysis_results/Amnesia™: Memories.csv
# Saved results for Defend Your Life.csv to sentiment_analysis_results/Defend Your Life.csv
# Saved results for 140.csv to sentiment_analysis_results/140.csv
# Saved results for The Emptiness Deluxe Edition.csv to sentiment_analysis_results/The Emptiness Deluxe Edition.csv
# Saved results for Blues and Bullets.csv to sentiment_analysis_results/Blues and Bullets.csv
# Saved results for Evolution VR.csv to sentiment_analysis_results/Evolution VR.csv
# Saved results for Pharaonic.csv to sentiment_analysis_results/Pharaonic.csv
# Saved results for Guacamelee! Super Turbo Championship Edition.csv to sentiment_analysis_results/Guacamelee! Super Turbo Championship Edition.csv
# Saved results for Flyhunter Origins.csv to sentiment_analysis_results/Flyhunter Origins.csv
# Saved results for Theatre of War.csv to sentiment_analysis_results/Theatre of War.csv
# Saved results for Professor Why™: The Quantum Eye.csv to sentiment_analysis_results/Professor Why™: The Quantum Eye.csv
# Saved results for Farm Frenzy Pizza Party.csv to sentiment_analysis_results/Farm Frenzy Pizza Party.csv
# Saved results for Baldur's Gate: Enhanced Edition.csv to sentiment_analysis_results/Baldur's Gate: Enhanced Edition.csv
# Saved results for Game Tycoon 2.csv to sentiment_analysis_results/Game Tycoon 2.csv
# Saved results for Star Horizon.csv to sentiment_analysis_results/Star Horizon.csv
# Saved results for LostWinds.csv to sentiment_analysis_results/LostWinds.csv
# Saved results for Hieroglyphika.csv to sentiment_analysis_results/Hieroglyphika.csv
# Saved results for Lost Chronicles of Zerzura.csv to sentiment_analysis_results/Lost Chronicles of Zerzura.csv
# Saved results for Crazy Steam Bros 2.csv to sentiment_analysis_results/Crazy Steam Bros 2.csv
# Saved results for BloodNet.csv to sentiment_analysis_results/BloodNet.csv
# Saved results for Star Realms.csv to sentiment_analysis_results/Star Realms.csv
# Saved results for Blade Symphony.csv to sentiment_analysis_results/Blade Symphony.csv
# Saved results for Maia.csv to sentiment_analysis_results/Maia.csv
# Saved results for The Last Sniper VR.csv to sentiment_analysis_results/The Last Sniper VR.csv
# Saved results for Zup!.csv to sentiment_analysis_results/Zup!.csv
# Saved results for S.T.A.L.K.E.R.: Clear Sky.csv to sentiment_analysis_results/S.T.A.L.K.E.R.: Clear Sky.csv
# Saved results for Farm Frenzy 4.csv to sentiment_analysis_results/Farm Frenzy 4.csv
# Saved results for StarsOne.csv to sentiment_analysis_results/StarsOne.csv
# Saved results for Monster Bash.csv to sentiment_analysis_results/Monster Bash.csv
# Saved results for Gravity Badgers.csv to sentiment_analysis_results/Gravity Badgers.csv
# Saved results for VR Boxing Workout.csv to sentiment_analysis_results/VR Boxing Workout.csv
# Saved results for ProtoGalaxy.csv to sentiment_analysis_results/ProtoGalaxy.csv
# Saved results for Greed: Black Border.csv to sentiment_analysis_results/Greed: Black Border.csv
# Saved results for Spellcrafter.csv to sentiment_analysis_results/Spellcrafter.csv
# Saved results for Lost Labyrinth Extended Version.csv to sentiment_analysis_results/Lost Labyrinth Extended Version.csv
# Saved results for Let Hawaii Happen VR.csv to sentiment_analysis_results/Let Hawaii Happen VR.csv
# Saved results for 99 Spirits.csv to sentiment_analysis_results/99 Spirits.csv
# Saved results for Attractio.csv to sentiment_analysis_results/Attractio.csv
# Saved results for PD Howler 10.csv to sentiment_analysis_results/PD Howler 10.csv
# Saved results for Hot Wheels™ World's Best Driver™.csv to sentiment_analysis_results/Hot Wheels™ World's Best Driver™.csv
# Saved results for Paganitzu.csv to sentiment_analysis_results/Paganitzu.csv
# Saved results for HordeZ.csv to sentiment_analysis_results/HordeZ.csv
# Saved results for Lead and Gold - Gangs of the Wild West.csv to sentiment_analysis_results/Lead and Gold - Gangs of the Wild West.csv
# Saved results for Poker Superstars II.csv to sentiment_analysis_results/Poker Superstars II.csv
# Saved results for Viktor.csv to sentiment_analysis_results/Viktor.csv
# Saved results for Rogue Operatives.csv to sentiment_analysis_results/Rogue Operatives.csv
# Saved results for NAM.csv to sentiment_analysis_results/NAM.csv
# Saved results for GALAK-Z.csv to sentiment_analysis_results/GALAK-Z.csv
# Saved results for Okhlos: Omega.csv to sentiment_analysis_results/Okhlos: Omega.csv
# Saved results for Actual Multiple Monitors.csv to sentiment_analysis_results/Actual Multiple Monitors.csv
# Saved results for Gyrodisc Super League.csv to sentiment_analysis_results/Gyrodisc Super League.csv
# Saved results for A.R.E.S. Extinction Agenda EX.csv to sentiment_analysis_results/A.R.E.S. Extinction Agenda EX.csv
# Saved results for Sakura Shrine Girls.csv to sentiment_analysis_results/Sakura Shrine Girls.csv
# Saved results for Alter Ego.csv to sentiment_analysis_results/Alter Ego.csv
# Saved results for Airport Madness 3D.csv to sentiment_analysis_results/Airport Madness 3D.csv
# Saved results for Two Steps Back.csv to sentiment_analysis_results/Two Steps Back.csv
# Saved results for My Pet Hotel 2.csv to sentiment_analysis_results/My Pet Hotel 2.csv
# Saved results for F.E.A.R. 3.csv to sentiment_analysis_results/F.E.A.R. 3.csv
# Saved results for Potato Thriller Steamed Potato Edition.csv to sentiment_analysis_results/Potato Thriller Steamed Potato Edition.csv
# Saved results for Bomb U!.csv to sentiment_analysis_results/Bomb U!.csv
# Saved results for Cute Things Dying Violently.csv to sentiment_analysis_results/Cute Things Dying Violently.csv
# Saved results for King's Bounty: Armored Princess.csv to sentiment_analysis_results/King's Bounty: Armored Princess.csv
# Saved results for Lords of the Realm.csv to sentiment_analysis_results/Lords of the Realm.csv
# Saved results for Plant Fire Department - The Simulation.csv to sentiment_analysis_results/Plant Fire Department - The Simulation.csv
# Saved results for Zeuxis : procedural texture generator.csv to sentiment_analysis_results/Zeuxis : procedural texture generator.csv
# Saved results for Millennium 5 - The Battle of the Millennium.csv to sentiment_analysis_results/Millennium 5 - The Battle of the Millennium.csv
# Saved results for Deadlings - Rotten Edition.csv to sentiment_analysis_results/Deadlings - Rotten Edition.csv
# Saved results for Project: Snowblind.csv to sentiment_analysis_results/Project: Snowblind.csv
# Saved results for Eador. Imperium.csv to sentiment_analysis_results/Eador. Imperium.csv
# Saved results for Big Fish Legend.csv to sentiment_analysis_results/Big Fish Legend.csv
# Saved results for The Shape Of Heart.csv to sentiment_analysis_results/The Shape Of Heart.csv
# Saved results for Gunpowder.csv to sentiment_analysis_results/Gunpowder.csv
# Saved results for inSynch.csv to sentiment_analysis_results/inSynch.csv
# Saved results for Typer Shark! Deluxe.csv to sentiment_analysis_results/Typer Shark! Deluxe.csv
# Saved results for Headlander.csv to sentiment_analysis_results/Headlander.csv
# Saved results for Knight Adventure.csv to sentiment_analysis_results/Knight Adventure.csv
# Saved results for Stormworm+.csv to sentiment_analysis_results/Stormworm+.csv
# Saved results for Pixel Cup Soccer 17.csv to sentiment_analysis_results/Pixel Cup Soccer 17.csv
# Saved results for Pony Island.csv to sentiment_analysis_results/Pony Island.csv
# Saved results for Crown and Council.csv to sentiment_analysis_results/Crown and Council.csv
# Saved results for MoW: Face Off M.csv to sentiment_analysis_results/MoW: Face Off M.csv
# Saved results for Lectrovolt II.csv to sentiment_analysis_results/Lectrovolt II.csv
# Saved results for Cosmic Sugar VR.csv to sentiment_analysis_results/Cosmic Sugar VR.csv
# Saved results for X-Tension.csv to sentiment_analysis_results/X-Tension.csv
# Saved results for Jagged Alliance Gold.csv to sentiment_analysis_results/Jagged Alliance Gold.csv
# Saved results for 拯救大魔王2 Rescue the Great Demon 2.csv to sentiment_analysis_results/拯救大魔王2 Rescue the Great Demon 2.csv
# Saved results for Rytmik Lite Chiptune Synthesizer.csv to sentiment_analysis_results/Rytmik Lite Chiptune Synthesizer.csv
# Saved results for You Must Build A Boat.csv to sentiment_analysis_results/You Must Build A Boat.csv
# Saved results for VirZOOM Arcade.csv to sentiment_analysis_results/VirZOOM Arcade.csv
# Saved results for VROOM: Aerie.csv to sentiment_analysis_results/VROOM: Aerie.csv
# Saved results for BitMaster.csv to sentiment_analysis_results/BitMaster.csv
# Saved results for Cubemen.csv to sentiment_analysis_results/Cubemen.csv
# Saved results for 9.03m.csv to sentiment_analysis_results/9.03m.csv
# Saved results for Blackguards 2.csv to sentiment_analysis_results/Blackguards 2.csv
# Saved results for MASSIVE CHALICE.csv to sentiment_analysis_results/MASSIVE CHALICE.csv
# Saved results for Euro Truck Simulator 2.csv to sentiment_analysis_results/Euro Truck Simulator 2.csv
# Saved results for Haegemonia: The Solon Heritage.csv to sentiment_analysis_results/Haegemonia: The Solon Heritage.csv
# Saved results for Riff Racer.csv to sentiment_analysis_results/Riff Racer.csv
# Saved results for NewRetroArcade: Neon.csv to sentiment_analysis_results/NewRetroArcade: Neon.csv
# ...
# Saved results for boxlife.csv to sentiment_analysis_results/boxlife.csv
# Saved results for The chronicles of Emerland. Solitaire..csv to sentiment_analysis_results/The chronicles of Emerland. Solitaire..csv
# Saved results for DUO.csv to sentiment_analysis_results/DUO.csv
# Saved results for Cave Story+.csv to sentiment_analysis_results/Cave Story+.csv
# Saved results for Energy Balance.csv to sentiment_analysis_results/Energy Balance.csv
# Saved results for IACTURA.csv to sentiment_analysis_results/IACTURA.csv
# Saved results for Happy Empire.csv to sentiment_analysis_results/Happy Empire.csv
# Saved results for Astroflux.csv to sentiment_analysis_results/Astroflux.csv
# Saved results for Terraformer Expedition to Mars.csv to sentiment_analysis_results/Terraformer Expedition to Mars.csv
# Saved results for PataNoir.csv to sentiment_analysis_results/PataNoir.csv
# Saved results for vrAMP.csv to sentiment_analysis_results/vrAMP.csv
# Saved results for Sherlock Holmes Consulting Detective: The Case of the Mummy’s Curse.csv to sentiment_analysis_results/Sherlock Holmes Consulting Detective: The Case of the Mummy’s Curse.csv
# Saved results for MC Lars: The Video Game.csv to sentiment_analysis_results/MC Lars: The Video Game.csv
# Saved results for The Typing of The Dead: Overkill.csv to sentiment_analysis_results/The Typing of The Dead: Overkill.csv
# Saved results for Shadows on the Vatican - Act I: Greed.csv to sentiment_analysis_results/Shadows on the Vatican - Act I: Greed.csv
# Saved results for Bigscreen Beta.csv to sentiment_analysis_results/Bigscreen Beta.csv
# Saved results for My Family Creative Studio.csv to sentiment_analysis_results/My Family Creative Studio.csv
# Saved results for Samurai of Hyuga Book 2.csv to sentiment_analysis_results/Samurai of Hyuga Book 2.csv
# Saved results for Blockships.csv to sentiment_analysis_results/Blockships.csv
# Saved results for The Charnel House Trilogy.csv to sentiment_analysis_results/The Charnel House Trilogy.csv
# Saved results for 16bit Trader.csv to sentiment_analysis_results/16bit Trader.csv
# Saved results for Sunrider: Liberation Day - Captain's Edition.csv to sentiment_analysis_results/Sunrider: Liberation Day - Captain's Edition.csv
# Saved results for Tick: The Time Based Puzzle Game.csv to sentiment_analysis_results/Tick: The Time Based Puzzle Game.csv
# Saved results for Ghostbusters.csv to sentiment_analysis_results/Ghostbusters.csv
# Saved results for LEGO® Pirates of the Caribbean The Video Game.csv to sentiment_analysis_results/LEGO® Pirates of the Caribbean The Video Game.csv
# Saved results for Scribble Space.csv to sentiment_analysis_results/Scribble Space.csv
# Saved results for RaidersSphere4th.csv to sentiment_analysis_results/RaidersSphere4th.csv
# Saved results for Pixel Survivors.csv to sentiment_analysis_results/Pixel Survivors.csv
# Saved results for Where's My Helmet?.csv to sentiment_analysis_results/Where's My Helmet?.csv
# Saved results for Will of the Gods.csv to sentiment_analysis_results/Will of the Gods.csv
# Saved results for Stick RPG 2.csv to sentiment_analysis_results/Stick RPG 2.csv
# Saved results for Prompt.csv to sentiment_analysis_results/Prompt.csv
# Saved results for Pushcat.csv to sentiment_analysis_results/Pushcat.csv
# Saved results for Ant Queen.csv to sentiment_analysis_results/Ant Queen.csv
# Saved results for Janky Tanks.csv to sentiment_analysis_results/Janky Tanks.csv
# Saved results for Racecar.io.csv to sentiment_analysis_results/Racecar.io.csv
# Saved results for Dusty Revenge.csv to sentiment_analysis_results/Dusty Revenge.csv
# Saved results for Zen of Sudoku.csv to sentiment_analysis_results/Zen of Sudoku.csv
# Saved results for BlackSmith HIT.csv to sentiment_analysis_results/BlackSmith HIT.csv
# Saved results for Road to Ballhalla.csv to sentiment_analysis_results/Road to Ballhalla.csv
# Saved results for Among the Sleep.csv to sentiment_analysis_results/Among the Sleep.csv
# Saved results for The Viceroy.csv to sentiment_analysis_results/The Viceroy.csv
# Saved results for TRI: Of Friendship and Madness.csv to sentiment_analysis_results/TRI: Of Friendship and Madness.csv
# Saved results for Paranormal.csv to sentiment_analysis_results/Paranormal.csv
# Saved results for Cosmic Dust & Rust.csv to sentiment_analysis_results/Cosmic Dust & Rust.csv
# Saved results for One Day : The Sun Disappeared.csv to sentiment_analysis_results/One Day : The Sun Disappeared.csv
# Saved results for Pinball FX2 VR.csv to sentiment_analysis_results/Pinball FX2 VR.csv
# Saved results for Build-A-Lot.csv to sentiment_analysis_results/Build-A-Lot.csv
# Saved results for Logic Missile.csv to sentiment_analysis_results/Logic Missile.csv
# Saved results for EvilMaze.csv to sentiment_analysis_results/EvilMaze.csv
# Saved results for Graviteam Tactics: Mius-Front.csv to sentiment_analysis_results/Graviteam Tactics: Mius-Front.csv
# Saved results for Drox Operative.csv to sentiment_analysis_results/Drox Operative.csv
# Saved results for Oniris Basket VR.csv to sentiment_analysis_results/Oniris Basket VR.csv
# Saved results for NEKOPARA Vol. 1.csv to sentiment_analysis_results/NEKOPARA Vol. 1.csv
# Saved results for Versus Squad.csv to sentiment_analysis_results/Versus Squad.csv
# Saved results for Bridge Constructor Stunts.csv to sentiment_analysis_results/Bridge Constructor Stunts.csv
# Saved results for Ravensword: Shadowlands.csv to sentiment_analysis_results/Ravensword: Shadowlands.csv
# Saved results for Time Machine VR.csv to sentiment_analysis_results/Time Machine VR.csv
# Saved results for The Treasures of Montezuma 3.csv to sentiment_analysis_results/The Treasures of Montezuma 3.csv
# Saved results for Womb Room.csv to sentiment_analysis_results/Womb Room.csv
# Saved results for Black Mirror III.csv to sentiment_analysis_results/Black Mirror III.csv
# Saved results for Secret Agent.csv to sentiment_analysis_results/Secret Agent.csv
# Saved results for Motte Island.csv to sentiment_analysis_results/Motte Island.csv
# Saved results for AdventureQuest 3D.csv to sentiment_analysis_results/AdventureQuest 3D.csv
# Saved results for Obscure 2.csv to sentiment_analysis_results/Obscure 2.csv
# Saved results for AntharioN.csv to sentiment_analysis_results/AntharioN.csv
# Saved results for 8BitMMO.csv to sentiment_analysis_results/8BitMMO.csv
# Saved results for Phantom Brave PC.csv to sentiment_analysis_results/Phantom Brave PC.csv
# Saved results for Marine Park Empire.csv to sentiment_analysis_results/Marine Park Empire.csv
# Saved results for Nightbanes.csv to sentiment_analysis_results/Nightbanes.csv
# Saved results for Blaster Simulator.csv to sentiment_analysis_results/Blaster Simulator.csv
# Saved results for Dota 2.csv to sentiment_analysis_results/Dota 2.csv
# Saved results for Warhammer 40,000: Dawn of War II.csv to sentiment_analysis_results/Warhammer 40,000: Dawn of War II.csv
# Saved results for Elder Sign: Omens.csv to sentiment_analysis_results/Elder Sign: Omens.csv
# Saved results for Soundboxing.csv to sentiment_analysis_results/Soundboxing.csv
# Saved results for Killer is Dead.csv to sentiment_analysis_results/Killer is Dead.csv
# Saved results for Yomawari: Night Alone.csv to sentiment_analysis_results/Yomawari: Night Alone.csv
# Saved results for Iggle Pop! Deluxe.csv to sentiment_analysis_results/Iggle Pop! Deluxe.csv
# Saved results for Signs of Life.csv to sentiment_analysis_results/Signs of Life.csv
# Saved results for ArtRage 4.csv to sentiment_analysis_results/ArtRage 4.csv
# Saved results for Deadlock - Planetary Conquest.csv to sentiment_analysis_results/Deadlock - Planetary Conquest.csv
# Saved results for Christmas Adventure: Candy Storm.csv to sentiment_analysis_results/Christmas Adventure: Candy Storm.csv
# Saved results for Artifact Adventure.csv to sentiment_analysis_results/Artifact Adventure.csv
# Saved results for Dead Space.csv to sentiment_analysis_results/Dead Space.csv
# Saved results for Mountain Crime: Requital.csv to sentiment_analysis_results/Mountain Crime: Requital.csv
# Saved results for Expand.csv to sentiment_analysis_results/Expand.csv
# Saved results for Wings of Vi.csv to sentiment_analysis_results/Wings of Vi.csv
# Saved results for Of Guards And Thieves.csv to sentiment_analysis_results/Of Guards And Thieves.csv
# Saved results for MX vs. ATV Unleashed.csv to sentiment_analysis_results/MX vs. ATV Unleashed.csv
# Saved results for Town of Salem.csv to sentiment_analysis_results/Town of Salem.csv
# Saved results for Wayward Manor.csv to sentiment_analysis_results/Wayward Manor.csv
# Saved results for Submerged.csv to sentiment_analysis_results/Submerged.csv
# Saved results for Chronicles of Mystery: The Scorpio Ritual.csv to sentiment_analysis_results/Chronicles of Mystery: The Scorpio Ritual.csv
# Saved results for Spells 'n' Stuff.csv to sentiment_analysis_results/Spells 'n' Stuff.csv
# Saved results for Mobile Light Force.csv to sentiment_analysis_results/Mobile Light Force.csv
# Saved results for MOAI 2: Path to Another World.csv to sentiment_analysis_results/MOAI 2: Path to Another World.csv
# Saved results for YOU DON'T KNOW JACK Vol. 2.csv to sentiment_analysis_results/YOU DON'T KNOW JACK Vol. 2.csv
# Saved results for Sweezy Gunner.csv to sentiment_analysis_results/Sweezy Gunner.csv
# Saved results for Patrician III.csv to sentiment_analysis_results/Patrician III.csv
# Saved results for Quern - Undying Thoughts.csv to sentiment_analysis_results/Quern - Undying Thoughts.csv
# Saved results for Delicious! Pretty Girls Mahjong Solitaire.csv to sentiment_analysis_results/Delicious! Pretty Girls Mahjong Solitaire.csv
# Saved results for Anarcute.csv to sentiment_analysis_results/Anarcute.csv
# Saved results for To Be or Not To Be.csv to sentiment_analysis_results/To Be or Not To Be.csv
# Saved results for Oddworld: New 'n' Tasty.csv to sentiment_analysis_results/Oddworld: New 'n' Tasty.csv
# Saved results for Discovering Colors - Animals.csv to sentiment_analysis_results/Discovering Colors - Animals.csv
# Saved results for Snail Bob 2.csv to sentiment_analysis_results/Snail Bob 2.csv
# Saved results for City Play.csv to sentiment_analysis_results/City Play.csv
# Saved results for Batman - The Telltale Series.csv to sentiment_analysis_results/Batman - The Telltale Series.csv
# Saved results for The Life Of Greather.csv to sentiment_analysis_results/The Life Of Greather.csv
# Saved results for Midnight Mysteries: Witches of Abraham - Collector's Edition.csv to sentiment_analysis_results/Midnight Mysteries: Witches of Abraham - Collector's Edition.csv
# Saved results for Grid Legion, Storm.csv to sentiment_analysis_results/Grid Legion, Storm.csv
# Saved results for Caves of Qud.csv to sentiment_analysis_results/Caves of Qud.csv
# Saved results for BRAWL.csv to sentiment_analysis_results/BRAWL.csv
# Saved results for STAR WARS™ Rebellion.csv to sentiment_analysis_results/STAR WARS™ Rebellion.csv
# Saved results for Not The Robots.csv to sentiment_analysis_results/Not The Robots.csv
# Saved results for Soulcaster: Part I & II.csv to sentiment_analysis_results/Soulcaster: Part I & II.csv
# Saved results for Cossacks: Back to War.csv to sentiment_analysis_results/Cossacks: Back to War.csv
# Saved results for Choplifter HD.csv to sentiment_analysis_results/Choplifter HD.csv
# Saved results for DARK.csv to sentiment_analysis_results/DARK.csv
# Saved results for Hotel Collectors Edition.csv to sentiment_analysis_results/Hotel Collectors Edition.csv
# Saved results for Sherlock Holmes versus Jack the Ripper.csv to sentiment_analysis_results/Sherlock Holmes versus Jack the Ripper.csv
# Saved results for SAMURAI WARRIORS 4-II.csv to sentiment_analysis_results/SAMURAI WARRIORS 4-II.csv
# Saved results for Space Pirate Trainer.csv to sentiment_analysis_results/Space Pirate Trainer.csv
# Saved results for Rodina.csv to sentiment_analysis_results/Rodina.csv
# Saved results for ENDLESS™ Legend.csv to sentiment_analysis_results/ENDLESS™ Legend.csv
# Saved results for Advent Rising.csv to sentiment_analysis_results/Advent Rising.csv
# Saved results for Space Channel 5: Part 2.csv to sentiment_analysis_results/Space Channel 5: Part 2.csv
# Saved results for Bohemian Killing.csv to sentiment_analysis_results/Bohemian Killing.csv
# Saved results for Lethis - Path of Progress.csv to sentiment_analysis_results/Lethis - Path of Progress.csv
# Saved results for Codename CURE.csv to sentiment_analysis_results/Codename CURE.csv
# Saved results for UBERMOSH:BLACK.csv to sentiment_analysis_results/UBERMOSH:BLACK.csv
# Saved results for WORLD END ECONOMiCA episode.01.csv to sentiment_analysis_results/WORLD END ECONOMiCA episode.01.csv
# Saved results for Call of Duty: Modern Warfare 3.csv to sentiment_analysis_results/Call of Duty: Modern Warfare 3.csv
# Saved results for Fish Tycoon.csv to sentiment_analysis_results/Fish Tycoon.csv
# Saved results for INSIDE.csv to sentiment_analysis_results/INSIDE.csv
# Saved results for Sword of the Stars II: Enhanced Edition.csv to sentiment_analysis_results/Sword of the Stars II: Enhanced Edition.csv
# Saved results for Adventure Park.csv to sentiment_analysis_results/Adventure Park.csv
# Saved results for Air Guardians.csv to sentiment_analysis_results/Air Guardians.csv
# Saved results for Hurtworld.csv to sentiment_analysis_results/Hurtworld.csv
# Saved results for Face It - A game to fight inner demons.csv to sentiment_analysis_results/Face It - A game to fight inner demons.csv
# Saved results for Machine Gun Train Run.csv to sentiment_analysis_results/Machine Gun Train Run.csv
# Saved results for Sun Dogs.csv to sentiment_analysis_results/Sun Dogs.csv
# Saved results for Toxic Bunny HD.csv to sentiment_analysis_results/Toxic Bunny HD.csv
# Saved results for Amazing Princess Sarah.csv to sentiment_analysis_results/Amazing Princess Sarah.csv
# Saved results for LEGO® Harry Potter: Years 1-4.csv to sentiment_analysis_results/LEGO® Harry Potter: Years 1-4.csv
# Saved results for Everyday Shooter.csv to sentiment_analysis_results/Everyday Shooter.csv
# Saved results for Manhole.csv to sentiment_analysis_results/Manhole.csv
# Saved results for Steamalot: Epoch's Journey.csv to sentiment_analysis_results/Steamalot: Epoch's Journey.csv
# Saved results for Gunslugs.csv to sentiment_analysis_results/Gunslugs.csv
# Saved results for Aozora Meikyuu.csv to sentiment_analysis_results/Aozora Meikyuu.csv
# Saved results for Pro Basketball Manager 2016.csv to sentiment_analysis_results/Pro Basketball Manager 2016.csv
# Saved results for X-COM: Terror from the Deep.csv to sentiment_analysis_results/X-COM: Terror from the Deep.csv
# Saved results for Battle Mages: Sign of Darkness.csv to sentiment_analysis_results/Battle Mages: Sign of Darkness.csv
# Saved results for Fiesta Online.csv to sentiment_analysis_results/Fiesta Online.csv
# Saved results for Booster Trooper.csv to sentiment_analysis_results/Booster Trooper.csv
# Saved results for Mr. Shadow.csv to sentiment_analysis_results/Mr. Shadow.csv
# Saved results for Knights of the Sky.csv to sentiment_analysis_results/Knights of the Sky.csv
# Saved results for Strife.csv to sentiment_analysis_results/Strife.csv
# Saved results for Dandelion - Wishes brought to you -.csv to sentiment_analysis_results/Dandelion - Wishes brought to you -.csv
# Saved results for KWAAN.csv to sentiment_analysis_results/KWAAN.csv
# Saved results for Equin: The Lantern.csv to sentiment_analysis_results/Equin: The Lantern.csv
# Saved results for Super Indie Karts.csv to sentiment_analysis_results/Super Indie Karts.csv
# Saved results for Ballads of Reemus: When the Bed Bites.csv to sentiment_analysis_results/Ballads of Reemus: When the Bed Bites.csv
# Saved results for Aces of the Luftwaffe.csv to sentiment_analysis_results/Aces of the Luftwaffe.csv
# Saved results for Get Off My Lawn!.csv to sentiment_analysis_results/Get Off My Lawn!.csv
# Saved results for The Visitor.csv to sentiment_analysis_results/The Visitor.csv
# Saved results for Hard to Be a God.csv to sentiment_analysis_results/Hard to Be a God.csv
# Saved results for Starters Orders 6.csv to sentiment_analysis_results/Starters Orders 6.csv
# Saved results for Siege Wars.csv to sentiment_analysis_results/Siege Wars.csv

# %%
# import os
# import pandas as pd
#
# def filter_csvs(csv_directory, output_file, col1_value, col2_value, col3_value, col4_value):
#     """
#     遍历指定目录中的 CSV 文件，根据四列的值进行筛选，并保存符合条件的文件名
#
#     :param csv_directory: 包含 CSV 文件的目录
#     :param output_file: 符合条件的文件名保存的位置
#     :param col1_value, col2_value, col3_value, col4_value: 筛选的条件
#     """
#     matching_files = []
#
#     # 获取 CSV 文件夹中的所有文件
#     files = [f for f in os.listdir(csv_directory) if f.endswith('.csv')]
#
#     # 遍历每个文件，读取 CSV 文件并筛选数据
#     for file in files:
#         df = pd.read_csv(os.path.join(csv_directory, file))
#
#         # 检查每个文件是否包含指定的值
#         if ((df['col1'] == col1_value) & (df['col2'] == col2_value) &
#             (df['col3'] == col3_value) & (df['col4'] == col4_value)).any():
#             matching_files.append(file)
#
#     # 保存符合条件的文件名到新的 CSV 文件
#     pd.DataFrame(matching_files, columns=['filename']).to_csv(output_file, index=False)
#
# # 使用示例
# directory = "most_game_comments"
# output_csv = "matching_files.csv"
# filter_csvs(directory, output_csv, 'value1', 'value2', 'value3', 'value4')

# %%
def filter_csvs(csv_directory, output_file1, output_file2, output_file3, output_file4,
                col_values1, col_values2, col_values3 ,col_values4):
    """
    遍历指定目录中的 CSV 文件，根据四列的值进行筛选，并保存符合条件的文件名

    :param csv_directory: 包含 CSV 文件的目录
    :param output_file1, output_file2: 符合条件的文件名保存的位置
    :param col_values1, col_values2: 筛选的条件
    """
    Good_Game = []
    Bad_Game = []
    Hard_to_say = []
    Niche_Games =[]
    # 获取 CSV 文件夹中的所有文件
    files = [f for f in os.listdir(csv_directory) if f.endswith('.csv')]

    # 遍历每个文件，读取 CSV 文件并筛选数据
    for file in files:
        df = pd.read_csv(os.path.join(csv_directory, file))

        # 检查每个文件是否包含指定的值
        if ((df['total_comments']  >= col_values1[0]) & (df['percentage_positive'] >= col_values1[1])).any():
            Good_Game.append(file)

        if ((df['total_comments'] >= col_values2[0]) & (df['percentage_positive'] <= col_values2[1]) ).any():
            Bad_Game.append(file)

        if ((df['total_comments'] <= col_values3)  ).any():
            Niche_Games.append(file)

        if ((df['total_comments'] >= col_values4[0]) & (df['percentage_positive'] >= col_values4[1])& (df['percentage_positive'] <= col_values4[2]) ).any():
            Hard_to_say.append(file)
    # 保存符合条件的文件名到新的 CSV 文件
    pd.DataFrame(Good_Game, columns=['Name']).to_csv(output_file1, index=False)
    pd.DataFrame(Bad_Game, columns=['Name']).to_csv(output_file2, index=False)
    pd.DataFrame(Niche_Games, columns=['Name']).to_csv(output_file3, index=False)
    pd.DataFrame(Hard_to_say, columns=['Name']).to_csv(output_file4, index=False)

# 使用示例
directory = "sentiment_analysis_results"
output_csv1 = "Good_Game.csv"
output_csv2 = "Bad_Game.csv"
output_csv3 = "Niche_Games.csv"
output_csv4 = "Hard_to_say.csv"
filter_csvs(directory, output_csv1, output_csv2,output_csv3,output_csv4,
            [100, 60],
            [100, 45],
            [99],
            [1000, 46, 59])#需要加个 大于1000条评论 且好评率在40-60之间的
# bad game 267
# good game  2660
# hard to say 3370

# %%
# replace .csv 去除.csv

def remove_string(csv_directory, target_string):
    """
    遍历指定目录中的 CSV 文件，删除所有文件中的特定字符串

    :param csv_directory: 包含 CSV 文件的目录
    :param target_string: 要删除的字符串
    """
    # 获取 CSV 文件夹中的所有文件
    files = [f for f in os.listdir(csv_directory) if f.endswith('.csv')]

    # 遍历每个文件，读取 CSV 文件并替换目标字符串
    for file in files:
        file_path = os.path.join(csv_directory, file)
        df = pd.read_csv(file_path)

        # 用 replace 函数替换所有列中的目标字符串
        df.replace(target_string, '', regex=True, inplace=True)

        # 将修改后的数据保存回 CSV 文件
        df.to_csv(file_path, index=False)

# 使用示例
directory = "Postive_Rate"
remove_string(directory, ".csv")

# %%
#ranked
import os
from dateutil import parser
import pandas as pd
def rank_csv(csv_file, column1, column2, column3, column4, column5):
    """
    从CSV文件中提取两列，根据一列的值进行排序，并在新的列中输出排名

    :param csv_file: CSV文件的路径
    :param column1, column2: 要提取的列的名称
    """
    # 读取CSV文件
    df = pd.read_csv(csv_file)
    df['Release date'] = df['Release date'].apply(lambda x: parser.parse(x))

# 获取每一行的年份
    df['year'] = df['Release date'].dt.year
    df = df[df['year'] < 2019]
    # 提取两列并根据 column1 的值进行排序
    df = df[[column1, column2, column3, column4, column5]].sort_values(by=column1, ascending=False)

    # 创建新的列 'Rank' 并赋值为 column1 的排名
    df['Rank'] = df[column1].rank(method = 'min',ascending=False)

    # 将结果保存到新的CSV文件
    df.to_csv('ranked_data.csv', index=False)

# 使用示例
csv_file = 'games.csv'
rank_csv(csv_file, 'Positive', 'Name', 'Genres','Developers','Publishers' )

# %%
def calculate_overlap(csv_file1, csv_file2, csv_file3, column_name):
    """
    计算两个CSV文件中特定列的重复值的比例

    :param csv_file1, csv_file2: 要比较的CSV文件的路径
    :param column_name: 要比较的列的名称
    """
    # 读取CSV文件
    df1 = pd.read_csv(csv_file1)
    df2 = pd.read_csv(csv_file2).head(7000)
    df3 = pd.read_csv(csv_file3)
    row_count = df1.shape[0]

    # 计算两个数据集在特定列上的重复值的数量
    overlap_count_Good = pd.merge(df1, df2, on=column_name).shape[0]
    overlap_count_Hard = pd.merge(df3, df2, on=column_name).shape[0]
    overlap_count = overlap_count_Good + overlap_count_Hard
    print(f"overlap_count is {overlap_count}")
    # 计算总的唯一值数量
    total_unique_values = pd.concat([df1[column_name], df2[column_name]]).nunique()
    print(total_unique_values)
    # 计算并返回重复值的比例
    overlap_ratio = overlap_count / row_count
    return overlap_ratio

csv1 = "Good_Game.csv"
csv2 = "ranked_data.csv"
csv3 = "Hard_to_say.csv"
column = "Name"
overlap = calculate_overlap(csv1, csv2, csv3,column)
print(f"The overlap ratio is {overlap}")
# Out:
# overlap_count is 2274
# 8472
# The overlap ratio is 0.8548872180451128

# %%
# #通过CSV文件1中一列的值对CSV文件2进行筛选
# def filter_csv_by_another(file1, file2, output_file, column_name):
#     """
#     通过CSV文件1中一列的值对CSV文件2进行筛选。
#
#     :param file1: 第一个CSV文件的路径
#     :param file2: 第二个CSV文件的路径
#     :param output_file: 保存结果的CSV文件的路径
#     :param column_name: 用于筛选数据的列的名称
#     """
#     # 读取两个CSV文件
#     df1 = pd.read_csv(file1)
#     df2 = pd.read_csv(file2)
#
#     # 从第一个CSV文件中获取一列的值
#     values = df1[column_name].values
#
#     # 在第二个CSV文件中筛选数据
#     df2_filtered = df2[df2[column_name].isin(values)]
#
#     # 保存结果
#     df2_filtered.to_csv(output_file, index=False)
#
# # 使用示例
# #filter to get the information for Good games
# # file1 = "Good_Game.csv"
# file1 = "Hard_to_say.csv"
#
# file2 = "games.csv"
# # output_file = "Filtered_Good_Game.csv"
# output_file = "Filtered_Hard_to_say.csv"
#
# column_name = "Name"
# filter_csv_by_another(file1, file2, output_file, column_name)

# %%
# # 读取两个CSV文件
# df1 = pd.read_csv('Filtered_Good_Game.csv')
# df2 = pd.read_csv('Filtered_Hard_to_say.csv')
#
# # 使用concat进行堆叠
# df = pd.concat([df1, df2])
#
# # 将结果保存到新的CSV文件
# df.to_csv('combined.csv', index=False)

# %%
#获取每五年的数据 准备以五年为标准进行模型预测
import pandas as pd

# 加载CSV
df = pd.read_csv('combined.csv')
df['Release date'] = df['Release date'].apply(lambda x: parser.parse(x))

# 获取每一行的年份
df['year'] = df['Release date'].dt.year
# 确保"year"列是整数类型
df['year'] = df['year'].astype(int)

# 筛选1994年及以后的数据
df = df[df['year'] >= 1994]

# 创建一个新的列"period"，其值为对应年份所在的五年区间
df['period'] = (df['year'] - 1994) // 3

# 按"period"列分组
groups = df.groupby('period')

# 打印每个五年区间的数据
for name, group in groups:
    print(f"Period: {1994 + name*3} - {1994 + (name+1)*3}")
    print(group)

# 如果需要保存每个五年区间的数据为单独的CSV文件
for name, group in groups:
    group.to_csv(f"data_{1994 + name*3}_{1994 + (name+1)*3}.csv", index=False)
# Out:
# Period: 1997 - 2000
#        AppID                         Name Release date    Estimated owners  \
# 634   224920  Legacy of Kain: Soul Reaver   1999-09-08    500000 - 1000000
# 709       20        Team Fortress Classic   1999-04-01  5000000 - 10000000
# 1296  282010         Carmageddon Max Pack   1997-06-30     100000 - 200000
# 1406      50    Half-Life: Opposing Force   1999-11-01  5000000 - 10000000
# 1774      70                    Half-Life   1998-11-08  5000000 - 10000000
#
#       Peak CCU  Required age  Price  DLC count  \
# 634          4            17   0.00          0
# 709        110             0   4.99          0
# 1296         6             0   9.99          0
# 1406       120             0   4.99          0
# 1774       752             0   9.99          1
#
#                                          About the game  \
# 634   As Raziel, stalk the shadows of Nosgoth preyin...
# 709   One of the most popular online action games of...
# 1296  Carmageddon is the original freeform driving s...
# 1406  Return to the Black Mesa Research Facility as ...
# 1774  Named Game of the Year by over 50 publications...
#
#                                     Supported languages  ...  \
# 634                                         ['English']  ...
# 709   ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 1296                                        ['English']  ...
# 1406          ['English', 'French', 'German', 'Korean']  ...
# 1774  ['English', 'French', 'German', 'Italian', 'Sp...  ...
#
#      Median playtime two weeks           Developers   Publishers  \
# 634                          0     Crystal Dynamics  Square Enix
# 709                          0                Valve        Valve
# 1296                         0  Stainless Games Ltd   THQ Nordic
# 1406                         0     Gearbox Software        Valve
# 1774                       102                Valve        Valve
#
#                                              Categories               Genres  \
# 634                                       Single-player     Action,Adventure
# 709   Multi-player,PvP,Online PvP,Shared/Split Scree...               Action
# 1296     Single-player,Multi-player,Steam Trading Cards  Action,Indie,Racing
# 1406  Single-player,Multi-player,Valve Anti-Cheat en...               Action
# 1774  Single-player,Multi-player,PvP,Online PvP,Stea...               Action
#
#                                                    Tags  \
# 634   Adventure,Action,Vampire,Classic,Story Rich,Da...
# 709   Action,FPS,Multiplayer,Classic,Hero Shooter,Sh...
# 1296  Combat Racing,Racing,Action,Classic,Indie,Gore...
# 1406  FPS,Action,Classic,Sci-fi,Singleplayer,Shooter...
# 1774  FPS,Singleplayer,Sci-fi,Multiplayer,1990's,Act...
#
#                                             Screenshots  \
# 634   https://cdn.akamai.steamstatic.com/steam/apps/...
# 709   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1296  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1406  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1774  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  Movies  year  period
# 634                                                 NaN  1999       1
# 709                                                 NaN  1999       1
# 1296  http://cdn.akamai.steamstatic.com/steam/apps/2...  1997       1
# 1406                                                NaN  1999       1
# 1774                                                NaN  1998       1
#
# [5 rows x 41 columns]
# Period: 2000 - 2003
#        AppID                   Name Release date     Estimated owners  \
# 860   200960            Geneforge 1   2001-12-01      100000 - 200000
# 1226      40     Deathmatch Classic   2001-06-01   5000000 - 10000000
# 1420      10         Counter-Strike   2000-11-01  10000000 - 20000000
# 1811     130  Half-Life: Blue Shift   2001-06-01  10000000 - 20000000
# 2317      60               Ricochet   2000-11-01   5000000 - 10000000
#
#       Peak CCU  Required age  Price  DLC count  \
# 860          3             0  19.99          0
# 1226         2             0   4.99          0
# 1420     13230             0   9.99          0
# 1811        78             0   4.99          0
# 2317        10             0   4.99          0
#
#                                          About the game  \
# 860   Geneforge is an Indie fantasy role-playing gam...
# 1226  Enjoy fast-paced multiplayer gaming with Death...
# 1420  Play the world's number 1 online action game. ...
# 1811  Made by Gearbox Software and originally releas...
# 2317  A futuristic action game that challenges your ...
#
#                                     Supported languages  ...  \
# 860                                         ['English']  ...
# 1226  ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 1420  ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 1811                    ['English', 'French', 'German']  ...
# 2317  ['English', 'French', 'German', 'Italian', 'Sp...  ...
#
#      Median playtime two weeks          Developers          Publishers  \
# 860                          0  Spiderweb Software  Spiderweb Software
# 1226                         0               Valve               Valve
# 1420                       733               Valve               Valve
# 1811                         0    Gearbox Software               Valve
# 2317                        49               Valve               Valve
#
#                                              Categories              Genres  \
# 860                                       Single-player  Strategy,RPG,Indie
# 1226  Multi-player,PvP,Online PvP,Shared/Split Scree...              Action
# 1420  Multi-player,PvP,Online PvP,Shared/Split Scree...              Action
# 1811                 Single-player,Remote Play Together              Action
# 2317  Multi-player,PvP,Online PvP,Valve Anti-Cheat e...              Action
#
#                                                    Tags  \
# 860   RPG,Indie,Isometric,Strategy,Turn-Based Combat...
# 1226  Action,FPS,Classic,Multiplayer,Shooter,First-P...
# 1420  Action,FPS,Multiplayer,Shooter,Classic,Team-Ba...
# 1811  FPS,Action,Sci-fi,Singleplayer,Shooter,Aliens,...
# 2317  Action,FPS,Multiplayer,Classic,First-Person,Sc...
#
#                                             Screenshots  Movies  year  period
# 860   https://cdn.akamai.steamstatic.com/steam/apps/...     NaN  2001       2
# 1226  https://cdn.akamai.steamstatic.com/steam/apps/...     NaN  2001       2
# 1420  https://cdn.akamai.steamstatic.com/steam/apps/...     NaN  2000       2
# 1811  https://cdn.akamai.steamstatic.com/steam/apps/...     NaN  2001       2
# 2317  https://cdn.akamai.steamstatic.com/steam/apps/...     NaN  2000       2
#
# [5 rows x 41 columns]
# Period: 2003 - 2006
#       AppID                            Name Release date     Estimated owners  \
# 138      30                   Day of Defeat   2003-05-01   5000000 - 10000000
# 170    3920            Sid Meier's Pirates!   2005-07-11      200000 - 500000
# 246   39510         Gothic II: Gold Edition   2005-11-29     500000 - 1000000
# 368      80  Counter-Strike: Condition Zero   2004-03-01   5000000 - 10000000
# 781     240          Counter-Strike: Source   2004-11-01  10000000 - 20000000
# 1319    220                     Half-Life 2   2004-11-16  10000000 - 20000000
# 1478    100  Counter-Strike: Condition Zero   2004-03-01  10000000 - 20000000
# 1627    320         Half-Life 2: Deathmatch   2004-11-01  10000000 - 20000000
# 1695   1500                        Darwinia   2005-07-14       50000 - 100000
# 2065    340         Half-Life 2: Lost Coast   2005-10-27  20000000 - 50000000
# 2151    280               Half-Life: Source   2004-06-01    2000000 - 5000000
#
#       Peak CCU  Required age  Price  DLC count  \
# 138        106             0   4.99          0
# 170        189             0   9.99          0
# 246        572             0   9.99          0
# 368        425             0   9.99          0
# 781       7162             0   9.99          0
# 1319      1015             0   9.99          1
# 1478        69             0   9.99          0
# 1627       213             0   4.99          0
# 1695         3             0   9.99          0
# 2065        23             0   0.00          0
# 2151        50             0   9.99          0
#
#                                          About the game  \
# 138   Enlist in an intense brand of Axis vs. Allied ...
# 170   Sail the Caribbean, marauding all on the high ...
# 246   Gothic II: Gold Edition brings together the ex...
# 368   With its extensive Tour of Duty campaign, a ne...
# 781   THE NEXT INSTALLMENT OF THE WORLD'S # 1 ONLINE...
# 1319  1998. HALF-LIFE sends a shock through the game...
# 1478  With its extensive Tour of Duty campaign, a ne...
# 1627  Fast multiplayer action set in the Half-Life 2...
# 1695  Combining fast-paced action with strategic bat...
# 2065  Originally planned as a section of the Highway...
# 2151  Winner of over 50 Game of the Year awards, Hal...
#
#                                     Supported languages  ...  \
# 138   ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 170                                         ['English']  ...
# 246   ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 368   ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 781   ['English', 'French', 'German', 'Italian', 'Ja...  ...
# 1319  ['English', 'French', 'German', 'Italian', 'Ko...  ...
# 1478  ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 1627                                        ['English']  ...
# 1695  ['English', 'German', 'French', 'Italian', 'Sp...  ...
# 2065  ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 2151  ['English', 'French', 'German', 'Italian', 'Ja...  ...
#
#      Median playtime two weeks             Developers             Publishers  \
# 138                          0                  Valve                  Valve
# 170                          0          Firaxis Games                     2K
# 246                          0          Piranha Bytes             THQ Nordic
# 368                         22                  Valve                  Valve
# 781                         53                  Valve                  Valve
# 1319                       315                  Valve                  Valve
# 1478                         0                  Valve                  Valve
# 1627                        75                  Valve                  Valve
# 1695                         0  Introversion Software  Introversion Software
# 2065                         0                  Valve                  Valve
# 2151                         0                  Valve                  Valve
#
#                                              Categories          Genres  \
# 138               Multi-player,Valve Anti-Cheat enabled          Action
# 170                                       Single-player             RPG
# 246                                       Single-player      Action,RPG
# 368   Single-player,Multi-player,Valve Anti-Cheat en...          Action
# 781   Multi-player,Cross-Platform Multiplayer,Steam ...          Action
# 1319  Single-player,Steam Achievements,Steam Trading...          Action
# 1478  Single-player,Multi-player,Valve Anti-Cheat en...          Action
# 1627  Multi-player,Valve Anti-Cheat enabled,Includes...          Action
# 1695  Single-player,Full controller support,Steam Cl...  Indie,Strategy
# 2065  Single-player,Commentary available,Remote Play...          Action
# 2151                 Single-player,Remote Play Together          Action
#
#                                                    Tags  \
# 138   FPS,World War II,Multiplayer,Shooter,Action,Wa...
# 170   Pirates,Open World,RPG,Adventure,Singleplayer,...
# 246   RPG,Classic,Open World,Atmospheric,Singleplaye...
# 368   Action,FPS,Shooter,Multiplayer,First-Person,Si...
# 781   Shooter,Action,FPS,Multiplayer,Team-Based,Firs...
# 1319  FPS,Action,Sci-fi,Classic,Singleplayer,Story R...
# 1478  Action,FPS,Shooter,Multiplayer,First-Person,Cl...
# 1627  Action,FPS,Multiplayer,Shooter,First-Person,Sc...
# 1695  Retro,Atmospheric,Strategy,RTS,Stylized,Single...
# 2065  FPS,Action,Singleplayer,First-Person,Sci-fi,Sh...
# 2151  FPS,Action,Classic,Sci-fi,Singleplayer,Shooter...
#
#                                             Screenshots  \
# 138   https://cdn.akamai.steamstatic.com/steam/apps/...
# 170   https://cdn.akamai.steamstatic.com/steam/apps/...
# 246   https://cdn.akamai.steamstatic.com/steam/apps/...
# 368   https://cdn.akamai.steamstatic.com/steam/apps/...
# 781   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1319  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1478  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1627  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1695  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2065  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2151  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  Movies  year  period
# 138                                                 NaN  2003       3
# 170                                                 NaN  2005       3
# 246   http://cdn.akamai.steamstatic.com/steam/apps/9...  2005       3
# 368                                                 NaN  2004       3
# 781                                                 NaN  2004       3
# 1319  http://cdn.akamai.steamstatic.com/steam/apps/9...  2004       3
# 1478                                                NaN  2004       3
# 1627                                                NaN  2004       3
# 1695  http://cdn.akamai.steamstatic.com/steam/apps/2...  2005       3
# 2065                                                NaN  2005       3
# 2151                                                NaN  2004       3
#
# [11 rows x 41 columns]
# Period: 2006 - 2009
#       AppID                                         Name Release date  \
# 47     1530                                   Multiwinia   2008-09-19
# 73    15500               The Wonderful End of the World   2008-07-17
# 126    4500          S.T.A.L.K.E.R.: Shadow of Chernobyl   2007-03-20
# 130    1700                                  Arx Fatalis   2007-04-03
# 131   16810    Sid Meier's Civilization IV: Colonization   2008-09-23
# ...     ...                                          ...          ...
# 2213  13240  Unreal Tournament: Game of the Year Edition   2008-03-17
# 2234   4000                                  Garry's Mod   2006-11-29
# 2239    420                     Half-Life 2: Episode Two   2007-10-10
# 2355   1520                                       DEFCON   2006-09-29
# 2369  22300                                    Fallout 3   2008-10-28
#
#          Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 47       500000 - 1000000         2             0   9.99          0
# 73        100000 - 200000         1             0   4.99          0
# 126     1000000 - 2000000       518            17  19.99          0
# 130       200000 - 500000        21             0   4.99          0
# 131     1000000 - 2000000       273             0  19.99          0
# ...                   ...       ...           ...    ...        ...
# 2213     500000 - 1000000        34            17   9.99          0
# 2234  20000000 - 50000000     37574             0   9.99          0
# 2239   5000000 - 10000000       263             0   7.99          1
# 2355     500000 - 1000000        20             0   9.99          0
# 2369     500000 - 1000000       122            17   9.99          6
#
#                                          About the game  \
# 47    'Long ago a computer scientist called Dr Sepul...
# 73    You can't save the whole world. It's going to ...
# 126   In 1986, the world's worst nuclear disaster oc...
# 130   Journey to the World Of Arx Explore A Fantasy ...
# 131   Sid Meier's Civilization IV: Colonization is t...
# ...                                                 ...
# 2213  Unreal Tournament is the original King of the ...
# 2234  Garry's Mod is a physics sandbox. There aren't...
# 2239  Half-Life&reg; 2: Episode Two is the second in...
# 2355  Inspired by the 1983 cult classic film, Wargam...
# 2369  Vault-Tec engineers have worked around the clo...
#
#                                     Supported languages  ...  \
# 47    ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 73                                          ['English']  ...
# 126   ['English', 'French', 'Italian', 'Spanish - Sp...  ...
# 130   ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 131   ['English', 'French', 'German', 'Spanish - Spa...  ...
# ...                                                 ...  ...
# 2213                                        ['English']  ...
# 2234  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2239  ['English', 'French', 'German', 'Russian', 'Da...  ...
# 2355  ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 2369  ['English', 'French', 'Italian', 'German', 'Sp...  ...
#
#      Median playtime two weeks             Developers             Publishers  \
# 47                           0  Introversion Software  Introversion Software
# 73                           0    Dejobaan Games, LLC    Dejobaan Games, LLC
# 126                         43         GSC Game World         GSC Game World
# 130                          0         Arkane Studios         Arkane Studios
# 131                          0          Firaxis Games                     2K
# ...                        ...                    ...                    ...
# 2213                         0       Epic Games, Inc.       Epic Games, Inc.
# 2234                       150      Facepunch Studios                  Valve
# 2239                       257                  Valve                  Valve
# 2355                         0  Introversion Software  Introversion Software
# 2369                         0  Bethesda Game Studios     Bethesda Softworks
#
#                                              Categories            Genres  \
# 47    Single-player,Multi-player,PvP,Online PvP,LAN ...             Indie
# 73    Single-player,Steam Achievements,Partial Contr...      Casual,Indie
# 126   Single-player,Multi-player,PvP,Online PvP,LAN ...        Action,RPG
# 130                                       Single-player               RPG
# 131                          Single-player,Multi-player          Strategy
# ...                                                 ...               ...
# 2213                         Single-player,Multi-player            Action
# 2234  Single-player,Multi-player,PvP,Online PvP,LAN ...  Indie,Simulation
# 2239  Single-player,Steam Achievements,Captions avai...            Action
# 2355                         Single-player,Multi-player    Indie,Strategy
# 2369           Single-player,Partial Controller Support               RPG
#
#                                                    Tags  \
# 47    Indie,RTS,Strategy,Multiplayer,Singleplayer,Retro
# 73    Indie,Casual,Action,Singleplayer,Short,Funny,C...
# 126   Atmospheric,Post-apocalyptic,Open World,FPS,Su...
# 130   RPG,First-Person,Classic,Atmospheric,Dark Fant...
# 131   Strategy,Turn-Based Strategy,Turn-Based,4X,His...
# ...                                                 ...
# 2213  Classic,FPS,Action,Arena Shooter,Fast-Paced,Mu...
# 2234  Sandbox,Multiplayer,Funny,Moddable,Building,Co...
# 2239  FPS,Action,Sci-fi,Singleplayer,Shooter,Story R...
# 2355  Strategy,Indie,Wargame,Cold War,Multiplayer,Ps...
# 2369  Open World,Post-apocalyptic,RPG,Singleplayer,E...
#
#                                             Screenshots  \
# 47    https://cdn.akamai.steamstatic.com/steam/apps/...
# 73    https://cdn.akamai.steamstatic.com/steam/apps/...
# 126   https://cdn.akamai.steamstatic.com/steam/apps/...
# 130   https://cdn.akamai.steamstatic.com/steam/apps/...
# 131   https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                 ...
# 2213  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2234  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2239  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2355  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2369  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  Movies  year  period
# 47                                                  NaN  2008       4
# 73                                                  NaN  2008       4
# 126                                                 NaN  2007       4
# 130   http://cdn.akamai.steamstatic.com/steam/apps/2...  2007       4
# 131                                                 NaN  2008       4
# ...                                                 ...   ...     ...
# 2213                                                NaN  2008       4
# 2234                                                NaN  2006       4
# 2239                                                NaN  2007       4
# 2355                                                NaN  2006       4
# 2369  http://cdn.akamai.steamstatic.com/steam/apps/2...  2008       4
#
# [78 rows x 41 columns]
# Period: 2009 - 2012
#       AppID                       Name Release date   Estimated owners  \
# 2     12140                  Max Payne   2011-01-06   500000 - 1000000
# 26    40420                    Tidalis   2010-07-16    100000 - 200000
# 35    22380         Fallout: New Vegas   2010-10-19  2000000 - 5000000
# 49    71250         Sonic Adventure DX   2011-03-04   500000 - 1000000
# 60    94200                  Jamestown   2011-06-08   500000 - 1000000
# ...     ...                        ...          ...                ...
# 2365  25890         Hearts of Iron III   2009-08-07   500000 - 1000000
# 2372  29800                     Caster   2009-03-19    200000 - 500000
# 2374  57300  Amnesia: The Dark Descent   2010-09-08  2000000 - 5000000
# 2375  39000             Moonbase Alpha   2010-07-06  1000000 - 2000000
# 2376  91700   E.Y.E: Divine Cybermancy   2011-07-29   500000 - 1000000
#
#       Peak CCU  Required age  Price  DLC count  \
# 2           49            17   3.49          0
# 26           0             0   4.99          0
# 35        5776            16   9.99          7
# 49         115             0   7.99          0
# 60           3             0   9.99          1
# ...        ...           ...    ...        ...
# 2365       113             0   9.99         18
# 2372         0             0   1.99          0
# 2374        73             0  19.99          0
# 2375         6             0   0.00          0
# 2376        23             0   9.99          0
#
#                                          About the game  \
# 2     Max Payne is a man with nothing to lose in the...
# 26    Tidalis is a block-based puzzle game with casu...
# 35    Welcome to Vegas. New Vegas. It’s the kind of ...
# 49    An ancient evil lurking within the Master Emer...
# 60    Please note: we've recently released Jamestown...
# ...                                                 ...
# 2365  Hearts of Iron III lets you play the most enga...
# 2372  Dash across Scenic Locations destroying bug li...
# 2374  The last remaining memories fade away into dar...
# 2375  NASA has once again landed on the lunar surfac...
# 2376  As a member of the strange secret society E.Y....
#
#                                     Supported languages  ...  \
# 2                                           ['English']  ...
# 26                                          ['English']  ...
# 35    ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 49    ['English', 'French', 'German', 'Japanese', 'S...  ...
# 60                                          ['English']  ...
# ...                                                 ...  ...
# 2365  ['English', 'French', 'German', 'Spanish - Spa...  ...
# 2372                                        ['English']  ...
# 2374  ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 2375                                        ['English']  ...
# 2376                              ['English', 'French']  ...
#
#      Median playtime two weeks                       Developers  \
# 2                           79             Remedy Entertainment
# 26                           0                 Arcen Games, LLC
# 35                         153           Obsidian Entertainment
# 49                          23                             SEGA
# 60                           0                 Final Form Games
# ...                        ...                              ...
# 2365                         0       Paradox Development Studio
# 2372                         0                          Elecorn
# 2374                         0                 Frictional Games
# 2375                         0  Virtual Heroes,Army Game Studio
# 2376                         0                 Streum On Studio
#
#                Publishers                                         Categories  \
# 2          Rockstar Games                                      Single-player
# 26       Arcen Games, LLC  Single-player,Multi-player,Co-op,Online Co-op,...
# 35     Bethesda Softworks  Single-player,Steam Achievements,Partial Contr...
# 49                   SEGA           Single-player,Partial Controller Support
# 60       Final Form Games  Single-player,Multi-player,PvP,Shared/Split Sc...
# ...                   ...                                                ...
# 2365  Paradox Interactive  Single-player,Multi-player,Co-op,Steam Trading...
# 2372              Elecorn  Single-player,Steam Trading Cards,Partial Cont...
# 2374     Frictional Games  Single-player,Steam Achievements,Full controll...
# 2375                 NASA  Single-player,Multi-player,Co-op,Valve Anti-Ch...
# 2376     Streum On Studio  Single-player,Multi-player,PvP,Online PvP,LAN ...
#
#                                           Genres  \
# 2                                         Action
# 26                                  Casual,Indie
# 35                                    Action,RPG
# 49                                           NaN
# 60                                  Action,Indie
# ...                                          ...
# 2365                                    Strategy
# 2372  Action,Adventure,Casual,Indie,RPG,Strategy
# 2374                      Action,Adventure,Indie
# 2375               Adventure,Simulation,Strategy
# 2376                            Action,Indie,RPG
#
#                                                    Tags  \
# 2     Action,Noir,Classic,Third-Person Shooter,Bulle...
# 26    Casual,Indie,Puzzle,Match 3,Co-op,Multiplayer,...
# 35    Open World,RPG,Post-apocalyptic,Singleplayer,M...
# 49    Platformer,3D Platformer,Great Soundtrack,Adve...
# 60    Shoot 'Em Up,Bullet Hell,Local Co-Op,Indie,Arc...
# ...                                                 ...
# 2365  Grand Strategy,Strategy,World War II,Historica...
# 2372  Action,Indie,Adventure,Third-Person Shooter,Ca...
# 2374  Horror,Psychological Horror,Atmospheric,Surviv...
# 2375  Space,Simulation,Free to Play,Multiplayer,Onli...
# 2376  Cyberpunk,RPG,FPS,Action,Co-op,Indie,Singlepla...
#
#                                             Screenshots  \
# 2     https://cdn.akamai.steamstatic.com/steam/apps/...
# 26    https://cdn.akamai.steamstatic.com/steam/apps/...
# 35    https://cdn.akamai.steamstatic.com/steam/apps/...
# 49    https://cdn.akamai.steamstatic.com/steam/apps/...
# 60    https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                 ...
# 2365  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2372  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2374  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2375  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2376  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  Movies  year  period
# 2                                                   NaN  2011       5
# 26                                                  NaN  2010       5
# 35                                                  NaN  2010       5
# 49                                                  NaN  2011       5
# 60                                                  NaN  2011       5
# ...                                                 ...   ...     ...
# 2365                                                NaN  2009       5
# 2372  http://cdn.akamai.steamstatic.com/steam/apps/2...  2009       5
# 2374                                                NaN  2010       5
# 2375                                                NaN  2010       5
# 2376  http://cdn.akamai.steamstatic.com/steam/apps/2...  2011       5
#
# [199 rows x 41 columns]
# Period: 2012 - 2015
#        AppID                                     Name Release date  \
# 4     242530                         The Chaos Engine   2013-08-29
# 7     108200                           Ticket to Ride   2012-05-24
# 8     302610                                  Boson X   2014-09-15
# 9     205690                                1000 Amps   2012-02-22
# 10    239430                  Q.U.B.E: Director's Cut   2014-05-21
# ...      ...                                      ...          ...
# 2361  104900                           ORION: Prelude   2013-04-16
# 2368  318220            Enforcer: Police Crime Action   2014-10-24
# 2370  253430                            CastleMiner Z   2014-02-03
# 2371  239200              Amnesia: A Machine for Pigs   2013-09-10
# 2378  265210  Viscera Cleanup Detail: Santa's Rampage   2013-12-13
#
#        Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 4       100000 - 200000         0             0   9.99          0
# 7      500000 - 1000000       395             0   9.99         10
# 8       200000 - 500000         5             0   2.99          0
# 9       100000 - 200000         0             0   4.99          0
# 10     500000 - 1000000         4             0   2.49          0
# ...                 ...       ...           ...    ...        ...
# 2361  1000000 - 2000000        13             0   0.99          1
# 2368    100000 - 200000         1            18  19.99          1
# 2370   500000 - 1000000        43             0   3.99          0
# 2371  1000000 - 2000000        17             0  19.99          0
# 2378  1000000 - 2000000        27             0   2.49          0
#
#                                          About the game  \
# 4     Prepare for the dark world of The Chaos Engine...
# 7     Set off with your friends and family to re(dis...
# 8     Quantum jump your way to critical velocity in ...
# 9     Light up the world! As Plug, you are charged w...
# 10    Q.U.B.E: Director's Cut is the definitive vers...
# ...                                                 ...
# 2361  ' ORION: Prelude ' is an indie Sci-Fi shooter ...
# 2368  While on duty you’ll need to remain ever vigil...
# 2370  CastleMiner Z is an online coop survival horro...
# 2371  This world is a Machine. A Machine for Pigs. F...
# 2378  Tragedy! Santa; the toy giving folk-hero, and ...
#
#                                     Supported languages  ...  \
# 4     ['English', 'French', 'German', 'Spanish - Spa...  ...
# 7     ['English', 'French', 'German', 'Italian', 'Sp...  ...
# 8                                           ['English']  ...
# 9                                           ['English']  ...
# 10                                          ['English']  ...
# ...                                                 ...  ...
# 2361                                        ['English']  ...
# 2368  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2370  ['English', 'Italian', 'German', 'Japanese', '...  ...
# 2371  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2378                                        ['English']  ...
#
#      Median playtime two weeks                             Developers  \
# 4                            0  Abstraction Games,The Bitmap Brothers
# 7                            0                         Days of Wonder
# 8                            0                Ian MacLarty,Jon Kerney
# 9                            0                         Brandon Brizzi
# 10                           0                            Toxic Games
# ...                        ...                                    ...
# 2361                         0                                 DANKIE
# 2368                         0                       Odin Game Studio
# 2370                         7                   DigitalDNA Games LLC
# 2371                         0                       The Chinese Room
# 2378                         0                              RuneStorm
#
#                           Publishers  \
# 4                          Rebellion
# 7     Days of Wonder,Asmodee Digital
# 8                       Ian MacLarty
# 9                     Brandon Brizzi
# 10                       Toxic Games
# ...                              ...
# 2361                          DANKIE
# 2368            Excalibur Publishing
# 2370            DigitalDNA Games LLC
# 2371                Frictional Games
# 2378                       RuneStorm
#
#                                              Categories  \
# 4     Single-player,Multi-player,Co-op,Shared/Split ...
# 7     Single-player,Multi-player,PvP,Online PvP,LAN ...
# 8     Single-player,Steam Achievements,Full controll...
# 9                                         Single-player
# 10    Single-player,Steam Achievements,VR Support,Pa...
# ...                                                 ...
# 2361  Single-player,Multi-player,PvP,Online PvP,Co-o...
# 2368                  Single-player,Steam Trading Cards
# 2370  Single-player,Multi-player,PvP,Online PvP,Co-o...
# 2371  Single-player,Full controller support,Captions...
# 2378  Single-player,Multi-player,Co-op,Shared/Split ...
#
#                               Genres  \
# 4                             Action
# 7              Casual,Indie,Strategy
# 8                       Action,Indie
# 9                    Adventure,Indie
# 10            Action,Adventure,Indie
# ...                              ...
# 2361      Action,Adventure,Indie,RPG
# 2368     Action,Adventure,Simulation
# 2370  Violent,Action,Adventure,Indie
# 2371          Action,Adventure,Indie
# 2378           Gore,Indie,Simulation
#
#                                                    Tags  \
# 4     Action,Retro,Co-op,Steampunk,Top-Down,Classic,...
# 7     Board Game,Strategy,Tabletop,Casual,Multiplaye...
# 8     Difficult,Action,Arcade,Runner,Minimalist,Park...
# 9     Puzzle-Platformer,Indie,Platformer,Puzzle,Adve...
# 10    Puzzle,Indie,First-Person,Adventure,Action,Sci...
# ...                                                 ...
# 2361  Dinosaurs,Action,FPS,Multiplayer,Online Co-Op,...
# 2368  Simulation,Action,Open World,Crime,Adventure,S...
# 2370  Open World Survival Craft,Survival,Zombies,Mul...
# 2371  Walking Simulator,Horror,Story Rich,Atmospheri...
# 2378  Simulation,Gore,Co-op,Indie,Blood,Comedy,Funny...
#
#                                             Screenshots  \
# 4     https://cdn.akamai.steamstatic.com/steam/apps/...
# 7     https://cdn.akamai.steamstatic.com/steam/apps/...
# 8     https://cdn.akamai.steamstatic.com/steam/apps/...
# 9     https://cdn.akamai.steamstatic.com/steam/apps/...
# 10    https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                 ...
# 2361  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2368  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2370  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2371  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2378  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  Movies  year  period
# 4     http://cdn.akamai.steamstatic.com/steam/apps/2...  2013       6
# 7     http://cdn.akamai.steamstatic.com/steam/apps/2...  2012       6
# 8     http://cdn.akamai.steamstatic.com/steam/apps/2...  2014       6
# 9                                                   NaN  2012       6
# 10    http://cdn.akamai.steamstatic.com/steam/apps/2...  2014       6
# ...                                                 ...   ...     ...
# 2361  http://cdn.akamai.steamstatic.com/steam/apps/2...  2013       6
# 2368  http://cdn.akamai.steamstatic.com/steam/apps/2...  2014       6
# 2370  http://cdn.akamai.steamstatic.com/steam/apps/2...  2014       6
# 2371                                                NaN  2013       6
# 2378  http://cdn.akamai.steamstatic.com/steam/apps/2...  2013       6
#
# [843 rows x 41 columns]
# Period: 2015 - 2018
#        AppID                           Name Release date   Estimated owners  \
# 0     346560         Hero of the Kingdom II   2015-02-20    100000 - 200000
# 1     434030  Aerofly FS 2 Flight Simulator   2017-11-20    100000 - 200000
# 3     396640                     TowerClimb   2015-09-22          0 - 20000
# 5     338190               Just Get Through   2015-01-30      20000 - 50000
# 6     351910                 Valhalla Hills   2015-12-02    200000 - 500000
# ...      ...                            ...          ...                ...
# 2364  341940                         Hatred   2015-06-01   500000 - 1000000
# 2366  495890                        Montaro   2016-07-25    200000 - 500000
# 2367  298900          Space Hulk: Deathwing   2016-12-14    200000 - 500000
# 2373  403190                     Planetbase   2015-10-15   500000 - 1000000
# 2377  307780                Mortal Kombat X   2015-04-13  2000000 - 5000000
#
#       Peak CCU  Required age  Price  DLC count  \
# 0            5             0   7.99          0
# 1           19             0  37.49         23
# 3            0             0  14.99          1
# 5            0             0   4.99          0
# 6            3             0   0.69          3
# ...        ...           ...    ...        ...
# 2364        49            18   5.99          2
# 2366         6             0   0.99          0
# 2367         4             0   0.00          0
# 2373       201             0  14.99          0
# 2377       351            17  19.99         23
#
#                                          About the game  \
# 0     Sail to the farthest islands to save your sist...
# 1     Aerofly FS 2 lets you explore the world of fly...
# 3     TowerClimb is a difficult and rewarding proced...
# 5     The procedurally generated platformer Just Get...
# 6     You spent your whole life in service to the go...
# ...                                                 ...
# 2364  Hatred fills your whole body. You’re sick and ...
# 2366  Montaro is a casual runner game that was creat...
# 2367  Space Hulk: Deathwing is a First-Person Shoote...
# 2373  Planetbase is a strategy game where you guide ...
# 2377  Who’s Next? Experience the Next Generation of ...
#
#                                     Supported languages  ...  \
# 0     ['English', 'French', 'German', 'Spanish - Spa...  ...
# 1                       ['English', 'German', 'French']  ...
# 3                                           ['English']  ...
# 5                                           ['English']  ...
# 6     ['English', 'German', 'Russian', 'French', 'It...  ...
# ...                                                 ...  ...
# 2364  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2366  ['English', 'Russian', 'Simplified Chinese', '...  ...
# 2367  ['English', 'French', 'German', 'Spanish - Spa...  ...
# 2373  ['English', 'Spanish - Spain', 'French', 'Germ...  ...
# 2377  ['English', 'French', 'Italian', 'Spanish - Sp...  ...
#
#      Median playtime two weeks                Developers  \
# 0                            0             Lonely Troops
# 1                            0                     IPACS
# 3                            0       Davioware and Quazi
# 5                            0                  Retrific
# 6                            0         Funatics Software
# ...                        ...                       ...
# 2364                         0     Destructive Creations
# 2366                         0                   JCKSLAP
# 2367                         0          Streum On Studio
# 2373                         0             Madruga Works
# 2377                       210  NetherRealm Studios,QLOC
#
#                                   Publishers  \
# 0                              Lonely Troops
# 1                                      IPACS
# 3                        Davioware and Quazi
# 5                                   Retrific
# 6                     Daedalic Entertainment
# ...                                      ...
# 2364                   Destructive Creations
# 2366                                    MBDL
# 2367                     Focus Entertainment
# 2373                           Madruga Works
# 2377  Warner Bros. Interactive Entertainment
#
#                                              Categories  \
# 0     Single-player,Steam Achievements,Steam Trading...
# 1              Single-player,Partial Controller Support
# 3     Single-player,Multi-player,Shared/Split Screen...
# 5     Single-player,Steam Achievements,Full controll...
# 6     Single-player,Steam Achievements,Steam Trading...
# ...                                                 ...
# 2364  Single-player,Steam Achievements,Steam Trading...
# 2366  Single-player,Steam Achievements,Steam Trading...
# 2367  Single-player,Multi-player,Co-op,Online Co-op,...
# 2373  Single-player,Steam Achievements,Steam Trading...
# 2377  Single-player,Multi-player,PvP,Shared/Split Sc...
#
#                                     Genres  \
# 0               Adventure,Casual,Indie,RPG
# 1           Action,Indie,Racing,Simulation
# 3               Action,Adventure,Indie,RPG
# 5     Action,Adventure,Casual,Indie,Racing
# 6                Indie,Simulation,Strategy
# ...                                    ...
# 2364                          Action,Indie
# 2366                          Casual,Indie
# 2367                      Action,Adventure
# 2373             Indie,Simulation,Strategy
# 2377                                Action
#
#                                                    Tags  \
# 0     Adventure,Casual,Point & Click,RPG,Indie,Isome...
# 1     Flight,Simulation,VR,Racing,Physics,Open World...
# 3     Indie,Action Roguelike,Action,Adventure,Rogue-...
# 5     Action Roguelike,Indie,Casual,Action,Adventure...
# 6     Strategy,Simulation,Indie,City Builder,Vikings...
# ...                                                 ...
# 2364  Gore,Violent,Action,Dark,Mature,Shooter,Indie,...
# 2366  Memes,Cute,Anime,Casual,Indie,Pixel Graphics,R...
# 2367  Warhammer 40K,Action,FPS,Online Co-Op,Sci-fi,C...
# 2373  Colony Sim,City Builder,Base-Building,Space,St...
# 2377  Fighting,Gore,Action,Violent,Multiplayer,Blood...
#
#                                             Screenshots  \
# 0     https://cdn.akamai.steamstatic.com/steam/apps/...
# 1     https://cdn.akamai.steamstatic.com/steam/apps/...
# 3     https://cdn.akamai.steamstatic.com/steam/apps/...
# 5     https://cdn.akamai.steamstatic.com/steam/apps/...
# 6     https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                 ...
# 2364  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2366  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2367  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2373  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2377  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  Movies  year  period
# 0     http://cdn.akamai.steamstatic.com/steam/apps/2...  2015       7
# 1     http://cdn.akamai.steamstatic.com/steam/apps/2...  2017       7
# 3     http://cdn.akamai.steamstatic.com/steam/apps/2...  2015       7
# 5     http://cdn.akamai.steamstatic.com/steam/apps/2...  2015       7
# 6     http://cdn.akamai.steamstatic.com/steam/apps/2...  2015       7
# ...                                                 ...   ...     ...
# 2364  http://cdn.akamai.steamstatic.com/steam/apps/2...  2015       7
# 2366  http://cdn.akamai.steamstatic.com/steam/apps/2...  2016       7
# 2367  http://cdn.akamai.steamstatic.com/steam/apps/2...  2016       7
# 2373  http://cdn.akamai.steamstatic.com/steam/apps/2...  2015       7
# 2377  http://cdn.akamai.steamstatic.com/steam/apps/2...  2015       7
#
# [1126 rows x 41 columns]
# Period: 2018 - 2021
#         AppID                                       Name Release date  \
# 59     363360                          Interstellar Rift   2020-09-24
# 77    1120410                               Apollo 11 VR   2019-08-01
# 152    315460                                 Dig or Die   2018-07-10
# 176    320240                               We Happy Few   2018-08-10
# 202    321980                                   Hardland   2019-09-17
# ...       ...                                        ...          ...
# 2084   389670                                      Pacer   2020-10-03
# 2157   473770                                BallisticNG   2018-12-14
# 2186   327090                               Out of Reach   2018-07-13
# 2218   323220                                    Vagante   2018-02-21
# 2360    12210  Grand Theft Auto IV: The Complete Edition   2020-03-24
#
#        Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 59       50000 - 100000        25             0   6.79          2
# 77            0 - 20000         0             0   0.00          0
# 152     200000 - 500000        37             0  11.99          0
# 176    500000 - 1000000       165            17  59.99          4
# 202      50000 - 100000         0             0  24.99          0
# ...                 ...       ...           ...    ...        ...
# 2084          0 - 20000         1             0  39.99          0
# 2157    200000 - 500000         8             0   7.99          4
# 2186     50000 - 100000         3             0  14.99          0
# 2218    200000 - 500000       102             0  14.99          1
# 2360  2000000 - 5000000      3439            17   5.99          0
#
#                                          About the game  \
# 59    Interstellar Rift is an open world Starship Si...
# 77    Apollo 11 VR is a first person experience of t...
# 152   Explore, fight, craft and build your defenses!...
# 176   We Happy Few is the tale of a plucky bunch of ...
# 202   In the year of Our Elder King 1018, an adventu...
# ...                                                 ...
# 2084  2075: The PACER World Championship has become ...
# 2157  BallisticNG is an anti-gravity combat racer an...
# 2186  The one who said that a combination of thunder...
# 2218  Vagante is an adventure set in a dark fantasy ...
# 2360  Niko Bellic, Johnny Klebitz, and Luis Lopez al...
#
#                                     Supported languages  ...  \
# 59    ['English', 'German', 'Russian', 'Simplified C...  ...
# 77                                          ['English']  ...
# 152   ['English', 'French', 'Russian', 'Simplified C...  ...
# 176   ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 202                                         ['English']  ...
# ...
# 2227  2252960                   Flashback   2023-02-20          0 - 20000
# 2273  1824450                    Ricochet   2022-01-11          0 - 20000
# 2379  1693980                  Dead Space   2023-01-27    200000 - 500000
# 2380  2050650             Resident Evil 4   2023-03-23          0 - 20000
#
#       Peak CCU  Required age  Price  DLC count  \
# 45          15            17  19.99          0
# 234          7             0   7.49          0
# 283          0             0   0.00          0
# 288          5             0   6.99          0
# 326         16             0  14.99          0
# 441         43             0  19.99          0
# 577          4             0   9.99          0
# 733       2779             0   0.00          0
# 805          3             0  14.99          0
# 1045         1             0   8.99          0
# 1153         0             0   0.00          0
# 1369         2             0   0.00          2
# 1454        71             0   0.00          0
# 1812         0             0   0.00          0
# 2062       264             0  24.99          0
# 2220         0             0   2.99          0
# 2221         0             0   8.99          0
# 2222         0             0   2.99          0
# 2223         0             0   0.00          0
# 2224         0             0   0.00          0
# 2225         0             0   0.00          3
# 2227         0             0   0.89          0
# 2273         0             0   2.99          2
# 2379     28122            17  59.99          1
# 2380    153726            17  59.99          9
#
#                                          About the game  \
# 45    The beloved, choice-driven narrative adventure...
# 234   Climbey is a VR-only climbing game! The goal i...
# 283   Rift is a third person arcade-style shooter wi...
# 288   A peaceful exploration and base building game ...
# 326   S.B.T.F. is a very hard arcade-style / rogue-l...
# 441   Have you ever dreamed of running your own car ...
# 577   Savage Lands is a challenging fantasy survival...
# 733   Rec Room is the best place to build and play g...
# 805   Both Sneak Thief 1.0 and Sneak Thief Legacy ar...
# 1045  Escape alien beasts across varying environment...
# 1153  Based on a short story of the same name. This ...
# 1369  Holodrive is a super fast-paced collectable 2D...
# 1454  CyberCon, the notorious global corporation, as...
# 1812  Grapple is a parkour game built for speedrunni...
# 2062  Team up to operate a starship and explore a ra...
# 2220  Current state of the game 1. My game is not co...
# 2221  Stranded in another solar system on a confusin...
# 2222  Play as a flaming ball of light bouncing off w...
# 2223  The story In Resonance you experience the stor...
# 2224  Summary 'The Visitor' is a singleplayer first-...
# 2225  theBlu: is a deeply immersive VR series that a...
# 2227  You will play as a deliveryman and encounter v...
# 2273  Ricochet is a 2D action shooter. Run around in...
# 2379  The sci-fi survival-horror classic Dead Space™...
# 2380  Survival is just the beginning. Six years have...
#
#                                     Supported languages  ...  \
# 45    ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 234                                         ['English']  ...
# 283                                         ['English']  ...
# 288                                         ['English']  ...
# 326                                         ['English']  ...
# 441   ['English', 'French', 'Japanese', 'Portuguese'...  ...
# 577                                         ['English']  ...
# 733                                         ['English']  ...
# 805                                         ['English']  ...
# 1045                                        ['English']  ...
# 1153                                        ['English']  ...
# 1369  ['English', 'Portuguese - Brazil', 'Spanish - ...  ...
# 1454  ['English', 'Turkish', 'Bulgarian', 'Swedish',...  ...
# 1812                                        ['English']  ...
# 2062                                        ['English']  ...
# 2220                  ['English', 'Simplified Chinese']  ...
# 2221                                        ['English']  ...
# 2222                                        ['English']  ...
# 2223                                         ['German']  ...
# 2224                                        ['English']  ...
# 2225                                        ['English']  ...
# 2227  ['English', 'Japanese', 'Simplified Chinese', ...  ...
# 2273                                        ['English']  ...
# 2379  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2380  ['English', 'French', 'Italian', 'German', 'Sp...  ...
#
#      Median playtime two weeks                             Developers  \
# 45                           0                         Telltale Games
# 234                          0                        Brian Lindenhof
# 283                          0                             HaZimation
# 288                          0          Claudio Norori,Antonio Vargas
# 326                          3                            nornware AB
# 441                          0  Visual Entertainment And Technologies
# 577                          0               Last Bastion Studios LLC
# 733                         95                               Rec Room
# 805                          0                         Nicholas Rizzo
# 1045                         0                              Altfuture
# 1153                         0                  Studio Madeleine Chai
# 1369                         0                         BitCake Studio
# 1454                         0                        Reperio Studios
# 1812                         0                                  Barji
# 2062                       139                            Leafy Games
# 2220                         0                             individual
# 2221                         0                                   Bage
# 2222                         0                                 Kofi-S
# 2223                         0                         MI Matrikel 16
# 2224                         0                  Raining Glass Studios
# 2225                         0                              Wevr, Inc
# 2227                         0                                  Renka
# 2273                         0    Nathaniel Stauffer,Michael Stauffer
# 2379                       356                                 Motive
# 2380                       297                       CAPCOM Co., Ltd.
#
#                                  Publishers  \
# 45                                       2K
# 234                       ShadowBrain Games
# 283                              HaZimation
# 288                                     NaN
# 326                             nornware AB
# 441   Visual Entertainment And Technologies
# 577                Last Bastion Studios LLC
# 733                                Rec Room
# 805                          Nicholas Rizzo
# 1045                              Altfuture
# 1153                  Studio Madeleine Chai
# 1369                            Versus Evil
# 1454                        Reperio Studios
# 1812                                  Barji
# 2062                            Leafy Games
# 2220                             individual
# 2221                                   Bage
# 2222                                 Kofi-S
# 2223   Hochschule Mittweida,Games-Studieren
# 2224                  Raining Glass Studios
# 2225                              Wevr, Inc
# 2227                                  Renka
# 2273                             Nix Studio
# 2379                        Electronic Arts
# 2380                       CAPCOM Co., Ltd.
#
#                                              Categories  \
# 45    Single-player,Steam Achievements,Full controll...
# 234   Single-player,Multi-player,PvP,Online PvP,Co-o...
# 283            Single-player,Partial Controller Support
# 288   Single-player,Multi-player,Co-op,Online Co-op,...
# 326   Single-player,Multi-player,PvP,Online PvP,Shar...
# 441   Single-player,Steam Achievements,Steam Trading...
# 577   Single-player,Multi-player,Co-op,Online Co-op,...
# 733   Multi-player,MMO,PvP,Online PvP,Co-op,Online C...
# 805   Single-player,Multi-player,PvP,Online PvP,Co-o...
# 1045              Single-player,Full controller support
# 1153  Single-player,Steam Achievements,Full controll...
# 1369  Multi-player,PvP,Online PvP,Cross-Platform Mul...
# 1454  Single-player,Multi-player,PvP,Online PvP,LAN ...
# 1812                   Single-player,Steam Achievements
# 2062  Single-player,Multi-player,Co-op,Online Co-op,...
# 2220                                      Single-player
# 2221                   Single-player,Steam Achievements
# 2222  Single-player,Multi-player,Full controller sup...
# 2223      Single-player,Multi-player,Co-op,Online Co-op
# 2224                                      Single-player
# 2225  Single-player,Tracked Controller Support,VR On...
# 2227       Single-player,Steam Achievements,Steam Cloud
# 2273  Multi-player,PvP,Shared/Split Screen PvP,Share...
# 2379  Single-player,Steam Achievements,Full controll...
# 2380  Single-player,Steam Achievements,Full controll...
#
#                                                  Genres  \
# 45                                            Adventure
# 234                                   Racing,Simulation
# 283              Action,Adventure,Strategy,Early Access
# 288                              Adventure,Casual,Indie
# 326                                        Action,Indie
# 441                           Indie,Simulation,Strategy
# 577               Action,Adventure,Indie,RPG,Simulation
# 733   Adventure,Casual,Free to Play,Massively Multip...
# 805                               Action,Indie,Strategy
# 1045                                Action,Indie,Racing
# 1153               Casual,Free to Play,Indie,Simulation
# 1369                          Action,Free to Play,Indie
# 1454                Action,Adventure,Free to Play,Indie
# 1812   Action,Casual,Free to Play,Indie,Racing,Strategy
# 2062                  Action,Adventure,Indie,Simulation
# 2220                                    Adventure,Indie
# 2221                         Casual,Simulation,Strategy
# 2222                                Action,Casual,Indie
# 2223                       Adventure,Free to Play,Indie
# 2224                                             Casual
# 2225                  Adventure,Casual,Indie,Simulation
# 2227                              Casual,Indie,Strategy
# 2273                                       Action,Indie
# 2379                                   Action,Adventure
# 2380                                   Action,Adventure
#
#                                                    Tags  \
# 45    Comedy,Adventure,Story Rich,Choices Matter,Sin...
# 234   Simulation,Racing,VR,Parkour,Multiplayer,Indie...
# 283                                                 NaN
# 288   Open World Survival Craft,Open World,Adventure...
# 326   Action Roguelike,Action,Indie,Horror,Co-op,FPS...
# 441   Simulation,Management,Strategy,Indie,Economy,A...
# 577   Open World Survival Craft,Survival,Open World,...
# 733   Free to Play,VR,Multiplayer,Online Co-Op,Funny...
# 805   Stealth,Action,Strategy,Indie,First-Person,Sin...
# 1045  Action Roguelike,Racing,Action,Indie,Pixel Gra...
# 1153                                                NaN
# 1369  Free to Play,Indie,Action,Multiplayer,Shooter,...
# 1454  Free to Play,Zombies,Multiplayer,FPS,Survival,...
# 1812                                                NaN
# 2062  Space,Co-op,Open World,Adventure,Multiplayer,A...
# 2220  Adventure,War,Puzzle,Story Rich,2D,Noir,Physic...
# 2221  Tower Defense,Time Management,Colony Sim,Agric...
# 2222                                                NaN
# 2223                                                NaN
# 2224                                                NaN
# 2225                                                NaN
# 2227  Anime,Choices Matter,Rogue-lite,Multiple Endin...
# 2273  Action,Multiplayer,Local Multiplayer,2D,2D Fig...
# 2379  Horror,Third-Person Shooter,Space,Shooter,Sci-...
# 2380  Action,Horror,Survival Horror,Third-Person Sho...
#
#                                             Screenshots  \
# 45    https://cdn.akamai.steamstatic.com/steam/apps/...
# 234   https://cdn.akamai.steamstatic.com/steam/apps/...
# 283   https://cdn.akamai.steamstatic.com/steam/apps/...
# 288   https://cdn.akamai.steamstatic.com/steam/apps/...
# 326   https://cdn.akamai.steamstatic.com/steam/apps/...
# 441   https://cdn.akamai.steamstatic.com/steam/apps/...
# 577   https://cdn.akamai.steamstatic.com/steam/apps/...
# 733   https://cdn.akamai.steamstatic.com/steam/apps/...
# 805   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1045  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1153  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1369  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1454  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1812  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2062  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2220  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2221  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2222  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2223  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2224  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2225  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2227  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2273  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2379  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2380  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  Movies  year  period
# 45    http://cdn.akamai.steamstatic.com/steam/apps/2...  2021       9
# 234   http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 283   http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 288   http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 326   http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 441   http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 577   http://cdn.akamai.steamstatic.com/steam/apps/2...  2021       9
# 733   http://cdn.akamai.steamstatic.com/steam/apps/2...  2021       9
# 805   http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 1045  http://cdn.akamai.steamstatic.com/steam/apps/2...  2021       9
# 1153  http://cdn.akamai.steamstatic.com/steam/apps/2...  2021       9
# 1369  http://cdn.akamai.steamstatic.com/steam/apps/2...  2021       9
# 1454  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 1812  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2062  http://cdn.akamai.steamstatic.com/steam/apps/2...  2021       9
# 2220  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2221  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2222  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2223  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2224  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2225  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2227  http://cdn.akamai.steamstatic.com/steam/apps/2...  2023       9
# 2273  http://cdn.akamai.steamstatic.com/steam/apps/2...  2022       9
# 2379  http://cdn.akamai.steamstatic.com/steam/apps/2...  2023       9
# 2380  http://cdn.akamai.steamstatic.com/steam/apps/2...  2023       9
#
# [25 rows x 41 columns]

# %%
#通过CSV文件1中一列的值对CSV文件2进行筛选
def filter_csv_by_another(file1, file2, output_file, column_name):
    """
    通过CSV文件1中一列的值对CSV文件2进行筛选。

    :param file1: 第一个CSV文件的路径
    :param file2: 第二个CSV文件的路径
    :param output_file: 保存结果的CSV文件的路径
    :param column_name: 用于筛选数据的列的名称
    """
    # 读取两个CSV文件
    df1 = pd.read_csv(file1)
    df2 = pd.read_csv(file2)

    # 从第一个CSV文件中获取一列的值
    values = df1[column_name].values

    # 在第二个CSV文件中筛选数据
    df2_filtered = df2[df2[column_name].isin(values)]

    # 保存结果
    df2_filtered.to_csv(output_file, index=False)

# 使用示例
#filter to get the information for Good games
# file1 = "Good_Game.csv"
file1 = "Hard_to_say.csv"

file2 = "games.csv"
# output_file = "Filtered_Good_Game.csv"
output_file = "Filtered_Hard_to_say.csv"

column_name = "Name"
filter_csv_by_another(file1, file2, output_file, column_name)

# %%
import os
import pandas as pd

# 指定文件夹路径
folder_path = 'years'

# 列出文件夹中的所有文件
filenames = os.listdir(folder_path)

# 对每个文件进行操作
for filename in filenames:
    # 检查文件是否为CSV文件
    if filename.endswith('.csv'):
        # 读取CSV文件
        df = pd.read_csv(os.path.join(folder_path, filename))

        df2 = pd.DataFrame()
        # 将逗号分隔的字符串拆分成列表
        df['Tags'] = df['Tags'].str.split(',')

        # 对列表进行one-hot编码
        df2 = df['Tags'].str.join('|').str.get_dummies()
        df2['Positive'] = df['Positive']

        # 保存结果，将原文件名（不含'.csv'）后加上'_after_onehot'作为新文件名
        new_filename = os.path.splitext(filename)[0] + '_after_onehot.csv'
        df2.to_csv(os.path.join(folder_path, new_filename), index=False)

# %%
# #完成每个的分类
# # 读取CSV文件
# # df = pd.read_csv("Filtered_Good_Game.csv")
# df = pd.read_csv("combined.csv")
#
# df2 = pd.DataFrame()
# # 将逗号分隔的字符串拆分成列表
# df['Tags'] = df['Tags'].str.split(',')
#
#
# # 对列表进行one-hot编码
# df2 = df['Tags'].str.join('|').str.get_dummies()
# df2['Positive'] = df['Positive']
# # df2['Recommendations'] = df['Recommendations']
# # df2['Average playtime forever'] = df['Average playtime forever']
#
# # 保存结果
# # df2.to_csv('After_one_hot_Good_Game.csv', index=False)
# df2.to_csv('after_onehot_combined.csv', index=False)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# 加载数据
# df = pd.read_csv("After_one_hot_Good_Game.csv")
df = pd.read_csv("data_2006_2009_after_onehot.csv")

# 我们假设df已经经过了one-hot编码

# 特征与目标
X = df.drop(columns=["Positive"]) # 假设"Recommendations"是你的目标列
y = df["Positive"]

# 分割数据集为训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=771)

# 创建并训练决策树回归模型
model = DecisionTreeRegressor(random_state=771)
model.fit(X_train, y_train)

# 评估模型
print(f"Training score: {model.score(X_train, y_train)}")
print(f"Test score: {model.score(X_test, y_test)}")

# 特征重要性
importance = pd.DataFrame({"Feature": X.columns, "Importance": model.feature_importances_})

# 排序以找到最重要的特征
importance = importance.sort_values(by="Importance", ascending=False)

print(importance.head(20))
# Out:
# Training score: 1.0
# Test score: 0.9025757506127253
#                   Feature  Importance
# 76                  Funny    0.495546
# 116          Online Co-Op    0.492160
# 150               Science    0.008967
# 81       Great Soundtrack    0.001029
# 157    Silent Protagonist    0.000640
# 20          Base-Building    0.000542
# 21       Based On A Novel    0.000493
# 176          Third Person    0.000251
# 8              Action RPG    0.000112
# 90   Inventory Management    0.000066
# 47           Cult Classic    0.000040
# 167              Strategy    0.000036
# 126      Post-apocalyptic    0.000027
# 121               Physics    0.000018
# 154               Shooter    0.000014
# 98                   Mars    0.000013
# 147               Sandbox    0.000011
# 10              Addictive    0.000010
# 25            Bullet Time    0.000004
# 18            Atmospheric    0.000004

# %%
import pandas as pd

# 读取csv文件
df = pd.read_csv('data_2009_2012_after_onehot.csv')

# 计算每一列（即每一个one-hot编码特征）的总和
counts = df.sum()

# 对计数进行排序并选取前20个
top20 = counts.sort_values(ascending=False)[:21]

print(top20)
# Out:
# Positive            3823349
# Singleplayer            178
# Action                  135
# Adventure               103
# Multiplayer              96
# Indie                    88
# Strategy                 80
# Great Soundtrack         71
# Co-op                    65
# Shooter                  62
# Atmospheric              60
# Sci-fi                   58
# Puzzle                   51
# Casual                   50
# RPG                      49
# 2D                       48
# Comedy                   47
# Third Person             45
# First-Person             42
# Open World               41
# Classic                  41
# dtype: int64

# %%
import os
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# 指定文件夹路径
folder_path = 'after_onehot'

# 列出文件夹中的所有文件
filenames = os.listdir(folder_path)

# 对每个文件进行操作
for filename in filenames:
    # 检查文件是否为CSV文件
    if filename.endswith('.csv'):
        # 读取CSV文件
        df = pd.read_csv(os.path.join(folder_path, filename))

        # 特征与目标
        X = df.drop(columns=["Positive"])  # 假设"Positive"是你的目标列
        y = df["Positive"]

        best_score = -np.inf
        best_random_state = None

        # 设置你想要遍历的random_state的范围
        # 这里我们每10个数值选取一次，从而减少遍历的数量
        for random_state in range(1, 1000, 10):
            # 分割数据集为训练集和测试集
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

            # 创建并训练决策树回归模型
            model = DecisionTreeRegressor(random_state=random_state)
            model.fit(X_train, y_train)

            # 评估模型
            score = model.score(X_test, y_test)

            # 如果这个模型的得分比之前的模型好，那么更新最好的分数和对应的random_state
            if score > best_score:
                best_score = score
                best_random_state = random_state

        # 打印结果
        print(f"For {filename}:")
        print(f"Best random state: {best_random_state}")
        print(f"Best test score: {best_score}")

        # 保存结果到CSV文件
        with open(os.path.join(folder_path, 'best_params.csv'), 'a') as f:
            writer = csv.writer(f)
            writer.writerow([filename, best_random_state, best_score])
# Out:
# For data_2018_2021_after_onehot.csv:
# Best random state: 751
# Best test score: 0.6295454860072749
# For data_2015_2018_after_onehot.csv:
# Best random state: 111
# Best test score: 0.23432700584756583
# For data_2009_2012_after_onehot.csv:
# Best random state: 21
# Best test score: 0.2723578099277504
# For data_2003_2006_after_onehot.csv:
# Best random state: 261
# Best test score: 0.3551623013519485
# For data_2012_2015_after_onehot.csv:
# Best random state: 631
# Best test score: 0.6897030094564062
# For data_2006_2009_after_onehot.csv:
# Best random state: 771
# Best test score: 0.9025757506127253
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/jiayi/Desktop/final/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# For data_2000_2003_after_onehot.csv:
# Best random state: None
# Best test score: -inf
# For data_2021_2024_after_onehot.csv:
# Best random state: 511
# Best test score: 0.995427461818299

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.svm import SVR
# import pandas as pd
#
# # 加载数据
# df = pd.read_csv("After_one_hot_Good_Game.csv")
#
# # 特征与目标
# X = df.drop(columns=["Positive"]) # "Positive" 是你的目标列
# y = df["Positive"]
#
# # 分割数据集为训练集和测试集
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1000)
#
# # 创建并训练SVM回归模型
# model = SVR()
# model.fit(X_train, y_train)
#
# # 评估模型
# print(f"Training score: {model.score(X_train, y_train)}")
# print(f"Test score: {model.score(X_test, y_test)}")
# Out:
# Training score: -0.03342613212769452
# Test score: -0.04877668030917959

# %%
from dateutil import parser

# 加载数据
df = pd.read_csv("games.csv")

# 使用dateutil解析日期
df['Release date'] = df['Release date'].apply(lambda x: parser.parse(x))

# 获取每一行的年份
df['year'] = df['Release date'].dt.year

# 找到每个年份中'Positive'值最大的行
df_sorted = df.groupby('year')['Positive'].nlargest(5)
df_sorted = df_sorted.reset_index(level=0, drop=True)

# 选取排序后的数据行
df_top5_positive = df.loc[df_sorted.index]

# 输出到csv
df_top5_positive.to_csv('superstar_games.csv', index=False)

# %%
#从此以下为文化方面

# %%
#不同语言
import pandas as pd
import os
#地区评论分析

def filter_rows(source_folder, target_folder1, target_folder2, target_folder3, column_name, str1, str2, str3):
    """
    遍历文件夹下的所有CSV文件，根据某列的值筛选数据，将符合特定字符串的行写入新的CSV文件。

    :param source_folder: 原CSV文件的文件夹路径
    :param target_folder1: 保存符合字符串1的CSV文件的文件夹路径
    :param target_folder2: 保存符合字符串2的CSV文件的文件夹路径
    :param column_name: 用于筛选数据的列的名称
    :param str1, str2: 要匹配的字符串
    """
    # 列出源文件夹中的所有文件
    filenames = os.listdir(source_folder)

    # 遍历文件名列表
    for filename in filenames:
        # 拼接完整的文件路径
        file_path = os.path.join(source_folder, filename)

        try:
            # 读取CSV文件
            df = pd.read_csv(file_path,encoding='latin1',low_memory=False)

            # 使用布尔索引筛选数据
            df1 = df[df[column_name] == str1]
            df2 = df[df[column_name] == str2]
            df3 = df[df[column_name] == str3]


            # 拼接目标文件的路径
            target_file1 = os.path.join(target_folder1, filename)
            target_file2 = os.path.join(target_folder2, filename)
            target_file3 = os.path.join(target_folder3, filename)

            # 将筛选的数据写入新的CSV文件
            df1.to_csv(target_file1, index=False)
            df2.to_csv(target_file2, index=False)
            df3.to_csv(target_file3, index=False)

        except pd.errors.ParserError:
            print(f"Skipping file due to parsing error: {file_path}")

# 使用示例
source_folder = "comments"
target_folder1 = "Chinese_Comments"
target_folder2 = "English_Comments"
target_folder3 = "Spanish_Comments"
column_name = "language"
str1 = "schinese"
str2 = "english"
str3 = "spanish"
filter_rows(source_folder, target_folder1, target_folder2,target_folder3, column_name, str1, str2, str3)
# Out:
# Skipping file due to parsing error: comments/.DS_Store

# %%
import requests
import csv
import json

# 定义你要查询的应用的ID

# 构造API URL
url = f"https://store.steampowered.com/appreviews/{282070}?json=1&language={'all'}&day_range={'80'}&num_per_page={'90'}"

# 发送GET请求到API
response = requests.get(url)

# 检查请求是否成功
if response.status_code == 200:
    # 请求成功，解析返回的JSON数据
    data = response.json()

    # 输出数据
    with open('data.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False)

else:
    # 请求失败，输出错误信息
    print(f"Request failed with status code {response.status_code}")

# %%
import json
import pandas as pd

# 读取JSON文件
with open('data.json') as f:
    data = json.load(f)

# 从JSON数据创建DataFrame
df = pd.DataFrame(data)
df
# 将DataFrame保存为CSV文件
# df.to_csv('data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 9
#       6     data = json.load(f)
#       8 # 从JSON数据创建DataFrame
# ----> 9 df = pd.DataFrame(data)
#      10 df
#      11 # 将DataFrame保存为CSV文件
#      12 # df.to_csv('data.csv', index=False)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:658, in _extract_index(data)
#     655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
# --> 658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#     662 if have_series:
#     663     if lengths[0] != len(index):
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
import requests
import pandas as pd
import json

# 加载csv文件
appid_data = pd.read_csv("steam_reviews.csv")

# 通过每一行迭代
for index, row in appid_data.iterrows():
    # 获取当前行的appid
    appid = row["app_id"]  # 请将这里的"appid"替换为你的CSV文件中相应列的名称

    # 构造API URL
    url = f"https://store.steampowered.com/appreviews/{appid}?json=1&language=all&day_range=80&num_per_page=90"

    # 发送GET请求到API
    response = requests.get(url)

    # 检查请求是否成功
    if response.status_code == 200:
        # 请求成功，解析返回的JSON数据
        data = response.json()

        # 输出数据
        with open(f'data_{appid}.json', 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False)
    else:
        # 请求失败，输出错误信息
        print(f"Request failed with status code {response.status_code} for appid {appid}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 6
#       3 import json
#       5 # 加载csv文件
# ----> 6 appid_data = pd.read_csv("steam_reviews.csv")
#       8 # 通过每一行迭代
#       9 for index, row in appid_data.iterrows():
#      10     # 获取当前行的appid
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:236, in CParserWrapper.read(self, nrows)
#     234     chunks = self._reader.read_low_memory(nrows)
#     235     # destructive to chunks
# --> 236     data = _concatenate_chunks(chunks)
#     238 else:
#     239     data = self._reader.read(nrows)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:389, in _concatenate_chunks(chunks)
#     387     result[name] = union_categoricals(arrs, sort_categories=False)
#     388 else:
# --> 389     result[name] = concat_compat(arrs)
#     390     if len(non_cat_dtypes) > 1 and result[name].dtype == np.dtype(object):
#     391         warning_columns.append(str(name))
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/dtypes/concat.py:117, in concat_compat(to_concat, axis, ea_compat_axis)
#     114 else:
#     115     target_dtype = np_find_common_type(*dtypes)
# --> 117 result = np.concatenate(to_concat, axis=axis)
#     118 if "b" in kinds and result.dtype.kind in ["i", "u", "f"]:
#     119     # GH#39817 cast to object instead of casting bools to numeric
#     120     result = result.astype(object, copy=False)
#
# KeyboardInterrupt:

# %%
import requests

# 定义你要查询的应用的ID和你想要的语言


# # 构造API URL，添加language参数
url = f"https://store.steampowered.com/appreviews/{282070}?json=1&language={'all'}&day_range={'80'}&num_per_page={'90'}"

# 发送GET请求到API
response = requests.get(url).text
a = pd.DataFrame(response["data"], columns=[x["R"] for x in response["review"]])
a
# 检查请求是否成功
# if response.status_code == 200:
#     # 请求成功，解析返回的JSON数据
#     data = response.json()
#
#     # 输出数据
#     print(data)
# else:
#     # 请求失败，输出错误信息
#     print(f"Request failed with status code {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 11
#       9 # 发送GET请求到API
#      10 response = requests.get(url).text
# ---> 11 a = pd.DataFrame(response["data"], columns=[x["R"] for x in response["review"]])
#      12 a
#      13 # 检查请求是否成功
#      14 # if response.status_code == 200:
#      15 #     # 请求成功，解析返回的JSON数据
#    (...)
#      21 #     # 请求失败，输出错误信息
#      22 #     print(f"Request failed with status code {response.status_code}")
#
# TypeError: string indices must be integers

# %%
import json
import pandas as pd
with open('data.json') as f:
    data = json.load(f)
df = pd.json_normalize(data['success'])
df
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[86], line 5
#       3 with open('data.json') as f:
#       4     data = json.load(f)
# ----> 5 df = pd.json_normalize(data['success'])
#       6 df
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/io/json/_normalize.py:447, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     445     data = list(data)
#     446 else:
# --> 447     raise NotImplementedError
#     449 # check to see if a simple recursive function is possible to
#     450 # improve performance (see #15621) but only for cases such
#     451 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     452 if (
#     453     record_path is None
#     454     and meta is None
#    (...)
#     457     and max_level is None
#     458 ):
#
# NotImplementedError:

# %%
#从此一下是硬件方面

# %%
import pandas as pd

# 加载数据
df = pd.read_csv("output.csv")

# 假设你想在 'your_column' 列中删除 'your_string'
df['name'] = df['name'].str.replace(' System Requirements','',case=False)

# 保存修改后的 DataFrame 到 CSV
df.to_csv("hardware.csv", index=False)

# %%
#判断硬件是否存在
import pandas as pd

df1 = pd.read_csv('superstar_games.csv',encoding_errors = 'ignore')
df2 = pd.read_csv('hardware.csv')

# 将df1设为'Name'列作为索引，这样我们可以通过名字直接获取对应的年份
df1.set_index('name', inplace=True)

# 在df2中找到在df1的'Name'列中也存在的行
mask = df2['name'].isin(df1.index)

# 创建新的DataFrame，只包含在df1的'Name'列中也存在的行
df_new = df2.loc[mask]

# 创建新列'year'，通过df1获取年份
# df_new['year'] = df1.loc[df_new['name'], 'year'].values

# 将新的DataFrame保存为新的CSV文件
df_new.to_csv('new.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 17
#      14 df_new = df2.loc[mask]
#      16 # 创建新列'year'，通过df1获取年份
# ---> 17 df_new['year'] = df1.loc[df_new['name'], 'year'].values
#      19 # 将新的DataFrame保存为新的CSV文件
#      20 df_new.to_csv('new.csv', index=False)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
#    4148         and not is_extension_array_dtype(value)
#    4149     ):
#    4150         # broadcast across multiple columns if necessary
#    4151         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/frame.py:4870, in DataFrame._sanitize_column(self, value)
#    4867     return _reindex_for_setitem(Series(value), self.index)
#    4869 if is_list_like(value):
# -> 4870     com.require_length_match(value, self.index)
#    4871 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/Desktop/final/venv/lib/python3.10/site-packages/pandas/core/common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (99) does not match length of index (95)

# %%
import pandas as pd

# 加载csv文件
csv1 = pd.read_csv("superstar_games.csv",encoding_errors = 'ignore')
csv2 = pd.read_csv("new.csv")

# 假设你想根据csv1中的"column1"列对csv2进行筛选
merged = pd.merge(csv2, csv1[['name', 'year']], on='name', how='inner')
merged = merged.sort_values('year')

# 将结果保存到新的csv文件
merged.to_csv('new_hardware.csv', index=False)
